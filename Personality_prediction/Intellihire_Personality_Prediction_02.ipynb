# %% [markdown]
# # Importing necessary libraries and downloading necessary packages

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import re
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# download stopwords package
import nltk
nltk.download('stopwords')

# download punkt package
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('averaged_perceptron_tagger')

import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# connecting to google drive

from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Intellihire
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Intellihire

# %% [markdown]
# # **MCQ Questions**

# %%
# load the CSV file into a Pandas DataFrame

responses = pd.read_csv('/content/drive/MyDrive/Intellihire/Responses.csv')
responses
# Out:
#    EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  ...  OPN1  \
# 0     3     1     5     2     4     1     5     2     4      2  ...     5
#
#    OPN2  OPN3  OPN4  OPN5  OPN6  OPN7  OPN8  OPN9  OPN10
# 0     2     4     1     4     1     5     3     4      5
#
# [1 rows x 50 columns]

# %%
# get the average answer to the each question group for the response

col_list = list(responses)
ext = col_list[0:10]
est = col_list[10:20]
agr = col_list[20:30]
csn = col_list[30:40]
opn = col_list[40:50]


res_df = pd.DataFrame()
res_df['openness'] = responses[opn].sum(axis=1)/10
res_df['conscientiousness'] = responses[csn].sum(axis=1)/10
res_df['extraversion'] = responses[ext].sum(axis=1)/10
res_df['agreeableness'] = responses[agr].sum(axis=1)/10
res_df['neuroticism'] = responses[est].sum(axis=1)/10

# %%
# view the distribution of Big Five Traits in candidate based on the responses for the mcq questionnaire
res_df
# Out:
#    openness  conscientiousness  extraversion  agreeableness  neuroticism
# 0       3.4                3.3           2.9            3.2          2.6

# %%
# save the above data into a csv file for future use

res_df.to_csv('mcq_scores.csv', index=False)

# %%
# save the created csv file on google drive

# !cp mcq_scores.csv "/content/drive/MyDrive/Intellihire"
# Out:
# cp: 'mcq_scores.csv' and '/content/drive/MyDrive/Intellihire/mcq_scores.csv' are the same file

# %% [markdown]
# # **Open-Ended Questions**

# %%
# Openness - How often do you seek out new experiences or take risks?
# Concientiousness - How do you ensure that your work is completed accurately and on time?
# Extraversion - How do you feel about social situations and making new connections?
# Agreeableness - How do you handle feedback or criticism from others?
# Neuroticism - Can you tell me about a time when you had to deal with a difficult or stressful situation? How did you handle it?

# %% [markdown]
# # Loading the Data Set

# %%
# load the CSV file into a Pandas DataFrame
responses_df = pd.read_csv('Open_ended.csv')

# %% [markdown]
# # Understading the Dataset

# %%
# Check the dimensions of the DataFrame
print("Number of rows:", responses_df.shape[0])
print("Number of columns:", responses_df.shape[1])
# Out:
# Number of rows: 50
# Number of columns: 5

# %%
# Check the first few rows of the DataFrame
print(responses_df.head())
# Out:
#                                             Openness  \
# 0  I strongly believe that seeking out new experi...
# 1  As someone who thrives on novelty and exciteme...
# 2  While I am naturally inclined to seek out new ...
# 3  Personal and professional growth are two of my...
# 4  While I am not a natural risk-taker, I recogni...
#
#                                     Concientiousness  \
# 0  I prioritize my work according to deadlines an...
# 1  I believe that accuracy and attention to detai...
# 2  I manage my time effectively by planning ahead...
# 3  To ensure that my work is accurate and complet...
# 4  I believe that setting realistic goals is the ...
#
#                                         Extraversion  \
# 0  I'm quite comfortable in social situations and...
# 1  I'm an outgoing person by nature, so social si...
# 2  As someone who values personal relationships, ...
# 3  While I wouldn't necessarily describe myself a...
# 4  As someone who is naturally extroverted, I thr...
#
#                                        Agreeableness  \
# 0  I try to view feedback and criticism as an opp...
# 1  Initially, it can be tough to receive criticis...
# 2  I handle feedback by staying open-minded and a...
# 3  I take feedback seriously, but I also try not ...
# 4  I view feedback as an opportunity to strengthe...
#
#                                          Neuroticism
# 0  When faced with a difficult situation, I try t...
# 1  In my experience, one of the most effective wa...
# 2  When dealing with stressful situations, I like...
# 3  I find that when dealing with stressful situat...
# 4  In my experience, the most effective way to ha...

# %%
# Check the data types of each column
print(responses_df.dtypes)
# Out:
# Openness            object
# Concientiousness    object
# Extraversion        object
# Agreeableness       object
# Neuroticism         object
# dtype: object

# %%
# Check summary statistics for numerical columns
print(responses_df.describe())
# Out:
#                                                  Openness  \
# count                                                  50
# unique                                                 50
# top     I strongly believe that seeking out new experi...
# freq                                                    1
#
#                                          Concientiousness  \
# count                                                  50
# unique                                                 50
# top     I prioritize my work according to deadlines an...
# freq                                                    1
#
#                                              Extraversion  \
# count                                                  50
# unique                                                 50
# top     I'm quite comfortable in social situations and...
# freq                                                    1
#
#                                             Agreeableness  \
# count                                                  50
# unique                                                 49
# top     I believe that feedback is a valuable tool for...
# freq                                                    2
#
#                                               Neuroticism
# count                                                  50
# unique                                                 50
# top     When faced with a difficult situation, I try t...
# freq                                                    1

# %%
# Check the unique values in each column
for col in responses_df.columns:
    print(col, responses_df[col].unique())
# Out:
# Openness ["I strongly believe that seeking out new experiences and taking risks is one of the best ways to foster personal growth and development. Life is too short to stick to the same old routine day in and day out. When we challenge ourselves to step outside our comfort zone, we not only learn new skills and gain valuable experiences, but we also build resilience and confidence. That being said, I understand that taking risks can be scary and intimidating at times. It's important to strike a balance between being adventurous and being cautious, and to always weigh the potential benefits and drawbacks before making any major decisions."
#  "As someone who thrives on novelty and excitement, I make it a point to seek out new experiences and take risks whenever possible. Whether it's trying a new hobby, exploring a new city, or taking on a challenging project at work, I find that these experiences help me stay engaged and motivated in all aspects of my life. Of course, not every risk pays off, and there have been times when I've fallen flat on my face. But even those failures have taught me valuable lessons and helped me grow as a person. I believe that the only true failure is not trying at all."
#  "While I am naturally inclined to seek out new experiences and take risks, I also recognize the importance of being thoughtful and strategic about these decisions. Before making any major moves, I carefully consider the potential risks and rewards, and weigh them against each other. I believe that taking calculated risks is key to success, whether in your personal or professional life. But it's equally important to be realistic and not bite off more than you can chew. By finding the right balance between adventurousness and practicality, I am able to continue to challenge myself while still feeling secure and grounded."
#  "Personal and professional growth are two of my top priorities, and I believe that taking risks is a crucial part of achieving those goals. Whether it's stepping outside my comfort zone to try something new, or taking on a project that feels intimidating, I am always seeking out ways to push myself and expand my horizons. However, I also recognize that not all risks are created equal. It's important to be mindful of potential pitfalls and to assess the potential benefits before taking any big leaps. By approaching risk-taking with a calculated and thoughtful mindset, I am able to make strategic decisions that help me grow in meaningful ways."
#  'While I am not a natural risk-taker, I recognize the value in seeking out new experiences and challenging myself to grow. There have been times in my life when I have played it safe and stuck to my comfort zone, and looking back, I realize that I missed out on many valuable opportunities for growth and learning. These days, I try to strike a balance between being cautious and being adventurous, and I am willing to take risks when I feel that the potential benefits outweigh the potential risks. By doing so, I am able to broaden my horizons and explore new facets of myself and the world around me.'
#  "As someone who enjoys taking risks and seeking out new experiences, I believe that it's important to be practical and grounded in these pursuits. While the thrill of the unknown can be exhilarating, it's important to be mindful of potential risks and to weigh them against the potential rewards. By taking a measured and strategic approach to risk-taking, I am able to pursue my passions and explore new horizons while still maintaining a sense of balance and stability in my life."
#  "Seeking out new experiences and taking risks can be a powerful way to learn, grow, and expand your horizons. But as with any endeavor, it's important to approach these pursuits with a thoughtful and strategic mindset. By being mindful of the potential risks and rewards, and taking a strategic approach to decision-making, I am able to pursue new opportunities and challenges in a way that feels both exciting and secure. While there is always a degree of uncertainty involved in taking risks, I believe that by being thoughtful and strategic in my approach, I am able to maximize my chances of success and minimize potential downsides."
#  "Exploring new ideas and trying new things is one of my greatest passions, but I also recognize the importance of balance and practicality. While it's tempting to dive headfirst into every new opportunity that comes my way, I know that this approach can quickly lead to burnout and overwhelm. Instead, I try to strike a balance between being adventurous and being grounded, and to approach new experiences with a sense of thoughtfulness and intentionality. By doing so, I am able to pursue my passions and interests in a sustainable way, while still considering the potential risks and rewards of each new opportunity."
#  "Seeking out new challenges and experiences is a key part of my personal and professional philosophy. I believe that growth and development are lifelong pursuits, and that the best way to achieve these goals is to challenge yourself to step outside your comfort zone and take risks. However, I also recognize that not all risks are created equal, and that it's important to be thoughtful and strategic in your approach. By carefully considering the potential benefits and drawbacks of each new opportunity, I am able to pursue my passions and interests in a way that feels both exciting and responsible."
#  "To me, seeking out new experiences and taking risks is an essential part of living a fulfilling and meaningful life. Whether it's pursuing a new career path, trying a new hobby, or exploring a new corner of the world, I believe that taking risks is key to personal and professional growth. Of course, this doesn't mean that I approach every new opportunity with reckless abandon. Rather, I try to strike a balance between being adventurous and being pragmatic, and to approach each new challenge with a sense of thoughtfulness and intentionality. By doing so, I am able to pursue my passions and interests in a way that feels both fulfilling and responsible."
#  "I am constantly seeking out new experiences and taking risks. I believe that taking risks is an important part of personal and professional growth. In my personal life, I enjoy trying new activities and exploring new places, and in my professional life, I'm always looking for new challenges and opportunities to learn. While I recognize that taking risks can be scary, I believe that it's important to push yourself out of your comfort zone in order to learn and grow."
#  "I make a point to seek out new experiences and take calculated risks on a regular basis. I believe that it's important to challenge yourself and try new things in order to grow, both personally and professionally. In my personal life, I enjoy trying new hobbies and exploring new places, and in my professional life, I'm always looking for new opportunities to learn and develop new skills. While I do take calculated risks, I also make sure to weigh the potential benefits and drawbacks before making any big decisions."
#  "I try to seek out new experiences and take risks whenever possible. I believe that it's important to push yourself out of your comfort zone in order to learn and grow. In my personal life, I enjoy trying new foods and exploring new places, and in my professional life, I'm always looking for new challenges and opportunities to learn. While I do recognize that taking risks can be scary, I believe that it's important to be open to new opportunities in order to grow and learn."
#  "I tend to be somewhat cautious, but I do seek out new experiences and take risks when I feel that the potential benefits outweigh the potential risks. In my personal life, I enjoy trying new activities and exploring new places, and in my professional life, I'm always looking for new opportunities to learn and grow. While I do consider the potential risks before making any big decisions, I also recognize the importance of challenging yourself and trying new things in order to learn and grow."
#  "I'm naturally inclined to seek out new experiences and take risks, but I also make sure to consider the potential risks and benefits before making any big decisions. In my personal life, I enjoy trying new hobbies and exploring new places, and in my professional life, I'm always looking for new challenges and opportunities to learn. While I do recognize the importance of taking risks, I also believe that it's important to be strategic and thoughtful about the risks that you take."
#  "I try to seek out new experiences and take risks on a regular basis, but I also recognize the importance of being thoughtful and strategic about the risks that I take. In my personal life, I enjoy trying new foods and exploring new places, and in my professional life, I'm always looking for new opportunities to learn and grow. While I do take calculated risks, I also make sure to weigh the potential benefits and drawbacks before making any big decisions."
#  "I believe that taking risks is an important part of personal and professional growth, and I try to seek out new experiences and take risks whenever possible. In my personal life, I enjoy trying new activities and exploring new places, and in my professional life, I'm always looking for new challenges and opportunities to learn. While I recognize that taking risks can be scary, I believe that it's important to push yourself out of your comfort zone in order to learn and grow."
#  "I enjoy exploring new ideas and trying new things, and I believe that taking risks is an important part of that process. In my personal life, I enjoy trying new hobbies and exploring new places, and in my professional life, I'm always looking for new challenges and opportunities to learn. While I do weigh the potential risks before making any big decisions, I also recognize that taking risks can lead to great rewards and can be an important part of personal and professional growth. I believe that it's important to be thoughtful and strategic about the risks that you take, but also to be open to new opportunities and experiences."
#  "I make it a priority to seek out new experiences and take risks on a regular basis. In my personal life, I enjoy trying new things and exploring new places, and in my professional life, I'm always looking for new challenges and opportunities to learn. I believe that taking calculated risks is an important part of personal and professional growth and I'm always willing to step out of my comfort zone in order to achieve my goals."
#  "I try to strike a balance between seeking out new experiences and taking calculated risks, while also being mindful of potential risks and drawbacks. In my personal life, I enjoy trying new hobbies and exploring new places, and in my professional life, I'm always looking for new opportunities to learn and grow. While I believe that taking risks is important for personal and professional growth, I also think it's important to weigh the potential risks and benefits before making any big decisions."
#  "I am always seeking out new experiences and taking risks. I believe that pushing myself out of my comfort zone is the best way to learn and grow, both personally and professionally. In my personal life, I enjoy trying new things and exploring new places, and in my professional life, I'm always looking for new opportunities to learn and develop new skills. While I do recognize that taking risks can be scary, I find that the rewards are often worth it. For example, in my previous job, I took on a new project that was outside of my comfort zone and involved a lot of new skills I had to learn. It was challenging, but I ended up succeeding and it was a great opportunity for growth."
#  "I try to balance seeking out new experiences and taking risks with being thoughtful and strategic about the risks I take. In my personal life, I enjoy trying new foods and traveling to new places, and in my professional life, I'm always looking for new challenges and opportunities to learn. While I believe that taking risks is important for growth, I also think it's important to consider the potential benefits and drawbacks before making any big decisions. For example, I once considered taking on a new project that involved a lot of risk, but after weighing the pros and cons, I decided it wasn't the best fit for me at the time."
#  "I make it a point to seek out new experiences and take risks on a regular basis. In my personal life, I enjoy trying new hobbies and exploring new places, and in my professional life, I'm always looking for new challenges and opportunities to learn. I believe that taking calculated risks is an important part of personal and professional growth, and I'm always willing to step out of my comfort zone in order to achieve my goals. For example, in my previous job, I pitched a new project idea that was a bit outside of the norm for our team. It was a risk, but it ended up being a big success and helped me to gain new skills and recognition."
#  "I enjoy exploring new ideas and trying new things, and I believe that taking risks is an important part of that process. In my personal life, I enjoy trying new hobbies and traveling to new places, and in my professional life, I'm always looking for new challenges and opportunities to learn. While I do weigh the potential risks before making any big decisions, I also believe that it's important to be open to new opportunities and experiences. For example, I recently took a risk by switching to a completely different industry. It was a big change, but it's been a great opportunity for growth and I've been able to bring new perspectives and ideas to my new team."
#  "I believe that seeking out new experiences and taking risks is an important part of personal and professional growth, and I try to do so on a regular basis. In my personal life, I enjoy trying new foods and exploring new places, and in my professional life, I'm always looking for new opportunities to learn and develop new skills. While I do recognize the potential risks involved in taking risks, I find that the rewards are often worth it. For example, I once took a risk by speaking up about an issue in my workplace that was causing some problems. It was a difficult conversation to have, but it ended up leading to positive changes in the workplace culture."
#  "I am constantly seeking out new experiences and taking risks, both personally and professionally. I believe that it's important to push yourself out of your comfort zone in order to learn and grow, and I'm always looking for new challenges and opportunities to do so. While I do consider the potential risks before making any big decisions, I believe that taking risks is an important part of personal and professional development."
#  "I make it a point to seek out new experiences and take risks regularly, as I believe that this is crucial for personal and professional growth. In my personal life, I love trying new things and exploring new places, and in my professional life, I'm always looking for new challenges and opportunities to learn. While I do consider the potential risks involved before making any big decisions, I'm not afraid to take calculated risks to achieve my goals. For example, I once took on a new project that involved a lot of risk, but it ended up being a huge success and helped me to develop new skills."
#  "I believe that taking risks is an essential part of personal and professional growth, and I try to do so on a regular basis. In my personal life, I enjoy trying new activities and traveling to new places, and in my professional life, I'm always looking for new opportunities to learn and develop new skills. While I do weigh the potential risks involved, I'm not afraid to take chances when I believe the potential benefits outweigh the risks. For instance, I recently took on a new project that was a bit outside of my area of expertise, but it ended up being a great opportunity for growth."
#  "I'm always seeking out new experiences and taking risks, as I believe that this is crucial for personal and professional growth. In my personal life, I enjoy trying new foods and exploring new places, and in my professional life, I'm always looking for new challenges and opportunities to learn. While I do consider the potential risks involved before making any big decisions, I believe that taking calculated risks is necessary to achieve success. For example, I once took a risk by taking on a new project that was outside of my comfort zone, but it ended up being a great opportunity for growth and development."
#  "I believe that seeking out new experiences and taking risks is an important part of personal and professional growth, and I try to do so on a regular basis. In my personal life, I enjoy trying new things and exploring new places, and in my professional life, I'm always looking for new challenges and opportunities to learn. While I do consider the potential risks involved before making any big decisions, I'm not afraid to take chances when I believe the potential benefits are worth it. For example, I recently took a risk by speaking up about a problem in my workplace that was causing issues, but it ended up leading to positive changes and improvements."
#  "I try to seek out new experiences and take risks regularly, as I believe that this is crucial for personal and professional growth. In my personal life, I enjoy trying new hobbies and exploring new places, and in my professional life, I'm always looking for new challenges and opportunities to learn. While I do consider the potential risks involved before making any big decisions, I believe that taking calculated risks is necessary to achieve success. For instance, I recently took on a new project that was outside of my comfort zone, but it ended up being a great opportunity for growth and development."
#  "I believe that seeking out new experiences and taking risks is an essential part of personal and professional growth, and I try to do so on a regular basis. In my personal life, I enjoy trying new activities and exploring new places, and in my professional life, I'm always looking for new challenges and opportunities to learn. While I do weigh the potential risks involved before making any big decisions, I'm not afraid to take calculated risks when I believe they are necessary to achieve my goals. For example, I once took on a new project that was a bit outside of my area of expertise,"
#  "I'm always looking for new experiences and opportunities to challenge myself, as I believe that this is essential for personal and professional growth. In my personal life, I enjoy trying new things and exploring new places, and in my professional life, I'm always looking for new projects and initiatives that will push me outside of my comfort zone. While I do consider the potential risks involved before making any big decisions, I'm not afraid to take calculated risks when I believe they are necessary to achieve my goals. For example, I once took a risk by proposing a new marketing strategy for a client, and it ended up being very successful."
#  "I'm a firm believer in seeking out new experiences and taking risks, as I think this is key to personal and professional growth. In my personal life, I love trying new activities and exploring new places, and in my professional life, I'm always looking for new challenges and opportunities to learn. While I do weigh the potential risks involved before making any big decisions, I'm not afraid to take chances when I believe the potential benefits outweigh the risks. For example, I recently took on a new project that was a bit outside of my area of expertise, but it ended up being a great opportunity for growth."
#  "I'm constantly seeking out new experiences and taking risks, as I believe that this is crucial for personal and professional development. In my personal life, I enjoy trying new things and traveling to new places, and in my professional life, I'm always looking for new opportunities to learn and grow. While I do consider the potential risks involved before making any big decisions, I'm not afraid to take calculated risks when I believe they are necessary to achieve success. For instance, I once took a risk by leading a new project, and it ended up being a great success."
#  "I make it a priority to seek out new experiences and take risks on a regular basis, as I believe that this is essential for personal and professional growth. In my personal life, I love trying new things and exploring new places, and in my professional life, I'm always looking for new challenges and opportunities to learn. While I do consider the potential risks involved before making any big decisions, I'm not afraid to take calculated risks when I believe they are necessary to achieve my goals. For example, I once took a risk by proposing a new approach to a problem, and it ended up being very successful."
#  "I believe that seeking out new experiences and taking risks is an important part of personal and professional growth, and I try to do so on a regular basis. In my personal life, I enjoy trying new hobbies and exploring new places, and in my professional life, I'm always looking for new challenges and opportunities to learn. While I do consider the potential risks involved before making any big decisions, I'm not afraid to take chances when I believe the potential benefits outweigh the risks. For instance, I once took on a new project that was a bit outside of my area of expertise, but it ended up being a great learning experience."
#  "I'm always seeking out new experiences and taking risks, as I believe that this is necessary for personal and professional growth. In my personal life, I love trying new things and exploring new places, and in my professional life, I'm always looking for new challenges and opportunities to learn. While I do consider the potential risks involved before making any big decisions, I'm not afraid to take calculated risks when I believe they are necessary to achieve my goals. For example, I once took a risk by proposing a new product strategy, and it ended up being very successful."
#  "I believe that seeking out new experiences and taking risks is essential for personal and professional growth, and I make it a priority to do so regularly. In my personal life, I enjoy trying new things and exploring new places, and in my professional life, I'm always looking for new challenges and opportunities to learn. While I do consider the potential risks involved before making any big decisions, I'm not afraid to take calculated risks when I believe they are necessary to achieve my goals. For example, I once took a risk by proposing a new project plan that involved a new technology, and it ended up being very successful."
#  "I consider seeking out new experiences and taking risks to be one of the most important aspects of personal and professional growth. In my personal life, I enjoy trying new activities and exploring new places, and in my professional life, I'm always looking for new challenges and opportunities to learn. While I do consider the potential risks involved before making any big decisions, I'm not afraid to take calculated risks when I believe they are necessary to achieve success. For instance, I once took on a new client with a challenging project, and it ended up being a great opportunity to expand my skills and knowledge."
#  'I have always been someone who enjoys trying new things and taking on new challenges. In my personal life, I love to travel and explore new cultures, and in my professional life, I am always looking for new ways to improve processes or take on projects that are outside of my comfort zone. I believe that seeking out new experiences is essential for personal and professional growth. By trying new things, we can expand our knowledge, skills, and perspectives, which can ultimately help us be more successful in our careers and lives.'
#  'I believe that taking risks is necessary for growth and innovation. While I do weigh the potential risks and benefits of any decision, I am not afraid to take calculated risks when I believe they will lead to positive outcomes. For example, I once proposed a new marketing strategy that involved targeting a niche audience, and it ended up being a big success. I think that taking risks requires confidence and a willingness to learn from failure. By taking calculated risks, we can push ourselves out of our comfort zones and achieve great things.'
#  "I think it's important to balance taking risks with being responsible and considering potential consequences. In my personal life, I enjoy trying new activities and experiences, but I always make sure to do so in a safe and responsible way. In my professional life, I am always looking for opportunities to innovate and try new things, but I always make sure to carefully evaluate the potential risks and benefits. I think that being responsible and strategic in our risk-taking can help us achieve success while minimizing negative consequences."
#  "I am someone who is always looking to learn and grow, both personally and professionally. I think that seeking out new experiences and taking risks is essential for this kind of growth. For example, I once took on a leadership role in a new project, even though I was nervous about the added responsibility. It ended up being a great learning experience for me, as I was able to develop my leadership skills and gain a better understanding of the project's objectives."
#  "I think that taking risks can be scary, but it's also necessary for growth and success. In my personal life, I enjoy trying new things and exploring new places, and in my professional life, I am always looking for new challenges and opportunities to learn. For example, I once volunteered to lead a cross-functional team on a challenging project, and it ended up being a great opportunity to develop my leadership skills and build strong relationships with my colleagues. I think that by taking risks, we can gain valuable experiences and skills that can help us achieve our goals."
#  "I am someone who thrives on challenge and new experiences. I think that taking calculated risks is necessary to achieve success, both personally and professionally. For example, I once took a job in a new industry that I wasn't familiar with, but I was excited about the challenge of learning and growing in a new field. While it was a bit daunting at first, I quickly learned the ropes and was able to make significant contributions to the organization. I think that by taking calculated risks, we can expand our horizons and achieve great things."
#  'I think that seeking out new experiences and taking risks is essential for personal and professional growth. In my personal life, I enjoy trying new activities and exploring new places, and in my professional life, I am always looking for new challenges and opportunities to learn. For example, I once took on a project that was outside of my usual area of expertise, and it ended up being a great learning experience for me. By taking on new challenges, we can broaden our skill sets and gain a better understanding of our strengths and weaknesses.'
#  "I believe that taking risks is necessary for growth and success, but it's also important to be strategic about it. When I encounter a new opportunity, I evaluate the potential risks and benefits and weigh them carefully before making a decision. For example, when I was presented with the opportunity to lead a project that was outside of my usual area of expertise, I considered the potential challenges and risks involved, but ultimately decided to take it on. It ended up being a great learning experience, and I was able to develop new skills and make a significant contribution to the project's success. I think that by being strategic in our risk-taking, we can achieve great things while minimizing negative consequences."
#  "I always strive to push myself out of my comfort zone and try new things. I think that in order to grow and learn, it's important to challenge ourselves and explore new opportunities. For example, last year I took a solo trip to a foreign country where I didn't speak the language. It was a bit daunting at first, but I ended up having an amazing experience and learning a lot about myself in the process. I think that seeking out new experiences is key to personal and professional growth."
#  "I believe that taking risks and seeking out new experiences is essential in both personal and professional life. It helps us to develop new skills, gain new perspectives, and stay engaged and motivated. For instance, when I was presented with an opportunity to work on a high-pressure project with tight deadlines, I didn't hesitate to take it on, even though I knew it would be challenging. Through hard work and dedication, I was able to successfully complete the project, and it gave me a real sense of accomplishment. I believe that taking calculated risks can lead to great rewards, both personally and professionally."]
# Concientiousness ["I prioritize my work according to deadlines and level of importance. I create a detailed schedule that outlines each task and the amount of time it will take to complete. I also build in extra time for reviewing my work and making any necessary edits or changes. Throughout the process, I keep an open line of communication with my team and stakeholders to ensure that we're all on the same page and that our work is meeting everyone's expectations. I am always focused on meeting or exceeding the deadlines that have been set for me."
#  "I believe that accuracy and attention to detail are critical components of any successful project or task. To ensure that my work is accurate, I break down my tasks into manageable steps and establish checkpoints along the way to verify that I'm on track. I use tools like spell-check and grammar-check to minimize any errors. I also rely on my team members and supervisors to provide feedback and constructive criticism, so I can improve my work as needed. Additionally, I stay up-to-date on industry best practices and take any training that is offered to help me improve my skills and stay on top of the latest trends."
#  "I manage my time effectively by planning ahead and anticipating any potential roadblocks that may arise. I have a detailed process that I follow to ensure that my work is accurate and completed on time. This process includes setting goals, breaking down tasks, establishing checkpoints, and creating a timeline. I also prioritize my tasks based on their level of importance, so that I'm always focused on the most critical work. I use project management tools like Asana and Trello to help me stay organized and on track. I believe that good communication is key to completing work accurately and on time, so I always make sure to stay in touch with my team, clients, and other stakeholders throughout the project."
#  'To ensure that my work is accurate and completed on time, I follow a strict quality control process. This includes double-checking my calculations and proofreading my documents multiple times. I use a checklist to ensure that I have covered all the necessary points and that my work meets the required standards. I also seek out feedback from colleagues and supervisors to identify areas for improvement. When it comes to time management, I prioritize my tasks based on their level of importance and urgency. I also create a detailed schedule that includes time for reviewing my work and making any necessary edits or changes.'
#  "I believe that setting realistic goals is the key to completing work accurately and on time. To ensure that my work is accurate, I break down my tasks into manageable steps and take the time to review my work at each stage of the process. I use tools like Grammarly and Hemingway Editor to help me catch any errors or typos. I also stay up-to-date on the latest technologies and tools that can help me complete my work more efficiently. When it comes to time management, I prioritize my tasks based on their level of importance and the amount of time they will take to complete. I also build in extra time for any unforeseen issues that may arise. Finally, I communicate regularly with my team and stakeholders to ensure that everyone is on the same page and that our work is meeting everyone's expectations."
#  "Accuracy and timeliness are essential for any project or task. To ensure that my work is accurate, I pay attention to the details and review my work several times before submitting it. I also leverage available resources like style guides, templates, and checklists to ensure that I'm following the best practices. I prioritize my work by breaking it down into smaller, manageable tasks, and creating a schedule that considers deadlines and the required level of effort. Finally, I maintain open communication with my team and stakeholders to ensure that we are all aligned and that any issues are addressed promptly."
#  "To ensure that my work is accurate and on time, I follow a systematic approach. I start by breaking down the project into smaller, manageable tasks, and then prioritize them based on the level of importance and urgency. I use a project management tool to help me track my progress and to ensure that I'm staying on schedule. I build in extra time for reviewing my work and making any necessary revisions. I also seek feedback from my colleagues and supervisor to identify areas for improvement and to make sure that my work meets the required standards."
#  "I ensure that my work is accurate and on time by being organized and proactive. I plan my work ahead of time and establish clear objectives and timelines. I also communicate with my team and stakeholders to ensure that we're all aligned and that our work is meeting everyone's expectations. I check my work multiple times to ensure that it's error-free and meets the required standards. I'm always looking for ways to improve my skills and knowledge to keep up with the latest trends and best practices."
#  "Accuracy and timeliness are crucial in any project or task. To ensure that my work is accurate, I use resources like style guides, templates, and checklists to help me follow the best practices. I also pay close attention to the details and review my work several times before submitting it. When it comes to time management, I prioritize my tasks by breaking them down into smaller, manageable tasks, and creating a schedule that considers deadlines and the required level of effort. I build in extra time for reviewing my work and making any necessary revisions. Finally, I maintain open communication with my team and stakeholders to ensure that everyone is on the same page and that our work is meeting everyone's expectations."
#  "I'm a perfectionist at heart, and I take pride in ensuring that my work is completed accurately and on time. I use a systematic approach to ensure that my work meets the required standards. This approach includes breaking down the project into smaller, manageable tasks, establishing clear objectives, and creating a schedule that considers deadlines and the required level of effort. I check my work multiple times to ensure that it's error-free and meets the required standards. I also seek feedback from my colleagues and supervisor to identify areas for improvement and to make sure that my work meets the required standards. Finally, I maintain open communication with my team and stakeholders to ensure that we're all aligned and that our work is meeting everyone's expectations."
#  'To ensure that my work is completed accurately and on time, I start by setting clear goals and objectives for the project or task. I also break down the work into smaller, manageable tasks and establish timelines for each task. I use tools like project management software and calendars to keep track of my progress and deadlines. I regularly communicate with my team members and stakeholders to make sure everyone is on the same page and that our work is meeting expectations. Finally, I always leave some buffer time for unexpected issues or revisions.'
#  "Accuracy and timeliness are critical to success in any job. To ensure that my work is completed accurately, I carefully review my work multiple times and seek feedback from others. To ensure that I meet my deadlines, I create a detailed plan that includes all of the necessary steps to complete the work on time. I also prioritize my work based on the level of importance and urgency. I'm always looking for ways to improve my efficiency and effectiveness, whether through better time management, more effective communication, or adopting new tools and techniques."
#  'I ensure that my work is completed accurately and on time by focusing on quality and planning. I take the time to thoroughly understand the requirements and scope of the project, and I establish clear goals and timelines. I also break down the work into smaller, more manageable tasks and establish deadlines for each task. Throughout the process, I regularly check my work for accuracy and quality, and I seek feedback from my team members and stakeholders to ensure that our work is meeting expectations.'
#  "To ensure that my work is completed accurately and on time, I prioritize my work by creating a task list and breaking down larger projects into smaller, manageable tasks with deadlines. I start by identifying the most critical tasks and working on those first. I also keep a calendar to stay on top of deadlines and ensure that I don't miss anything important. By breaking down the work into smaller tasks and setting deadlines, I can stay on track and avoid procrastination."
#  'Communication is key to completing work accurately and on time. I regularly check in with my team members and supervisor to ensure that everyone is on the same page and that there are no misunderstandings about expectations or timelines. I am always willing to ask questions and seek clarification if I am unsure about something. By keeping an open line of communication, we can work together more efficiently and effectively.'
#  'I always double-check my work to ensure that it is accurate. I know that even small mistakes can have significant consequences, so I take the time to review my work carefully. If I am unsure about something or need clarification, I am not afraid to ask. By taking a proactive approach to accuracy, I can catch errors before they become bigger issues.'
#  'Project management tools like Trello or Asana are incredibly useful for keeping track of my work and ensuring that I am staying on schedule. I use these tools to track my progress, set deadlines, and keep important information in one place. By using project management tools, I can be more efficient and organized, which helps me complete work accurately and on time.'
#  'When completing work, I am always looking ahead to identify potential roadblocks or delays. If I see a potential issue, I work to address it as quickly as possible to avoid it becoming a larger problem. By being proactive and taking a problem-solving approach, I can ensure that my work is completed accurately and on time.'
#  'To ensure that I can be flexible in my work and reprioritize tasks when needed, I always make sure to have a clear understanding of the project goals and requirements. By having a solid understanding of what needs to be accomplished, I can quickly adapt to changing circumstances and still ensure that the project is completed accurately and on time. Additionally, I have found that being transparent about my workload with my supervisor and team members is helpful in staying on top of changing priorities. By keeping everyone informed, we can work together to ensure that the most important work is completed first.'
#  'To ensure that I am accurately estimating the time required for each task, I have found that breaking down larger projects into smaller tasks is helpful. By identifying each step required to complete the project, I can better estimate the time required for each task and avoid overcommitting myself. Additionally, I prioritize tasks based on their level of importance and urgency, ensuring that the most critical work is completed first. By being organized and efficient with my time, I can ensure that my work is completed accurately and on time.'
#  'I find that being organized and keeping detailed notes is essential to completing work accurately and on time. To achieve this, I use tools like Microsoft OneNote and Google Drive to keep all my notes and information organized in one place. This way, I can quickly access the information I need without wasting time searching for it. Additionally, I always take the time to review my work before submitting it, even if it means spending a few extra minutes on each task. By being thorough and detail-oriented, I can ensure that my work is of the highest quality.'
#  'I believe that taking pride in my work and having a strong sense of ownership over it is critical to completing work accurately and on time. To achieve this, I make sure to stay focused on the task at hand and not allow myself to be distracted by other things. I also take the time to understand the purpose and impact of the work I am doing, so I can see the value in completing it to the best of my ability. By being invested in my work, I can ensure that it is completed accurately and on time, and that it meets the highest standards of quality.'
#  'While I always strive to complete work accurately and on time during regular business hours, I understand that there may be occasions where additional time is required to ensure that the work is completed successfully. In these situations, I am willing to put in extra hours or work on weekends to meet my deadlines. However, I do not see this as a sustainable solution and believe that it is important to identify the root cause of any delays and work to address it as quickly as possible. By being dedicated to meeting my deadlines and working with my team members to address any roadblocks, I can ensure that my work is completed accurately and on time without sacrificing my work-life balance.'
#  'To ensure that my work is completed accurately and on time, I prioritize effective communication with my team members and stakeholders. I believe that clear communication is essential for avoiding misunderstandings and delays. This includes being proactive about sharing updates on my progress, asking for feedback on my work, and addressing any concerns that my team members or stakeholders may have. I also make sure to clarify any ambiguities or uncertainties, so everyone is on the same page. By keeping everyone informed and involved, I can ensure that the work is completed accurately and on time.'
#  'One way I ensure that my work is completed accurately and on time is by using project management software such as Asana or Trello. These tools help me to keep track of all the tasks associated with a project, assign them to team members, and set deadlines. I find that this approach ensures that nothing falls through the cracks, and everyone knows what they need to do to keep the project moving forward. In addition, I can easily monitor the progress of each task and identify any bottlenecks or issues that may arise. This allows me to proactively address them and keep the project on track.'
#  'I believe that taking breaks and practicing self-care are essential to completing work accurately and on time. When I am well-rested and in a positive state of mind, I can approach my work with greater focus and attention to detail. I find that regular exercise, healthy eating, and mindfulness practices such as meditation help me to maintain a healthy work-life balance. By prioritizing my well-being, I can ensure that I am at my best when completing my work.'
#  'To ensure that my work is completed accurately and on time, I actively seek out learning opportunities to improve my skills and knowledge. This includes attending training sessions, webinars, and conferences, as well as reading industry publications and staying up to date with the latest developments in my field. By continuously improving my abilities, I can work more efficiently and effectively. I also enjoy sharing my newfound knowledge with my team members and applying it to my work to produce better results.'
#  'I find that collaborating with others is key to completing work accurately and on time. By working closely with my colleagues and leveraging their expertise, I can identify potential issues early on and address them before they become significant roadblocks. I also believe in sharing credit with others when a project is successful, as this encourages teamwork and fosters a positive work environment. In addition, I find that brainstorming and discussing ideas with my team members helps me to identify creative solutions and achieve better outcomes.'
#  'To ensure that my work is completed accurately and on time, I set realistic deadlines for myself based on the complexity of the task at hand. I also build in some buffer time to account for unexpected delays or roadblocks. This helps me to avoid overcommitting myself and ensures that I can deliver high-quality work on time. I find that setting realistic deadlines also helps me to manage my time better and prioritize my tasks effectively.'
#  'I believe in the power of positive thinking and visualization to complete work accurately and on time. Before starting a project, I take a moment to visualize its successful completion and the positive impact it will have. This helps me to approach my work with enthusiasm and confidence, which in turn increases my productivity and helps me to meet my deadlines. I also find that maintaining a positive attitude helps me to overcome any obstacles that may arise during the project and keep working towards a successful outcome.'
#  'To ensure that my work is completed accurately and on time, I take a proactive approach to risk management. This includes identifying potential risks early on and developing contingency plans to address them. By being prepared for unexpected challenges, I can minimize the impact they have on the project timeline and deliverables. I also make sure to communicate any risks or issues to my team members and stakeholders, so everyone is aware of the situation and can work together to find solutions. I find that setting clear expectations and goals is essential to completing work accurately and on time. This includes defining the scope of the project, outlining specific deliverables, and establishing deadlines. By setting clear expectations upfront, I can avoid any misunderstandings or confusion later on. I also make sure to get buy-in from my team members and stakeholders, so everyone is aligned and committed to achieving the project goals. This approach helps me to stay focused and motivated and ensure that the work is completed accurately and on time.'
#  'To ensure that my work is completed accurately and on time, I make use of feedback and performance metrics. I regularly seek feedback from my team members and stakeholders to identify areas for improvement and ensure that I am meeting their expectations. I also set up performance metrics to track my progress and identify any deviations from the plan. This helps me to make any necessary adjustments to keep the project on track and ensure that the work is completed accurately and on time. By continuously monitoring my performance and seeking feedback, I can deliver high-quality work consistently.'
# ...
#  'I find that maintaining a healthy work-life balance is essential for managing stress. I make a point to prioritize my personal life and hobbies, which helps me stay refreshed and energized when faced with challenging situations at work. For example, I make time for hobbies like painting and hiking, which help me recharge and stay productive at work.'
#  'When faced with difficult situations, I try to keep a positive attitude and remain flexible. I remind myself that every problem is an opportunity for growth and development, and I try to approach challenges with a sense of curiosity and optimism. I also make a point to stay organized and prioritize my tasks, breaking down the problem into smaller, actionable steps. This helps me manage stress and stay focused on finding solutions.'
#  'I find that communication is key to managing stressful situations effectively. I make a point to stay in regular contact with my team or other stakeholders, sharing updates and seeking input and feedback. This helps me stay informed and make better decisions. I also try to maintain a sense of humor and keep things in perspective, which helps me stay calm and focused in challenging situations.'
#  "In my experience, taking a collaborative approach to problem-solving is highly effective. I try to work closely with my team or other stakeholders, leveraging everyone's strengths and expertise. By working together, we are better able to manage stress and find solutions to difficult problems. I also make a point to stay positive and supportive, encouraging others to share their ideas and opinions, which helps build trust and create a more productive work environment."
#  'When faced with a difficult situation, my approach is to stay calm and composed. I understand that stress can cloud judgment and lead to poor decision-making. So, I take a deep breath, pause for a moment, and then start analyzing the situation. I try to break it down into smaller, more manageable components and prioritize the most critical aspects. This helps me stay focused and develop a clear action plan.'
#  'I believe that one of the most effective ways to handle stressful situations is to prepare in advance. I try to anticipate potential problems and develop contingency plans. This helps me stay ahead of the curve and manage stress more effectively. In addition, I try to build strong relationships with my colleagues, which helps me stay informed and collaborate more effectively.'
#  'My approach to handling difficult situations is to stay positive and solution-focused. I remind myself that every problem has a solution and try to stay optimistic. In addition, I try to remain flexible and open to new ideas. This helps me stay adaptable and pivot when necessary.'
#  'I find that communication is key to handling stressful situations effectively. I make a point to stay in regular contact with my team or other stakeholders, sharing updates and seeking input and feedback. This helps me stay informed and make better decisions. In addition, I try to be transparent and honest about any challenges we are facing. This helps build trust and allows us to work together to find solutions.'
#  'When dealing with stressful situations, I try to prioritize self-care. I make sure to take breaks when necessary, get plenty of rest, and engage in stress-reducing activities like meditation or exercise. This helps me stay calm and focused when faced with challenging situations.'
#  'My approach to handling difficult situations is to gather as much information as possible. I try to analyze the problem, identify potential roadblocks, and come up with a clear action plan. I believe that taking a strategic approach helps me manage stress and develop effective solutions.'
#  'I find that taking a step back and assessing the situation before taking any action is highly effective. By doing this, I am better able to manage stress and develop a clear plan of action. In addition, I try to stay organized and focused, breaking down the problem into smaller, more manageable components.'
#  'I believe that staying positive and solution-focused is key to handling stressful situations effectively. I try to approach challenges with a sense of curiosity and optimism, which helps me stay motivated and energized. In addition, I try to learn from past experiences and use them as a guide to navigate difficult situations in the future.'
#  'When faced with difficult situations, I try to stay calm and composed. I understand that stress can impact my ability to think clearly and make rational decisions. So, I take a moment to collect my thoughts and then start analyzing the situation. By doing this, I am better able to manage stress and find effective solutions.'
#  'My approach to handling difficult situations is to stay focused on the task at hand. I try to remain organized and break down the problem into smaller, more manageable components. This helps me stay on track and make progress towards finding a solution. In addition, I try to seek input from others with different backgrounds and experiences, which helps me stay open-minded and develop innovative solutions to complex problems.'
#  'When faced with a difficult situation, I try to remain calm and level-headed. I remind myself of the bigger picture and focus on the task at hand, breaking it down into manageable steps. By staying organized and methodical, I am able to effectively manage my stress and come up with solutions to challenging problems."'
#  'I find that taking care of myself is key to managing stress in difficult situations. I make sure to get enough sleep, exercise regularly, and eat well. Additionally, I try to engage in activities that help me relax, such as reading or spending time with loved ones. This helps me maintain a healthy balance and remain centered when faced with stressful situations.'
#  'When dealing with difficult situations, I try to approach them with a positive mindset. I remind myself that challenges are opportunities for growth and try to stay optimistic. Additionally, I seek support from my team and colleagues, who can provide a fresh perspective and help me find solutions.'
#  'I find that preparation is key to handling difficult situations. I make sure to gather all the necessary information and resources before making any decisions. Additionally, I try to anticipate potential problems and develop contingency plans. This helps me stay ahead of the curve and manage stress more effectively.'
#  'When dealing with stressful situations, I try to take a step back and assess the situation objectively. I try to view it from different angles and seek input from others with different perspectives. This helps me gain a deeper understanding of the issue at hand and develop effective solutions.'
#  'I find that staying organized and prioritizing tasks is crucial for managing stress in difficult situations. By breaking down complex problems into smaller, manageable tasks, I am able to stay focused and on track. Additionally, I try to delegate tasks to others when possible, which helps me maintain a healthy work-life balance.'
#  'When faced with difficult situations, I try to maintain open and honest communication with my team and colleagues. This includes sharing updates and seeking feedback, as well as providing support and encouragement. This helps me stay informed and make better decisions.'
#  'I find that taking a proactive approach is effective in managing stress. Rather than waiting for problems to arise, I try to identify potential issues early on and develop strategies to prevent them. This helps me stay in control and manage stress more effectively.'
#  'When dealing with difficult situations, I try to remain flexible and adaptable. I recognize that things may not always go according to plan, and I am prepared to adjust my approach as needed. Additionally, I seek out creative solutions and consider multiple perspectives, which helps me find innovative solutions to complex problems.'
#  'I find that maintaining a positive attitude and a sense of humor is helpful in managing stress in difficult situations. By staying optimistic and finding ways to laugh, even in tough situations, I am better able to stay grounded and maintain a healthy perspective.'
#  'When faced with stressful and difficult situations, my first approach is to remain calm and composed. I take a moment to breathe and gather my thoughts before taking any action. I also prioritize the tasks at hand and break them down into smaller, more manageable steps to avoid feeling overwhelmed. I believe that by breaking down complex problems into smaller, more achievable tasks, I can maintain my focus and motivation. In addition, I seek advice from my colleagues or mentors to gain different perspectives and ideas. I am a firm believer that two heads are better than one and that the collective wisdom of a group can help identify the best course of action.'
#  'I believe in the power of positive thinking, even in challenging situations. I try to focus on the potential solutions rather than the problems and stay motivated to find the best outcome. I believe that a positive attitude can be contagious and can help lift the mood of those around me. I also try to approach problems with a growth mindset, recognizing that every challenge presents an opportunity for learning and growth. To stay motivated and focused, I regularly set short-term goals and celebrate my progress along the way.'
#  'To handle stressful situations, I try to maintain a healthy work-life balance, including exercise and mindfulness practices. I believe that taking care of my physical and mental health helps me stay resilient and productive in the face of difficult challenges. In addition to exercise and mindfulness, I also make sure to get enough sleep and take breaks throughout the day. I find that these practices help me stay energized and focused, even when working on demanding projects.'
#  'In difficult situations, I like to stay organized and focused. I prioritize tasks and delegate responsibilities where appropriate. I also use a variety of problem-solving techniques, such as brainstorming, SWOT analysis, and decision-making frameworks, to find the best solutions. To ensure that everyone on the team is on the same page, I also make sure to communicate clearly and regularly with my colleagues and stakeholders. By staying organized and focused, I am able to manage my workload effectively and deliver high-quality results.'
#  'My approach to handling stress is to stay proactive and avoid procrastination. I set clear goals and timelines for myself and regularly review my progress. I also stay open to feedback and criticism and use it to improve my work. By staying proactive and taking ownership of my projects, I am able to anticipate potential challenges and address them before they become major issues. I also believe that feedback and criticism are valuable opportunities for learning and growth and welcome them as part of the creative process.'
#  'To manage stress, I like to communicate effectively with my team members and stakeholders. I believe clear and transparent communication helps build trust and fosters collaboration. I also use active listening skills to understand different perspectives and opinions. By creating an open and collaborative environment, I am able to work more effectively with my colleagues and stakeholders and build strong, positive relationships.'
#  'When faced with a difficult situation, I take a step back and assess the situation objectively. I consider the risks and benefits of different options before making a decision. I also try to learn from the experience and use it to improve my problem-solving skills. By taking a thoughtful and deliberate approach, I am able to make well-informed decisions that are grounded in data and analysis. I also see every challenge as an opportunity to learn and grow and use my experiences to become a better problem solver.'
#  'When faced with stressful and difficult situations, I make sure to maintain a positive attitude and a sense of humor. I believe that laughter and positivity can help lighten the mood and reduce tension. I also try to approach problems with a creative mindset, looking for unique and innovative solutions. By staying optimistic and open-minded, I am able to overcome challenges and find new opportunities for growth and development.'
#  'To handle stressful situations, I make sure to take breaks and recharge my batteries. I know that pushing myself too hard can lead to burnout and decreased productivity, so I make sure to take time for myself when I need it. I also try to maintain a healthy work-life balance and engage in activities outside of work that bring me joy and fulfillment. By taking care of myself both physically and mentally, I am able to approach challenges with renewed energy and focus.'
#  'My approach to handling stressful and difficult situations involves collaborating with others and seeking input from a diverse range of perspectives. I believe that every team member brings unique skills and experiences to the table, and by working together, we can find the best solutions to complex problems. I also value open and honest communication and encourage my team to speak up and share their ideas and opinions. By fostering a culture of collaboration and communication, I am able to overcome challenges and achieve our goals as a team.'
#  'When I face a stressful situation, I take a step back to analyze the situation objectively. I try to identify the root cause of the problem and think of the best ways to solve it. I also evaluate the possible consequences of my actions before taking any decisions. By taking a rational approach, I can make well-informed decisions that address the issue at hand and prevent future problems.'
#  'To handle stressful situations, I prioritize self-care and stress-management practices. I make sure to exercise regularly, eat healthy, and practice mindfulness and meditation. I also take frequent breaks throughout the day to recharge my batteries and maintain my focus. By taking care of myself both physically and mentally, I am able to approach challenges with a clear and calm mind.'
#  'When faced with a difficult situation, I like to gather information and data to make informed decisions. I conduct research, consult with experts, and review past experiences to identify the best course of action. I also seek feedback and input from my team members to gain diverse perspectives and ensure that we are aligned towards a common goal. By making data-driven decisions, I can minimize risks and increase the chances of success.'
#  "In stressful situations, I try to stay adaptable and flexible. I know that sometimes things don't go as planned, and being able to pivot and adapt is crucial. I am willing to take on new challenges and adjust my plans as needed. I also encourage my team members to be open-minded and embrace change. By staying adaptable and flexible, we can respond to challenges more effectively and take advantage of new opportunities."
#  'My approach to handling difficult situations is to remain optimistic and focused on finding solutions. I believe that a positive attitude can help motivate and inspire others. I also try to stay organized and manage my time effectively to avoid feeling overwhelmed. I break down tasks into smaller steps and celebrate each milestone to stay motivated. By staying optimistic and organized, I can tackle challenges with confidence and determination.']

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ##I. Text Cleaning

# %%
# Preprocess the text data
responses_df = responses_df.applymap(lambda x: x.lower() if isinstance(x, str) else x) # convert to lowercase
responses_df = responses_df.replace(to_replace=r'[^\w\s]', value='', regex=True) # remove non-word and non-whitespace characters
responses_df = responses_df.replace(to_replace=r'\d', value='', regex=True) # remove digits

# %% [markdown]
# ##II. Tokenization

# %%
# Tokenize the text data
responses_df['Openness'] = responses_df['Openness'].apply(word_tokenize)
responses_df['Concientiousness'] = responses_df['Concientiousness'].apply(word_tokenize)
responses_df['Extraversion'] = responses_df['Extraversion'].apply(word_tokenize)
responses_df['Agreeableness'] = responses_df['Agreeableness'].apply(word_tokenize)
responses_df['Neuroticism'] = responses_df['Neuroticism'].apply(word_tokenize)

# %% [markdown]
# ##III. Stopword Removal

# %%
# Remove stop words
stop_words = set(stopwords.words('english'))

responses_df['Openness'] = responses_df['Openness'].apply(lambda x: [word for word in x if word not in stop_words])
responses_df['Concientiousness'] = responses_df['Concientiousness'].apply(lambda x: [word for word in x if word not in stop_words])
responses_df['Extraversion'] = responses_df['Extraversion'].apply(lambda x: [word for word in x if word not in stop_words])
responses_df['Agreeableness'] = responses_df['Agreeableness'].apply(lambda x: [word for word in x if word not in stop_words])
responses_df['Neuroticism'] = responses_df['Neuroticism'].apply(lambda x: [word for word in x if word not in stop_words])

# %%
responses_df['Openness'].head(2)
# Out:
# 0    [strongly, believe, seeking, new, experiences,...
# 1    [someone, thrives, novelty, excitement, make, ...
# Name: Openness, dtype: object

# %% [markdown]
# ##IV. Lemmatization

# %%
# why lematization and not stemming?

# Lemmatization aims to convert words to their base or dictionary form which would be a meaningful word.
# Stemming, on the other hand, is a simpler and more rule-based approach whcih converts the word into a word stem or root form which may not always be a valid word in the language. 
# Since we need to to meaningful keywords we will be using Lemmatization.

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
import pandas as pd

# initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# define function to lemmatize tokens
def lemmatize_tokens(tokens):
    # convert POS tag to WordNet format
    def get_wordnet_pos(word):
        tag = nltk.pos_tag([word])[0][1][0].upper()
        tag_dict = {"J": wordnet.ADJ,
                    "N": wordnet.NOUN,
                    "V": wordnet.VERB,
                    "R": wordnet.ADV}
        return tag_dict.get(tag, wordnet.NOUN)
    
    # lemmatize tokens
    lemmas = [lemmatizer.lemmatize(token, get_wordnet_pos(token)) for token in tokens]
    
    # return lemmatized tokens as a list
    return lemmas

# apply lemmatization function to column of dataframe
responses_df['Openness_lemmatized'] = responses_df['Openness'].apply(lemmatize_tokens)

# %%
responses_df['Openness_lemmatized']
# Out:
# 0     [strongly, believe, seek, new, experience, tak...
# 1     [someone, thrives, novelty, excitement, make, ...
# 2     [naturally, inclined, seek, new, experience, t...
# 3     [personal, professional, growth, two, top, pri...
# 4     [natural, risktaker, recognize, value, seek, n...
# 5     [someone, enjoys, take, risk, seek, new, exper...
# 6     [seek, new, experience, take, risk, powerful, ...
# 7     [explore, new, idea, try, new, thing, one, gre...
# 8     [seek, new, challenge, experience, key, part, ...
# 9     [seek, new, experience, take, risk, essential,...
# 10    [constantly, seek, new, experience, take, risk...
# 11    [make, point, seek, new, experience, take, cal...
# 12    [try, seek, new, experience, take, risk, whene...
# 13    [tend, somewhat, cautious, seek, new, experien...
# 14    [im, naturally, inclined, seek, new, experienc...
# 15    [try, seek, new, experience, take, risk, regul...
# 16    [believe, take, risk, important, part, persona...
# 17    [enjoy, explore, new, idea, try, new, thing, b...
# 18    [make, priority, seek, new, experience, take, ...
# 19    [try, strike, balance, seek, new, experience, ...
# 20    [always, seek, new, experience, take, risk, be...
# 21    [try, balance, seek, new, experience, take, ri...
# 22    [make, point, seek, new, experience, take, ris...
# 23    [enjoy, explore, new, idea, try, new, thing, b...
# 24    [believe, seek, new, experience, take, risk, i...
# 25    [constantly, seek, new, experience, take, risk...
# 26    [make, point, seek, new, experience, take, ris...
# 27    [believe, take, risk, essential, part, persona...
# 28    [im, always, seek, new, experience, take, risk...
# 29    [believe, seek, new, experience, take, risk, i...
# 30    [try, seek, new, experience, take, risk, regul...
# 31    [believe, seek, new, experience, take, risk, e...
# 32    [im, always, look, new, experience, opportunit...
# 33    [im, firm, believer, seek, new, experience, ta...
# 34    [im, constantly, seek, new, experience, take, ...
# 35    [make, priority, seek, new, experience, take, ...
# 36    [believe, seek, new, experience, take, risk, i...
# 37    [im, always, seek, new, experience, take, risk...
# 38    [believe, seek, new, experience, take, risk, e...
# 39    [consider, seek, new, experience, take, risk, ...
# 40    [always, someone, enjoys, try, new, thing, tak...
# 41    [believe, take, risk, necessary, growth, innov...
# 42    [think, important, balance, take, risk, respon...
# 43    [someone, always, look, learn, grow, personall...
# 44    [think, take, risk, scary, also, necessary, gr...
# 45    [someone, thrives, challenge, new, experience,...
# 46    [think, seek, new, experience, take, risk, ess...
# 47    [believe, take, risk, necessary, growth, succe...
# 48    [always, strive, push, comfort, zone, try, new...
# 49    [believe, take, risk, seek, new, experience, e...
# Name: Openness_lemmatized, dtype: object

# %%
# initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# define function to lemmatize tokens
def lemmatize_tokens(tokens):
    # convert POS tag to WordNet format
    def get_wordnet_pos(word):
        tag = nltk.pos_tag([word])[0][1][0].upper()
        tag_dict = {"J": wordnet.ADJ,
                    "N": wordnet.NOUN,
                    "V": wordnet.VERB,
                    "R": wordnet.ADV}
        return tag_dict.get(tag, wordnet.NOUN)
    
    # lemmatize tokens
    lemmas = [lemmatizer.lemmatize(token, get_wordnet_pos(token)) for token in tokens]
    
    # return lemmatized tokens as a list
    return lemmas

# apply lemmatization function to column of dataframe
responses_df['Concientiousness_lemmatized'] = responses_df['Concientiousness'].apply(lemmatize_tokens)

# %%
responses_df['Concientiousness_lemmatized']
# Out:
# 0     [prioritize, work, accord, deadline, level, im...
# 1     [believe, accuracy, attention, detail, critica...
# 2     [manage, time, effectively, planning, ahead, a...
# 3     [ensure, work, accurate, complete, time, follo...
# 4     [believe, set, realistic, goal, key, complete,...
# 5     [accuracy, timeliness, essential, project, tas...
# 6     [ensure, work, accurate, time, follow, systema...
# 7     [ensure, work, accurate, time, organize, proac...
# 8     [accuracy, timeliness, crucial, project, task,...
# 9     [im, perfectionist, heart, take, pride, ensure...
# 10    [ensure, work, complete, accurately, time, sta...
# 11    [accuracy, timeliness, critical, success, job,...
# 12    [ensure, work, complete, accurately, time, foc...
# 13    [ensure, work, complete, accurately, time, pri...
# 14    [communication, key, complete, work, accuratel...
# 15    [always, doublecheck, work, ensure, accurate, ...
# 16    [project, management, tool, like, trello, asan...
# 17    [complete, work, always, look, ahead, identify...
# 18    [ensure, flexible, work, reprioritize, task, n...
# 19    [ensure, accurately, estimate, time, require, ...
# 20    [find, organize, keep, detailed, note, essenti...
# 21    [believe, take, pride, work, strong, sense, ow...
# 22    [always, strive, complete, work, accurately, t...
# 23    [ensure, work, complete, accurately, time, pri...
# 24    [one, way, ensure, work, complete, accurately,...
# 25    [believe, take, break, practice, selfcare, ess...
# 26    [ensure, work, complete, accurately, time, act...
# 27    [find, collaborate, others, key, complete, wor...
# 28    [ensure, work, complete, accurately, time, set...
# 29    [believe, power, positive, think, visualizatio...
# 30    [ensure, work, complete, accurately, time, tak...
# 31    [ensure, work, complete, accurately, time, mak...
# 32    [ensure, work, complete, accurately, time, pri...
# 33    [find, effective, communication, critical, com...
# 34    [believe, important, embrace, growth, mindset,...
# 35    [ensure, work, complete, accurately, time, mak...
# 36    [believe, essential, maintain, positive, proac...
# 37    [ensure, work, complete, accurately, time, mak...
# 38    [find, helpful, establish, clear, role, respon...
# 39    [ensure, work, complete, accurately, time, mak...
# 40    [believe, important, adaptable, flexible, work...
# 41    [ensure, work, complete, accurately, time, mak...
# 42    [ensure, work, complete, accurately, time, pri...
# 43    [find, helpful, establish, clear, project, mil...
# 44    [ensure, work, complete, accurately, time, mak...
# 45    [find, helpful, establish, clear, communicatio...
# 46    [ensure, work, complete, accurately, time, mak...
# 47    [believe, important, maintain, proactive, solu...
# 48    [ensure, work, complete, accurately, time, mak...
# 49    [find, helpful, build, time, reflection, evalu...
# Name: Concientiousness_lemmatized, dtype: object

# %%
# initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# define function to lemmatize tokens
def lemmatize_tokens(tokens):
    # convert POS tag to WordNet format
    def get_wordnet_pos(word):
        tag = nltk.pos_tag([word])[0][1][0].upper()
        tag_dict = {"J": wordnet.ADJ,
                    "N": wordnet.NOUN,
                    "V": wordnet.VERB,
                    "R": wordnet.ADV}
        return tag_dict.get(tag, wordnet.NOUN)
    
    # lemmatize tokens
    lemmas = [lemmatizer.lemmatize(token, get_wordnet_pos(token)) for token in tokens]
    
    # return lemmatized tokens as a list
    return lemmas

# apply lemmatization function to column of dataframe
responses_df['Extraversion_lemmatized'] = responses_df['Extraversion'].apply(lemmatize_tokens)

# %%
responses_df['Extraversion_lemmatized']
# Out:
# 0     [im, quite, comfortable, social, situation, al...
# 1     [im, outgo, person, nature, social, situation,...
# 2     [someone, value, personal, relationship, im, a...
# 3     [wouldnt, necessarily, describe, extroverted, ...
# 4     [someone, naturally, extroverted, thrive, soci...
# 5     [ocial, situation, always, energize, enjoyable...
# 6     [someone, strong, interpersonal, skill, social...
# 7     [im, openminded, friendly, person, believe, he...
# 8     [im, good, listener, nature, think, help, succ...
# 9     [understand, building, connection, others, cru...
# 10    [introvert, tend, feel, comfortable, small, qu...
# 11    [social, situation, bit, overwhelm, introvert,...
# 12    [extrovert, absolutely, love, social, situatio...
# 13    [social, situation, definitely, comfort, zone,...
# 14    [extrovert, love, social, situation, meeting, ...
# 15    [introvert, social, situation, drain, still, e...
# 16    [social, situation, definitely, comfort, zone,...
# 17    [extrovert, thrive, social, situation, love, m...
# 18    [feel, comfortable, confident, social, situati...
# 19    [believe, networking, building, relationship, ...
# 20    [naturally, outgo, person, enjoy, socialize, m...
# 21    [developed, strong, communication, interperson...
# 22    [understand, value, make, new, connection, exp...
# 23    [enjoy, challenge, building, new, relationship...
# 24    [approach, social, situation, open, mind, posi...
# 25    [comfortable, social, situation, learn, adapt,...
# 26    [see, social, situation, opportunity, learn, o...
# 27    [recognize, importance, networking, building, ...
# 28    [naturally, outgo, enjoy, meeting, new, people...
# 29    [make, new, connection, important, part, perso...
# 30    [social, situation, nervewracking, try, approa...
# 31    [introvert, find, social, situation, challenge...
# 32    [naturally, curious, enjoy, meeting, new, peop...
# 33    [social, situation, intimidate, try, approach,...
# 34    [enjoy, meeting, new, people, building, relati...
# 35    [social, situation, challenge, try, approach, ...
# 36    [natural, extrovert, thrive, social, situation...
# 37    [make, new, connection, essential, part, perso...
# 38    [always, comfortable, social, situation, enjoy...
# 39    [social, situation, sometimes, overwhelm, reco...
# 40    [introvert, person, social, situation, challen...
# 41    [absolutely, love, social, situation, meeting,...
# 42    [social, situation, intimidate, found, also, i...
# 43    [believe, social, situation, make, new, connec...
# 44    [social, situation, bit, daunt, time, recogniz...
# 45    [someone, value, relationship, human, connecti...
# 46    [social, situation, sometimes, challenge, try,...
# 47    [meeting, new, people, try, friendly, approach...
# 48    [individual, naturally, outgo, personality, so...
# 49    [social, situation, make, new, connection, ner...
# Name: Extraversion_lemmatized, dtype: object

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
import pandas as pd

# initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# define function to lemmatize tokens
def lemmatize_tokens(tokens):
    # convert POS tag to WordNet format
    def get_wordnet_pos(word):
        tag = nltk.pos_tag([word])[0][1][0].upper()
        tag_dict = {"J": wordnet.ADJ,
                    "N": wordnet.NOUN,
                    "V": wordnet.VERB,
                    "R": wordnet.ADV}
        return tag_dict.get(tag, wordnet.NOUN)
    
    # lemmatize tokens
    lemmas = [lemmatizer.lemmatize(token, get_wordnet_pos(token)) for token in tokens]
    
    # return lemmatized tokens as a list
    return lemmas

# apply lemmatization function to column of dataframe
responses_df['Agreeableness_lemmatized'] = responses_df['Agreeableness'].apply(lemmatize_tokens)

# %%
responses_df['Agreeableness_lemmatized']
# Out:
# 0     [try, view, feedback, criticism, opportunity, ...
# 1     [initially, tough, receive, criticism, negativ...
# 2     [handle, feedback, stay, openminded, actively,...
# 3     [take, feedback, seriously, also, try, take, p...
# 4     [view, feedback, opportunity, strengthen, rela...
# 5     [take, proactive, approach, feedback, regularl...
# 6     [receive, feedback, try, stay, objective, focu...
# 7     [handle, feedback, take, ownership, mistake, s...
# 8     [try, approach, feedback, growth, mindset, see...
# 9     [receive, feedback, challenge, try, approach, ...
# 10    [believe, feedback, essential, part, personal,...
# 11    [handle, feedback, try, stay, objective, view,...
# 12    [receive, feedback, make, sure, stay, openmind...
# 13    [handle, feedback, use, tool, selfimprovement,...
# 14    [receive, feedback, try, take, balance, approa...
# 15    [handle, feedback, stay, focus, end, goal, rem...
# 16    [receive, feedback, try, view, opportunity, bu...
# 17    [handle, feedback, take, proactive, approach, ...
# 18    [receive, feedback, try, approach, curious, mi...
# 19    [handle, feedback, try, stay, calm, levelheade...
# 20    [handle, feedback, take, responsibility, actio...
# 21    [receive, feedback, try, see, learn, opportuni...
# 22    [handle, feedback, prioritize, communication, ...
# 23    [receive, feedback, try, patient, understand, ...
# 24    [handle, feedback, focus, solution, try, avoid...
# 25    [take, feedback, learn, opportunity, believe, ...
# 26    [try, remain, openminded, take, criticism, per...
# 27    [view, feedback, way, grow, develop, believe, ...
# 28    [try, empathetic, put, shoe, person, give, fee...
# 29    [take, feedback, seriously, try, remain, profe...
# 30    [try, proactive, seek, feedback, others, regul...
# 31    [view, feedback, opportunity, improve, skill, ...
# 32    [approach, feedback, growth, mindset, understa...
# 33    [try, maintain, positive, attitude, receive, f...
# 34    [try, follow, person, give, feedback, show, ap...
# 35    [believe, feedback, valuable, tool, growth, tr...
# 36    [try, seek, feedback, diverse, range, source, ...
# 37    [try, use, feedback, set, measurable, goal, be...
# 38    [try, use, feedback, challenge, believe, feedb...
# 39    [try, use, feedback, build, resilience, recogn...
# 40    [believe, feedback, valuable, tool, growth, tr...
# 41    [try, use, feedback, build, selfawareness, bel...
# 42    [try, take, proactive, approach, feedback, sol...
# 43    [try, approach, feedback, open, mind, without,...
# 44    [try, use, feedback, create, plan, improvement...
# 45    [try, use, feedback, identify, blind, spot, ar...
# 46    [receive, feedback, try, show, appreciation, g...
# 47    [try, use, feedback, identify, opportunity, pr...
# 48    [try, use, feedback, build, trust, others, rec...
# 49    [try, use, feedback, stay, focus, goal, easy, ...
# Name: Agreeableness_lemmatized, dtype: object

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

# initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# define function to lemmatize tokens
def lemmatize_tokens(tokens):
    # convert POS tag to WordNet format
    def get_wordnet_pos(word):
        tag = nltk.pos_tag([word])[0][1][0].upper()
        tag_dict = {"J": wordnet.ADJ,
                    "N": wordnet.NOUN,
                    "V": wordnet.VERB,
                    "R": wordnet.ADV}
        return tag_dict.get(tag, wordnet.NOUN)
    
    # lemmatize tokens
    lemmas = [lemmatizer.lemmatize(token, get_wordnet_pos(token)) for token in tokens]
    
    # return lemmatized tokens as a list
    return lemmas

# apply lemmatization function to column of dataframe
responses_df['Neuroticism_lemmatized'] = responses_df['Neuroticism'].apply(lemmatize_tokens)

# %%
responses_df['Neuroticism_lemmatized']
# Out:
# 0     [face, difficult, situation, try, remain, calm...
# 1     [experience, one, effective, way, handle, stre...
# 2     [deal, stressful, situation, like, take, proac...
# 3     [find, deal, stressful, situation, communicati...
# 4     [experience, effective, way, handle, stressful...
# 5     [face, difficult, situation, like, take, step,...
# 6     [experience, one, best, way, handle, stressful...
# 7     [deal, stressful, situation, find, help, suppo...
# 8     [believe, preparation, key, handle, difficult,...
# 9     [experience, effective, way, handle, stressful...
# 10    [deal, stressful, situation, try, approach, pr...
# 11    [find, maintain, healthy, worklife, balance, e...
# 12    [face, difficult, situation, try, keep, positi...
# 13    [find, communication, key, manage, stressful, ...
# 14    [experience, take, collaborative, approach, pr...
# 15    [face, difficult, situation, approach, stay, c...
# 16    [believe, one, effective, way, handle, stressf...
# 17    [approach, handle, difficult, situation, stay,...
# 18    [find, communication, key, handle, stressful, ...
# 19    [deal, stressful, situation, try, prioritize, ...
# 20    [approach, handle, difficult, situation, gathe...
# 21    [find, take, step, back, assess, situation, ta...
# 22    [believe, stay, positive, solutionfocused, key...
# 23    [face, difficult, situation, try, stay, calm, ...
# 24    [approach, handle, difficult, situation, stay,...
# 25    [face, difficult, situation, try, remain, calm...
# 26    [find, take, care, key, manage, stress, diffic...
# 27    [deal, difficult, situation, try, approach, po...
# 28    [find, preparation, key, handle, difficult, si...
# 29    [deal, stressful, situation, try, take, step, ...
# 30    [find, stay, organize, prioritize, task, cruci...
# 31    [face, difficult, situation, try, maintain, op...
# 32    [find, take, proactive, approach, effective, m...
# 33    [deal, difficult, situation, try, remain, flex...
# 34    [find, maintain, positive, attitude, sense, hu...
# 35    [face, stressful, difficult, situation, first,...
# 36    [believe, power, positive, think, even, challe...
# 37    [handle, stressful, situation, try, maintain, ...
# 38    [difficult, situation, like, stay, organize, f...
# 39    [approach, handle, stress, stay, proactive, av...
# 40    [manage, stress, like, communicate, effectivel...
# 41    [face, difficult, situation, take, step, back,...
# 42    [face, stressful, difficult, situation, make, ...
# 43    [handle, stressful, situation, make, sure, tak...
# 44    [approach, handle, stressful, difficult, situa...
# 45    [face, stressful, situation, take, step, back,...
# 46    [handle, stressful, situation, prioritize, sel...
# 47    [face, difficult, situation, like, gather, inf...
# 48    [stressful, situation, try, stay, adaptable, f...
# 49    [approach, handle, difficult, situation, remai...
# Name: Neuroticism_lemmatized, dtype: object

# %% [markdown]
# # Word Cloud

# %%
# OPENNESS

print('Word cloud for Openness trait: \n')

# Concatenate all the lemmatized tokens into a single string
lemmatized_text = ' '.join([token for sublist in responses_df['Openness_lemmatized'] for token in sublist])

# Generate the word cloud
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', min_font_size = 10).generate(lemmatized_text)

# Display the word cloud
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
  
plt.show()
# Out:
# Word cloud for Openness trait:

# %%
# CONSCIENTIOUSNESS

print('Word cloud for Concientiousness trait: \n')

# Concatenate all the lemmatized tokens into a single string
lemmatized_text = ' '.join([token for sublist in responses_df['Concientiousness_lemmatized'] for token in sublist])

# Generate the word cloud
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', min_font_size = 10).generate(lemmatized_text)

# Display the word cloud
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
  
plt.show()
# Out:
# Word cloud for Concientiousness trait:

# %%
# EXTRAVERSION

print('Word cloud for Extraversion trait: \n')

# Concatenate all the lemmatized tokens into a single string
lemmatized_text = ' '.join([token for sublist in responses_df['Extraversion_lemmatized'] for token in sublist])

# Generate the word cloud
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', min_font_size = 10).generate(lemmatized_text)

# Display the word cloud
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
  
plt.show()
# Out:
# Word cloud for Extraversion trait:

# %%
# AGREEABLENESS

print('Word cloud for Agreeableness trait: \n')

# Concatenate all the lemmatized tokens into a single string
lemmatized_text = ' '.join([token for sublist in responses_df['Agreeableness_lemmatized'] for token in sublist])

# Generate the word cloud
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', min_font_size = 10).generate(lemmatized_text)

# Display the word cloud
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
  
plt.show()
# Out:
# Word cloud for Agreeableness trait:

# %%
# NEUROTICISM

print('Word cloud for Neuroticism trait: \n')

# Concatenate all the lemmatized tokens into a single string
lemmatized_text = ' '.join([token for sublist in responses_df['Agreeableness_lemmatized'] for token in sublist])

# Generate the word cloud
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', min_font_size = 10).generate(lemmatized_text)

# Display the word cloud
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
  
plt.show()
# Out:
# Word cloud for Neuroticism trait:

# %%
# write selected columns of responses_df dataframe to a CSV file
selected_columns = ['Openness_lemmatized', 'Concientiousness_lemmatized', 'Extraversion_lemmatized', 'Agreeableness_lemmatized', 'Neuroticism_lemmatized']
new_column_names = {'Openness_lemmatized':'Openness', 'Concientiousness_lemmatized':'Concientiousness', 'Extraversion_lemmatized':'Extraversion', 'Agreeableness_lemmatized':'Agreeableness', 'Neuroticism_lemmatized':'Neuroticism'}
responses_df[selected_columns].rename(columns=new_column_names).to_csv('preprocessed.csv', index=False)

# %%
# Authenticate and create the PyDrive client

# !cp preprocessed.csv "/content/drive/MyDrive/Intellihire"
# Out:
# cp: 'preprocessed.csv' and '/content/drive/MyDrive/Intellihire/preprocessed.csv' are the same file

# %%
# loading the clean dataset into a dataframe

df = pd.read_csv('preprocessed.csv')
df.head(10)
# Out:
#                                             Openness  \
# 0  ['strongly', 'believe', 'seek', 'new', 'experi...
# 1  ['someone', 'thrives', 'novelty', 'excitement'...
# 2  ['naturally', 'inclined', 'seek', 'new', 'expe...
# 3  ['personal', 'professional', 'growth', 'two', ...
# 4  ['natural', 'risktaker', 'recognize', 'value',...
# 5  ['someone', 'enjoys', 'take', 'risk', 'seek', ...
# 6  ['seek', 'new', 'experience', 'take', 'risk', ...
# 7  ['explore', 'new', 'idea', 'try', 'new', 'thin...
# 8  ['seek', 'new', 'challenge', 'experience', 'ke...
# 9  ['seek', 'new', 'experience', 'take', 'risk', ...
#
#                                     Concientiousness  \
# 0  ['prioritize', 'work', 'accord', 'deadline', '...
# 1  ['believe', 'accuracy', 'attention', 'detail',...
# 2  ['manage', 'time', 'effectively', 'planning', ...
# 3  ['ensure', 'work', 'accurate', 'complete', 'ti...
# 4  ['believe', 'set', 'realistic', 'goal', 'key',...
# 5  ['accuracy', 'timeliness', 'essential', 'proje...
# 6  ['ensure', 'work', 'accurate', 'time', 'follow...
# 7  ['ensure', 'work', 'accurate', 'time', 'organi...
# 8  ['accuracy', 'timeliness', 'crucial', 'project...
# 9  ['im', 'perfectionist', 'heart', 'take', 'prid...
#
#                                         Extraversion  \
# 0  ['im', 'quite', 'comfortable', 'social', 'situ...
# 1  ['im', 'outgo', 'person', 'nature', 'social', ...
# 2  ['someone', 'value', 'personal', 'relationship...
# 3  ['wouldnt', 'necessarily', 'describe', 'extrov...
# 4  ['someone', 'naturally', 'extroverted', 'thriv...
# 5  ['ocial', 'situation', 'always', 'energize', '...
# 6  ['someone', 'strong', 'interpersonal', 'skill'...
# 7  ['im', 'openminded', 'friendly', 'person', 'be...
# 8  ['im', 'good', 'listener', 'nature', 'think', ...
# 9  ['understand', 'building', 'connection', 'othe...
#
#                                        Agreeableness  \
# 0  ['try', 'view', 'feedback', 'criticism', 'oppo...
# 1  ['initially', 'tough', 'receive', 'criticism',...
# 2  ['handle', 'feedback', 'stay', 'openminded', '...
# 3  ['take', 'feedback', 'seriously', 'also', 'try...
# 4  ['view', 'feedback', 'opportunity', 'strengthe...
# 5  ['take', 'proactive', 'approach', 'feedback', ...
# 6  ['receive', 'feedback', 'try', 'stay', 'object...
# 7  ['handle', 'feedback', 'take', 'ownership', 'm...
# 8  ['try', 'approach', 'feedback', 'growth', 'min...
# 9  ['receive', 'feedback', 'challenge', 'try', 'a...
#
#                                          Neuroticism
# 0  ['face', 'difficult', 'situation', 'try', 'rem...
# 1  ['experience', 'one', 'effective', 'way', 'han...
# 2  ['deal', 'stressful', 'situation', 'like', 'ta...
# 3  ['find', 'deal', 'stressful', 'situation', 'co...
# 4  ['experience', 'effective', 'way', 'handle', '...
# 5  ['face', 'difficult', 'situation', 'like', 'ta...
# 6  ['experience', 'one', 'best', 'way', 'handle',...
# 7  ['deal', 'stressful', 'situation', 'find', 'he...
# 8  ['believe', 'preparation', 'key', 'handle', 'd...
# 9  ['experience', 'effective', 'way', 'handle', '...

# %% [markdown]
# # Keyword Extraction

# %% [markdown]
# ##I. Bag of Words Representation

# %%
# OPENNESS

# Create a bag of words representation of the text data
vectorizer = CountVectorizer()
bag_of_words = vectorizer.fit_transform(responses_df['Openness_lemmatized'].apply(lambda x: ' '.join(x)))

# Get the sum of the counts of each word in the corpus
sum_words = bag_of_words.sum(axis=0)

# Get the frequency of each word in the corpus
word_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]

# Sort the list of words by frequency in descending order
word_freq = sorted(word_freq, key=lambda x: x[1], reverse=True)

# Print the top 10 most common words
print('Bag of words representation for Openness trait:\n')

Openness_top25 = []

for word, freq in word_freq[:25]:
    print(word, freq)
    Openness_top25.append(word)
# Out:
# Bag of words representation for Openness trait:
#
# new 206
# risk 136
# take 123
# life 74
# personal 64
# professional 63
# believe 59
# try 59
# opportunity 54
# experience 53
# learn 51
# im 50
# always 48
# potential 48
# challenge 44
# seek 40
# make 40
# growth 39
# look 37
# explore 36
# important 35
# place 31
# enjoy 30
# decision 27
# big 26

# %%
# CONCIENTIOUSNESS

# Create a bag of words representation of the text data
vectorizer = CountVectorizer()
bag_of_words = vectorizer.fit_transform(responses_df['Concientiousness_lemmatized'].apply(lambda x: ' '.join(x)))

# Get the sum of the counts of each word in the corpus
sum_words = bag_of_words.sum(axis=0)

# Get the frequency of each word in the corpus
word_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]

# Sort the list of words by frequency in descending order
word_freq = sorted(word_freq, key=lambda x: x[1], reverse=True)

# Print the top 10 most common words
print('Bag of words representation for Concientiousness trait:\n')

Concientiousness_top25 = []

for word, freq in word_freq[:25]:
    print(word, freq)
    Concientiousness_top25.append(word)
# Out:
# Bag of words representation for Concientiousness trait:
#
# work 133
# time 89
# ensure 82
# complete 63
# project 47
# accurately 45
# task 42
# also 27
# team 27
# include 26
# make 24
# deadline 21
# stay 20
# member 19
# help 19
# identify 19
# take 18
# everyone 18
# prioritize 17
# keep 17
# stakeholder 17
# clear 17
# communication 16
# set 16
# break 16

# %%
# EXTRAVERSION

# Create a bag of words representation of the text data
vectorizer = CountVectorizer()
bag_of_words = vectorizer.fit_transform(responses_df['Extraversion_lemmatized'].apply(lambda x: ' '.join(x)))

# Get the sum of the counts of each word in the corpus
sum_words = bag_of_words.sum(axis=0)

# Get the frequency of each word in the corpus
word_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]

# Sort the list of words by frequency in descending order
word_freq = sorted(word_freq, key=lambda x: x[1], reverse=True)

# Print the top 10 most common words
print('Bag of words representation for Extraversion trait:\n')

Extraversion_top25 = []

for word, freq in word_freq[:25]:
    print(word, freq)
    Extraversion_top25.append(word)
# Out:
# Bag of words representation for Extraversion trait:
#
# new 116
# connection 94
# people 75
# make 65
# social 63
# relationship 60
# situation 58
# try 58
# meeting 56
# others 56
# believe 40
# building 39
# learn 37
# build 33
# find 32
# experience 29
# able 29
# help 28
# also 25
# valuable 24
# interest 23
# may 22
# professional 20
# life 20
# perspective 20

# %%
# AGREEABLENESS

# Create a bag of words representation of the text data
vectorizer = CountVectorizer()
bag_of_words = vectorizer.fit_transform(responses_df['Agreeableness_lemmatized'].apply(lambda x: ' '.join(x)))

# Get the sum of the counts of each word in the corpus
sum_words = bag_of_words.sum(axis=0)

# Get the frequency of each word in the corpus
word_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]

# Sort the list of words by frequency in descending order
word_freq = sorted(word_freq, key=lambda x: x[1], reverse=True)

# Print the top 10 most common words
print('Bag of words representation for Agreeableness trait:\n')

Agreeableness_top25 = []

for word, freq in word_freq[:25]:
    print(word, freq)
    Agreeableness_top25.append(word)
# Out:
# Bag of words representation for Agreeableness trait:
#
# feedback 184
# try 69
# take 51
# improve 43
# receive 41
# make 40
# believe 38
# stay 28
# use 27
# ask 23
# listen 22
# person 22
# approach 21
# understand 20
# opportunity 19
# skill 17
# question 16
# change 16
# become 16
# help 16
# view 15
# learn 15
# colleague 15
# seek 15
# work 15

# %%
# NEUROTICISM

# Create a bag of words representation of the text data
vectorizer = CountVectorizer()
bag_of_words = vectorizer.fit_transform(responses_df['Neuroticism_lemmatized'].apply(lambda x: ' '.join(x)))

# Get the sum of the counts of each word in the corpus
sum_words = bag_of_words.sum(axis=0)

# Get the frequency of each word in the corpus
word_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]

# Sort the list of words by frequency in descending order
word_freq = sorted(word_freq, key=lambda x: x[1], reverse=True)

# Print the top 10 most common words
print('Bag of words representation for Neuroticism trait:\n')

Neuroticism_top25= []

for word, freq in word_freq[:25]:
    print(word, freq)
    Neuroticism_top25.append(word)
# Out:
# Bag of words representation for Neuroticism trait:
#
# situation 62
# stay 62
# try 45
# help 43
# take 35
# problem 34
# make 32
# difficult 30
# find 29
# manage 27
# stress 27
# solution 26
# also 25
# approach 25
# challenge 25
# focus 24
# stressful 24
# able 22
# face 21
# break 19
# handle 19
# work 17
# well 16
# maintain 15
# team 15

# %% [markdown]
# ##II. TF-IDF Vectorizer

# %%
# OPENNESS

# create a TfidfVectorizer
tfidf = TfidfVectorizer()

# fit and transform the text column
tfidf_matrix = tfidf.fit_transform(df['Openness'])

# get the sum of the TF-IDF scores for each word
tfidf_sum = tfidf_matrix.sum(axis=0)

# convert the sum to a list of tuples (word, score)
word_scores = [(word, tfidf_sum[0, idx]) for word, idx in tfidf.vocabulary_.items()]

# sort the list by score (in descending order)
word_scores.sort(key=lambda x: x[1], reverse=True)

# print the top 10 most frequent words
print('Most frequently used words for Openness trait:\n')

Openness_tokens = []

for word, score in word_scores[:25]:
    #print(f'{word}: {score}')
    Openness_tokens.append(word)

print(Openness_tokens)
# Out:
# Most frequently used words for Openness trait:
#
# ['new', 'risk', 'take', 'life', 'im', 'professional', 'personal', 'try', 'believe', 'learn', 'opportunity', 'potential', 'always', 'important', 'make', 'experience', 'challenge', 'growth', 'look', 'explore', 'enjoy', 'seek', 'place', 'big', 'decision']

# %%
# CONCIENTIOUSNESS

# create a TfidfVectorizer
tfidf = TfidfVectorizer()

# fit and transform the text column
tfidf_matrix = tfidf.fit_transform(df['Concientiousness'])

# get the sum of the TF-IDF scores for each word
tfidf_sum = tfidf_matrix.sum(axis=0)

# convert the sum to a list of tuples (word, score)
word_scores = [(word, tfidf_sum[0, idx]) for word, idx in tfidf.vocabulary_.items()]

# sort the list by score (in descending order)
word_scores.sort(key=lambda x: x[1], reverse=True)

# print the top 10 most frequent words
print('Most frequently used words for Concientiousness trait:\n')

Concientiousness_tokens = []

for word, score in word_scores[:25]:
    #print(f'{word}: {score}')
    Concientiousness_tokens.append(word)

print(Concientiousness_tokens)
# Out:
# Most frequently used words for Concientiousness trait:
#
# ['work', 'time', 'ensure', 'task', 'complete', 'project', 'accurately', 'team', 'include', 'also', 'make', 'deadline', 'clear', 'stay', 'communication', 'everyone', 'member', 'keep', 'help', 'take', 'identify', 'establish', 'require', 'prioritize', 'stakeholder']

# %%
# EXTRAVERSION

# create a TfidfVectorizer
tfidf = TfidfVectorizer()

# fit and transform the text column
tfidf_matrix = tfidf.fit_transform(df['Extraversion'])

# get the sum of the TF-IDF scores for each word
tfidf_sum = tfidf_matrix.sum(axis=0)

# convert the sum to a list of tuples (word, score)
word_scores = [(word, tfidf_sum[0, idx]) for word, idx in tfidf.vocabulary_.items()]

# sort the list by score (in descending order)
word_scores.sort(key=lambda x: x[1], reverse=True)

# print the top 10 most frequent words
print('Most frequently used words for Extraversion trait:\n')

Extraversion_tokens = []

for word, score in word_scores[:25]:
    #print(f'{word}: {score}')
    Extraversion_tokens.append(word)

print(Extraversion_tokens)
# Out:
# Most frequently used words for Extraversion trait:
#
# ['new', 'connection', 'people', 'make', 'try', 'others', 'relationship', 'social', 'meeting', 'situation', 'able', 'building', 'learn', 'build', 'believe', 'find', 'experience', 'help', 'may', 'valuable', 'also', 'interest', 'life', 'opportunity', 'professional']

# %%
# AGREEABLENESS

# create a TfidfVectorizer
tfidf = TfidfVectorizer()

# fit and transform the text column
tfidf_matrix = tfidf.fit_transform(df['Agreeableness'])

# get the sum of the TF-IDF scores for each word
tfidf_sum = tfidf_matrix.sum(axis=0)

# convert the sum to a list of tuples (word, score)
word_scores = [(word, tfidf_sum[0, idx]) for word, idx in tfidf.vocabulary_.items()]

# sort the list by score (in descending order)
word_scores.sort(key=lambda x: x[1], reverse=True)

# print the top 10 most frequent words
print('Most frequently used words for Agreeableness trait:\n')

Agreeableness_tokens = []

for word, score in word_scores[:25]:
    #print(f'{word}: {score}')
    Agreeableness_tokens.append(word)

print(Agreeableness_tokens)
# Out:
# Most frequently used words for Agreeableness trait:
#
# ['feedback', 'try', 'take', 'improve', 'make', 'believe', 'use', 'receive', 'stay', 'approach', 'understand', 'ask', 'person', 'listen', 'learn', 'opportunity', 'growth', 'mindset', 'skill', 'seek', 'view', 'work', 'change', 'become', 'help']

# %%
# NEUROTICISM

# create a TfidfVectorizer
tfidf = TfidfVectorizer()

# fit and transform the text column
tfidf_matrix = tfidf.fit_transform(df['Neuroticism'])

# get the sum of the TF-IDF scores for each word
tfidf_sum = tfidf_matrix.sum(axis=0)

# convert the sum to a list of tuples (word, score)
word_scores = [(word, tfidf_sum[0, idx]) for word, idx in tfidf.vocabulary_.items()]

# sort the list by score (in descending order)
word_scores.sort(key=lambda x: x[1], reverse=True)

# print the top 10 most frequent words
print('Most frequently used words for Neuroticism trait:\n')

Neuroticism_tokens = []

for word, score in word_scores[:25]:
    #print(f'{word}: {score}')
    Neuroticism_tokens.append(word)

print(Neuroticism_tokens)
# Out:
# Most frequently used words for Neuroticism trait:
#
# ['stay', 'situation', 'try', 'help', 'take', 'problem', 'make', 'find', 'stress', 'solution', 'manage', 'difficult', 'focus', 'approach', 'challenge', 'stressful', 'also', 'able', 'break', 'face', 'handle', 'well', 'maintain', 'task', 'effectively']

# %%
# put the extracted tokens for the five traits into a dataframe

# freq_tokens = pd.DataFrame({'Openness_tokens': Openness_tokens, 'Concientiousness_tokens': Concientiousness_tokens, 'Extraversion_tokens': Extraversion_tokens, 'Agreeableness_tokens':Agreeableness_tokens, 'Neuroticism_tokens':Neuroticism_tokens})
# freq_tokens

# %% [markdown]
# ##III. keyBERT

# %%
pip install keybert
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keybert in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: sentence-transformers>=0.3.8 in /usr/local/lib/python3.10/dist-packages (from keybert) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.10/dist-packages (from keybert) (1.2.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from keybert) (1.22.4)
# Requirement already satisfied: rich>=10.4.0 in /usr/local/lib/python3.10/dist-packages (from keybert) (13.3.4)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.4.0->keybert) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.4.0->keybert) (2.14.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (3.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.29.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.15.2+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.14.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.12.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2023.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (23.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.4.0->keybert) (0.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (16.0.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (0.13.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.3.8->keybert) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=0.3.8->keybert) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (1.3.0)

# %%
# def extract_keywords_from_dataframe(df, text_column, num_keywords=5):
#     # Initialize the KeyBERT model
#     model = KeyBERT()

#     # Extract keywords for each text in the specified column
#     keyword_list = []
#     for text in df[text_column]:
#         keywords = model.extract_keywords(text, keyphrase_ngram_range=(1, 1), stop_words='english', top_n=num_keywords)
#         keyword_list.append([keyword for keyword, _ in keywords])

#     # Return the list of extracted keywords
#     return keyword_list

# %%
from keybert import KeyBERT

def extract_keywords_from_dataframe(df, text_column, num_keywords=5):
    # Initialize the KeyBERT model
    model = KeyBERT()

    # Concatenate all text phrases in the column into a single string
    text = ' '.join(df[text_column])

    # Extract keywords from the concatenated text
    keywords = model.extract_keywords(text, keyphrase_ngram_range=(1, 1), stop_words='english', top_n=num_keywords)

    # Return the extracted keywords
    return [keyword for keyword, _ in keywords]

# %%
import pandas as pd

# Extract keywords from the 'Openness' column
Openness_keywords_BERT = extract_keywords_from_dataframe(df, 'Openness', num_keywords=25)

# Print the extracted keywords for the whole column
print(f"{Openness_keywords_BERT}")
# Out:
# ['adventurousness', 'adventurous', 'thrill', 'motivate', 'risktaking', 'lifelong', 'strength', 'willingness', 'skill', 'meaningful', 'experience', 'endeavor', 'explore', 'develop', 'potential', 'passion', 'risk', 'decisionmaking', 'activity', 'strong', 'knowledge', 'hobby', 'risktaker', 'life', 'expertise']

# %%
import pandas as pd

# Extract keywords from the 'Openness' column
Concientiousness_keywords_BERT = extract_keywords_from_dataframe(df, 'Concientiousness', num_keywords=25)

# Print the extracted keywords for the whole column
print(f"{Concientiousness_keywords_BERT}")
# Out:
# ['task', 'outline', 'checklist', 'list', 'decisionmaking', 'teamwork', 'organize', 'completion', 'activity', 'priority', 'urgency', 'grammarcheck', 'expertise', 'editor', 'progress', 'workload', 'initiative', 'overwhelmed', 'manage', 'guide', 'milestone', 'management', 'procrastination', 'revision', 'productivity']

# %%
import pandas as pd

# Extract keywords from the 'Openness' column
Extraversion_keywords_BERT = extract_keywords_from_dataframe(df, 'Extraversion', num_keywords=25)

# Print the extracted keywords for the whole column
print(f"{Extraversion_keywords_BERT}")
# Out:
# ['meaningful', 'interpersonal', 'enjoyable', 'thoughtfulness', 'personality', 'thoughtful', 'mindful', 'empathy', 'humility', 'rapport', 'relationship', 'conversation', 'respectful', 'language', 'personable', 'group', 'friendly', 'meeting', 'social', 'socialize', 'mind', 'actively', 'partner', 'collaboration', 'honesty']

# %%
import pandas as pd

# Extract keywords from the 'Openness' column
Agreeableness_keywords_BERT = extract_keywords_from_dataframe(df, 'Agreeableness', num_keywords=25)

# Print the extracted keywords for the whole column
print(f"{Agreeableness_keywords_BERT}")
# Out:
# ['feedback', 'criticism', 'coworkers', 'supervisor', 'attentively', 'mentor', 'rapport', 'colleague', 'appreciation', 'constructive', 'productive', 'teamwork', 'continually', 'excellence', 'skill', 'receptive', 'professional', 'gratitude', 'example', 'conversation', 'progress', 'activity', 'review', 'develop', 'collaborate']

# %%
import pandas as pd

# Extract keywords from the 'Openness' column
Neuroticism_keywords_BERT = extract_keywords_from_dataframe(df, 'Neuroticism', num_keywords=25)

# Print the extracted keywords for the whole column
print(f"{Neuroticism_keywords_BERT}")
# Out:
# ['methodical', 'stressmanagement', 'task', 'activity', 'motivate', 'worklife', 'stressful', 'overwhelmed', 'manageable', 'decisionmaking', 'skill', 'stress', 'manage', 'tension', 'brainstorming', 'involves', 'ease', 'creative', 'expertise', 'inspire', 'collaborative', 'focus', 'solutionfocused', 'strength', 'guide']

# %% [markdown]
# # Candidate Responses

# %%
# OPENNESS
openness_response = "I am someone who enjoys taking on new challenges and seeking out new experiences. I believe that by pushing myself out of my comfort zone, I am able to learn and grow both professionally and personally. In my previous roles, I have taken on new projects and tasks that were outside of my immediate area of expertise, and I found these experiences to be incredibly rewarding. Of course, I always make sure to assess the risks involved before taking on a new challenge, but I am not afraid to take calculated risks in order to achieve my goals. Overall, I would say that I am someone who is open to new experiences and willing to take risks when the situation calls for it."
concientiousness_response = "I ensure accurate and timely completion of work by breaking down projects into manageable tasks and prioritizing based on importance and urgency. I use productivity tools and communicate regularly with my team to track progress and address issues early. Seeking feedback from colleagues and stakeholders, taking ownership of my work, and being willing to put in extra effort are also important to me in ensuring successful completion of projects."
extraversion_response = "I am a very sociable person and enjoy meeting new people. I thrive in social situations and find that making new connections is both exciting and fulfilling. I am comfortable striking up conversations with strangers and find it easy to connect with people from different backgrounds and cultures. I believe that building new connections is important not only for personal growth but also for professional development, and I am always eager to expand my network and learn from others."
agreeableness_response = "I handle feedback and criticism from others constructively and positively. Firstly, I listen carefully to the feedback and try to understand the perspective of the person providing it. I ask clarifying questions to gain a better understanding of their expectations and how I can improve. I do not take the feedback personally and remain open to suggestions for improvement. I then take time to reflect on the feedback and develop an action plan to address any areas for improvement. I am proactive in seeking feedback and view it as an opportunity to learn and grow professionally. Ultimately, I strive to use feedback to improve my performance and achieve better outcomes in my work."
neuroticism_response = "Sure, there was a time when I was working on a project with a tight deadline, and we were faced with a setback due to unforeseen technical difficulties. I took a step back, analyzed the situation, and communicated openly with my team about the issue. I then researched and proposed several solutions, and we worked together to select the best option. Despite the added pressure and long hours, I remained calm and focused on the task at hand. In the end, we were able to overcome the challenge and complete the project on time, with a successful outcome. This experience taught me the importance of staying calm under pressure, maintaining clear communication, and being proactive in finding solutions to difficult situations."

# %% [markdown]
# # Preprocessing Candidate Response

# %% [markdown]
# ##I.TF-IDF

# %%
# OPENNESS

# take all the words in the candidate response into a list
openness_response_words = openness_response.split()

# CONVERT TO LOWERCASE
# Convert all words in the list to lowercase using list comprehension
openness_response_words = [word.lower() for word in openness_response_words]


# STOPWORD REMOVAL
import nltk
from nltk.corpus import stopwords

# Download the stopwords corpus if not already downloaded
nltk.download('stopwords')

# Get the set of stopwords
stop_words = set(stopwords.words('english'))

# Remove the stopwords from the list
openness_response_words = [word for word in openness_response_words if word.lower() not in stop_words]


# LEMMATIZATION
# Initialize the WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Lemmatize all words in the list using list comprehension
openness_response_words = [lemmatizer.lemmatize(word, pos='v') for word in openness_response_words]

# Print the lemmatized list
print(openness_response_words, '\n')
# Out:
# ['someone', 'enjoy', 'take', 'new', 'challenge', 'seek', 'new', 'experiences.', 'believe', 'push', 'comfort', 'zone,', 'able', 'learn', 'grow', 'professionally', 'personally.', 'previous', 'roles,', 'take', 'new', 'project', 'task', 'outside', 'immediate', 'area', 'expertise,', 'find', 'experience', 'incredibly', 'rewarding.', 'course,', 'always', 'make', 'sure', 'assess', 'risk', 'involve', 'take', 'new', 'challenge,', 'afraid', 'take', 'calculate', 'risk', 'order', 'achieve', 'goals.', 'overall,', 'would', 'say', 'someone', 'open', 'new', 'experience', 'will', 'take', 'risk', 'situation', 'call', 'it.']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# CONCIENTIOUSNESS

# take all the words in the candidate response into a list
concientiousness_response_words = concientiousness_response.split()

# CONVERT TO LOWERCASE
# Convert all words in the list to lowercase using list comprehension
concientiousness_response_words = [word.lower() for word in concientiousness_response_words]


# STOPWORD REMOVAL
import nltk
from nltk.corpus import stopwords

# Download the stopwords corpus if not already downloaded
nltk.download('stopwords')

# Get the set of stopwords
stop_words = set(stopwords.words('english'))

# Remove the stopwords from the list
concientiousness_response_words = [word for word in concientiousness_response_words if word.lower() not in stop_words]


# LEMMATIZATION
# Initialize the WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Lemmatize all words in the list using list comprehension
concientiousness_response_words = [lemmatizer.lemmatize(word, pos='v') for word in concientiousness_response_words]

# Print the lemmatized list
print(concientiousness_response_words, '\n')
# Out:
# ['ensure', 'accurate', 'timely', 'completion', 'work', 'break', 'project', 'manageable', 'task', 'prioritize', 'base', 'importance', 'urgency.', 'use', 'productivity', 'tool', 'communicate', 'regularly', 'team', 'track', 'progress', 'address', 'issue', 'early.', 'seek', 'feedback', 'colleagues', 'stakeholders,', 'take', 'ownership', 'work,', 'will', 'put', 'extra', 'effort', 'also', 'important', 'ensure', 'successful', 'completion', 'projects.']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# EXTRAVERSION

# take all the words in the candidate response into a list
extraversion_response_words = extraversion_response.split()

# CONVERT TO LOWERCASE
# Convert all words in the list to lowercase using list comprehension
extraversion_response_words = [word.lower() for word in extraversion_response_words]


# STOPWORD REMOVAL
import nltk
from nltk.corpus import stopwords

# Download the stopwords corpus if not already downloaded
nltk.download('stopwords')

# Get the set of stopwords
stop_words = set(stopwords.words('english'))

# Remove the stopwords from the list
extraversion_response_words = [word for word in extraversion_response_words if word.lower() not in stop_words]


# LEMMATIZATION
# Initialize the WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Lemmatize all words in the list using list comprehension
extraversion_response_words = [lemmatizer.lemmatize(word, pos='v') for word in extraversion_response_words]

# Print the lemmatized list
print(extraversion_response_words, '\n')
# Out:
# ['sociable', 'person', 'enjoy', 'meet', 'new', 'people.', 'thrive', 'social', 'situations', 'find', 'make', 'new', 'connections', 'excite', 'fulfilling.', 'comfortable', 'strike', 'conversations', 'strangers', 'find', 'easy', 'connect', 'people', 'different', 'background', 'cultures.', 'believe', 'build', 'new', 'connections', 'important', 'personal', 'growth', 'also', 'professional', 'development,', 'always', 'eager', 'expand', 'network', 'learn', 'others.']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# AGREEABLENESS 

# take all the words in the candidate response into a list
agreeableness_response_words = agreeableness_response.split()

# CONVERT TO LOWERCASE
# Convert all words in the list to lowercase using list comprehension
agreeableness_response_words = [word.lower() for word in agreeableness_response_words]


# STOPWORD REMOVAL
import nltk
from nltk.corpus import stopwords

# Download the stopwords corpus if not already downloaded
nltk.download('stopwords')

# Get the set of stopwords
stop_words = set(stopwords.words('english'))

# Remove the stopwords from the list
agreeableness_response_words = [word for word in agreeableness_response_words if word.lower() not in stop_words]


# LEMMATIZATION
# Initialize the WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Lemmatize all words in the list using list comprehension
agreeableness_response_words = [lemmatizer.lemmatize(word, pos='v') for word in agreeableness_response_words]

# Print the lemmatized list
print(agreeableness_response_words, '\n')
# Out:
# ['handle', 'feedback', 'criticism', 'others', 'constructively', 'positively.', 'firstly,', 'listen', 'carefully', 'feedback', 'try', 'understand', 'perspective', 'person', 'provide', 'it.', 'ask', 'clarify', 'question', 'gain', 'better', 'understand', 'expectations', 'improve.', 'take', 'feedback', 'personally', 'remain', 'open', 'suggestions', 'improvement.', 'take', 'time', 'reflect', 'feedback', 'develop', 'action', 'plan', 'address', 'areas', 'improvement.', 'proactive', 'seek', 'feedback', 'view', 'opportunity', 'learn', 'grow', 'professionally.', 'ultimately,', 'strive', 'use', 'feedback', 'improve', 'performance', 'achieve', 'better', 'outcomes', 'work.']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# NEUROTICISM

# take all the words in the candidate response into a list
neuroticism_response_words = neuroticism_response.split()

# CONVERT TO LOWERCASE
# Convert all words in the list to lowercase using list comprehension
neuroticism_response_words = [word.lower() for word in neuroticism_response_words]


# STOPWORD REMOVAL
import nltk
from nltk.corpus import stopwords

# Download the stopwords corpus if not already downloaded
nltk.download('stopwords')

# Get the set of stopwords
stop_words = set(stopwords.words('english'))

# Remove the stopwords from the list
neuroticism_response_words = [word for word in neuroticism_response_words if word.lower() not in stop_words]


# LEMMATIZATION
# Initialize the WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Lemmatize all words in the list using list comprehension
neuroticism_response_words = [lemmatizer.lemmatize(word, pos='v') for word in neuroticism_response_words]

# Print the lemmatized list
print(neuroticism_response_words, '\n')
# Out:
# ['sure,', 'time', 'work', 'project', 'tight', 'deadline,', 'face', 'setback', 'due', 'unforeseen', 'technical', 'difficulties.', 'take', 'step', 'back,', 'analyze', 'situation,', 'communicate', 'openly', 'team', 'issue.', 'research', 'propose', 'several', 'solutions,', 'work', 'together', 'select', 'best', 'option.', 'despite', 'add', 'pressure', 'long', 'hours,', 'remain', 'calm', 'focus', 'task', 'hand.', 'end,', 'able', 'overcome', 'challenge', 'complete', 'project', 'time,', 'successful', 'outcome.', 'experience', 'teach', 'importance', 'stay', 'calm', 'pressure,', 'maintain', 'clear', 'communication,', 'proactive', 'find', 'solutions', 'difficult', 'situations.']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ##II.BERT

# %%
# OPENNESS

# take all the words in the candidate response into a list
openness_response_words = openness_response.split()

# CONVERT TO LOWERCASE
# Convert all words in the list to lowercase using list comprehension
openness_response_words = [word.lower() for word in openness_response_words]


# STOPWORD REMOVAL
import nltk
from nltk.corpus import stopwords

# Download the stopwords corpus if not already downloaded
nltk.download('stopwords')

# Get the set of stopwords
stop_words = set(stopwords.words('english'))

# Remove the stopwords from the list
openness_response_words = [word for word in openness_response_words if word.lower() not in stop_words]


# LEMMATIZATION
# Initialize the WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Lemmatize all words in the list using list comprehension
openness_response_words = [lemmatizer.lemmatize(word, pos='v') for word in openness_response_words]

# Print the lemmatized list
print(openness_response_words, '\n')
# Out:
# ['someone', 'enjoy', 'take', 'new', 'challenge', 'seek', 'new', 'experiences.', 'believe', 'push', 'comfort', 'zone,', 'able', 'learn', 'grow', 'professionally', 'personally.', 'previous', 'roles,', 'take', 'new', 'project', 'task', 'outside', 'immediate', 'area', 'expertise,', 'find', 'experience', 'incredibly', 'rewarding.', 'course,', 'always', 'make', 'sure', 'assess', 'risk', 'involve', 'take', 'new', 'challenge,', 'afraid', 'take', 'calculate', 'risk', 'order', 'achieve', 'goals.', 'overall,', 'would', 'say', 'someone', 'open', 'new', 'experience', 'will', 'take', 'risk', 'situation', 'call', 'it.']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# CONSCIENTIOUSNESS

# take all the words in the candidate response into a list
concientiousness_response_words = concientiousness_response.split()

# CONVERT TO LOWERCASE
# Convert all words in the list to lowercase using list comprehension
concientiousness_response_words = [word.lower() for word in concientiousness_response_words]


# STOPWORD REMOVAL
import nltk
from nltk.corpus import stopwords

# Download the stopwords corpus if not already downloaded
nltk.download('stopwords')

# Get the set of stopwords
stop_words = set(stopwords.words('english'))

# Remove the stopwords from the list
concientiousness_response_words = [word for word in concientiousness_response_words if word.lower() not in stop_words]


# LEMMATIZATION
# Initialize the WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Lemmatize all words in the list using list comprehension
concientiousness_response_words = [lemmatizer.lemmatize(word, pos='v') for word in concientiousness_response_words]

# Print the lemmatized list
print(concientiousness_response_words, '\n')
# Out:
# ['ensure', 'accurate', 'timely', 'completion', 'work', 'break', 'project', 'manageable', 'task', 'prioritize', 'base', 'importance', 'urgency.', 'use', 'productivity', 'tool', 'communicate', 'regularly', 'team', 'track', 'progress', 'address', 'issue', 'early.', 'seek', 'feedback', 'colleagues', 'stakeholders,', 'take', 'ownership', 'work,', 'will', 'put', 'extra', 'effort', 'also', 'important', 'ensure', 'successful', 'completion', 'projects.']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# EXTRAVERSION

# take all the words in the candidate response into a list
extraversion_response_words = extraversion_response.split()

# CONVERT TO LOWERCASE
# Convert all words in the list to lowercase using list comprehension
extraversion_response_words = [word.lower() for word in extraversion_response_words]


# STOPWORD REMOVAL
import nltk
from nltk.corpus import stopwords

# Download the stopwords corpus if not already downloaded
nltk.download('stopwords')

# Get the set of stopwords
stop_words = set(stopwords.words('english'))

# Remove the stopwords from the list
extraversion_response_words = [word for word in extraversion_response_words if word.lower() not in stop_words]


# LEMMATIZATION
# Initialize the WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Lemmatize all words in the list using list comprehension
extraversion_response_words = [lemmatizer.lemmatize(word, pos='v') for word in extraversion_response_words]

# Print the lemmatized list
print(extraversion_response_words, '\n')
# Out:
# ['sociable', 'person', 'enjoy', 'meet', 'new', 'people.', 'thrive', 'social', 'situations', 'find', 'make', 'new', 'connections', 'excite', 'fulfilling.', 'comfortable', 'strike', 'conversations', 'strangers', 'find', 'easy', 'connect', 'people', 'different', 'background', 'cultures.', 'believe', 'build', 'new', 'connections', 'important', 'personal', 'growth', 'also', 'professional', 'development,', 'always', 'eager', 'expand', 'network', 'learn', 'others.']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# AGREEABLENESS

# take all the words in the candidate response into a list
agreeableness_response_words = agreeableness_response.split()

# CONVERT TO LOWERCASE
# Convert all words in the list to lowercase using list comprehension
agreeableness_response_words = [word.lower() for word in agreeableness_response_words]


# STOPWORD REMOVAL
import nltk
from nltk.corpus import stopwords

# Download the stopwords corpus if not already downloaded
nltk.download('stopwords')

# Get the set of stopwords
stop_words = set(stopwords.words('english'))

# Remove the stopwords from the list
agreeableness_response_words = [word for word in agreeableness_response_words if word.lower() not in stop_words]


# LEMMATIZATION
# Initialize the WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Lemmatize all words in the list using list comprehension
agreeableness_response_words = [lemmatizer.lemmatize(word, pos='v') for word in agreeableness_response_words]

# Print the lemmatized list
print(agreeableness_response_words, '\n')
# Out:
# ['handle', 'feedback', 'criticism', 'others', 'constructively', 'positively.', 'firstly,', 'listen', 'carefully', 'feedback', 'try', 'understand', 'perspective', 'person', 'provide', 'it.', 'ask', 'clarify', 'question', 'gain', 'better', 'understand', 'expectations', 'improve.', 'take', 'feedback', 'personally', 'remain', 'open', 'suggestions', 'improvement.', 'take', 'time', 'reflect', 'feedback', 'develop', 'action', 'plan', 'address', 'areas', 'improvement.', 'proactive', 'seek', 'feedback', 'view', 'opportunity', 'learn', 'grow', 'professionally.', 'ultimately,', 'strive', 'use', 'feedback', 'improve', 'performance', 'achieve', 'better', 'outcomes', 'work.']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# NEUROTICISM

# take all the words in the candidate response into a list
neuroticism_response_words = neuroticism_response.split()

# CONVERT TO LOWERCASE
# Convert all words in the list to lowercase using list comprehension
neuroticism_response_words = [word.lower() for word in neuroticism_response_words]


# STOPWORD REMOVAL
import nltk
from nltk.corpus import stopwords

# Download the stopwords corpus if not already downloaded
nltk.download('stopwords')

# Get the set of stopwords
stop_words = set(stopwords.words('english'))

# Remove the stopwords from the list
neuroticism_response_words = [word for word in neuroticism_response_words if word.lower() not in stop_words]


# LEMMATIZATION
# Initialize the WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Lemmatize all words in the list using list comprehension
neuroticism_response_words = [lemmatizer.lemmatize(word, pos='v') for word in neuroticism_response_words]

# Print the lemmatized list
print(neuroticism_response_words, '\n')
# Out:
# ['sure,', 'time', 'work', 'project', 'tight', 'deadline,', 'face', 'setback', 'due', 'unforeseen', 'technical', 'difficulties.', 'take', 'step', 'back,', 'analyze', 'situation,', 'communicate', 'openly', 'team', 'issue.', 'research', 'propose', 'several', 'solutions,', 'work', 'together', 'select', 'best', 'option.', 'despite', 'add', 'pressure', 'long', 'hours,', 'remain', 'calm', 'focus', 'task', 'hand.', 'end,', 'able', 'overcome', 'challenge', 'complete', 'project', 'time,', 'successful', 'outcome.', 'experience', 'teach', 'importance', 'stay', 'calm', 'pressure,', 'maintain', 'clear', 'communication,', 'proactive', 'find', 'solutions', 'difficult', 'situations.']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Comparing Candidate Response

# %% [markdown]
# score = (number of expected words in text(n) / total number of expected words(N)) * 100

# %% [markdown]
# ##I.TF-IDF

# %%
# TF-IDF

Openness_tokens = ['new', 
                   'risk', 
                   'try', 
                   'believe', 
                   'learn', 
                   'opportunity', 
                   'potential', 
                   'experience', 
                   'challenge', 
                   'growth', 
                   'look', 
                   'explore', 
                   'enjoy', 
                   'seek']

Concientiousness_tokens = ['work', 
                           'time', 
                           'ensure', 
                           'task', 
                           'complete', 
                           'accurately', 
                           'deadline', 
                           'prioritize']

Extraversion_tokens = ['connection', 
                       'people', 
                       'relationship', 
                       'social', 
                       'meeting', 
                       'building', 
                       'experience', 
                       'opportunity', 
                       'professional']

Agreeableness_tokens = ['feedback', 
                        'believe', 
                        'approach', 
                        'understand', 
                        'ask', 
                        'person', 
                        'listen', 
                        'learn', 
                        'opportunity', 
                        'help']

Neuroticism_tokens = ['problem', 
                      'stress', 
                      'difficult', 
                      'challenge', 
                      'stressful', 
                      'break']

# %%
# OPENNESS

# Find the common words in the two lists
openness_common = set(openness_response_words) & set(Openness_tokens)

# Print the common words in the candidate response and the extracted tokens for the trait
print(openness_common)
# Out:
# {'new', 'experience', 'enjoy', 'seek', 'learn', 'challenge', 'believe', 'risk'}

# %%
# Calculate level of 'Openness' trait for candidate

Openness_score = len(openness_common)/len(Openness_tokens)*5
print('Candidate Score for \'Openness\' trait: ', Openness_score)
# Out:
# Candidate Score for 'Openness' trait:  2.8571428571428568

# %%
# CONCIENTIOUSNESS

# Find the common words in the two lists
concientiousness_common = set(concientiousness_response_words) & set(Concientiousness_tokens)

# Print the common words in the candidate response and the extracted tokens for the trait
print(concientiousness_common)
# Out:
# {'task', 'work', 'prioritize', 'ensure'}

# %%
# Calculate level of 'Concientiousness' trait for candidate

Concientiousness_score = len(concientiousness_common)/len(Concientiousness_tokens)*5
print('Candidate Score for \'Concientiousness\' trait: ', Concientiousness_score)
# Out:
# Candidate Score for 'Concientiousness' trait:  2.5

# %%
# EXTRAVERSION

# Find the common words in the two lists
extraversion_common = set(extraversion_response_words) & set(Extraversion_tokens)

# Print the common words in the candidate response and the extracted tokens for the trait
print(extraversion_common)
# Out:
# {'people', 'social', 'professional'}

# %%
# Calculate level of 'Extraversion' trait for candidate

Extraversion_score = len(extraversion_common)/len(Extraversion_tokens)*5
print('Candidate Score for \'Extraversion\' trait: ', Extraversion_score)
# Out:
# Candidate Score for 'Extraversion' trait:  1.6666666666666665

# %%
# AGREEABLENESS

# Find the common words in the two lists
agreeableness_common = set(agreeableness_response_words) & set(Agreeableness_tokens)

# Print the common words in the candidate response and the extracted tokens for the trait
print(agreeableness_common)
# Out:
# {'ask', 'opportunity', 'listen', 'learn', 'understand', 'feedback', 'person'}

# %%
# Calculate level of 'Agreeableness' trait for candidate

Agreeableness_score = len(agreeableness_common)/len(Agreeableness_tokens)*5
print('Candidate Score for \'Agreeableness\' trait: ', Agreeableness_score)
# Out:
# Candidate Score for 'Agreeableness' trait:  3.5

# %%
# NEUROTICISM

# Find the common words in the two lists
neuroticism_common = set(neuroticism_response_words) & set(Neuroticism_tokens)

# Print the common words in the candidate response and the extracted tokens for the trait
print(neuroticism_common)
# Out:
# {'challenge', 'difficult'}

# %%
# Calculate level of 'Neuroticism' trait for candidate

Neuroticism_score = len(neuroticism_common)/len(Neuroticism_tokens)*5
print('Candidate Score for \'Neuroticism\' trait: ', Neuroticism_score)
# Out:
# Candidate Score for 'Neuroticism' trait:  1.6666666666666665

# %% [markdown]
# ##II.BERT

# %%
# BERT

Openness_tokens_BERT = ['adventurousness',
'adventurous',
'thrill',
'motivate',
'risktaking',
'explore',
'develop',
'potential',
'passion',
'risk',
'activity',
'knowledge',
'risktaker']

Concientiousness_tokens_BERT = ['task',
'outline',
'checklist', 
'list',
'decisionmaking',
'organize',
'completion',
'priority',
'urgency',
'progress',
'workload',
'initialtive',
'manage',
'milestone',
'management',
'revision',
'productivity']

Extraversion_tokens_BERT = ['social',
'socialize',
'group',
'meeting',
'friendly',
'conversation',
'personable',
'partner',
'collaboration']

Agreeableness_tokens_BERT = ['attentively',
'rapport',
'appreciation',
'receptive',
'gratitude',
'conversation',
'progress',
'activity',
'review',
'develop']

Neuroticism_tokens_BERT = ['stressmanagement',
'stressful',
'overwhelmed',
'tension',
'focus',
'strength']

# %%
# OPENNESS

# Find the common words in the two lists
openness_common = set(openness_response_words) & set(Openness_tokens_BERT)

# Print the common words in the candidate response and the extracted tokens for the trait
print(openness_common)
# Out:
# {'risk'}

# %%
# Calculate level of 'Openness' trait for candidate

Openness_score_BERT = len(openness_common)/len(Openness_tokens_BERT)*5
print('Candidate Score for \'Openness\' trait: ', Openness_score_BERT)
# Out:
# Candidate Score for 'Openness' trait:  0.38461538461538464

# %%
# CONCIENTIOUSNESS

# Find the common words in the two lists
concientiousness_common = set(concientiousness_response_words) & set(Concientiousness_tokens_BERT)

# Print the common words in the candidate response and the extracted tokens for the trait
print(concientiousness_common)
# Out:
# {'task', 'productivity', 'completion', 'progress'}

# %%
# Calculate level of 'Concientiousness' trait for candidate

Concientiousness_score_BERT = len(concientiousness_common)/len(Concientiousness_tokens)*5
print('Candidate Score for \'Concientiousness\' trait: ', Concientiousness_score_BERT)
# Out:
# Candidate Score for 'Concientiousness' trait:  2.5

# %%
# EXTRAVERSION

# Find the common words in the two lists
extraversion_common = set(extraversion_response_words) & set(Extraversion_tokens_BERT)

# Print the common words in the candidate response and the extracted tokens for the trait
print(extraversion_common)
# Out:
# {'social'}

# %%
# Calculate level of 'Extraversion' trait for candidate

Extraversion_score_BERT = len(extraversion_common)/len(Extraversion_tokens)*5
print('Candidate Score for \'Extraversion\' trait: ', Extraversion_score_BERT)
# Out:
# Candidate Score for 'Extraversion' trait:  0.5555555555555556

# %%
# AGREEABLENESS

# Find the common words in the two lists
agreeableness_common = set(agreeableness_response_words) & set(Agreeableness_tokens)

# Print the common words in the candidate response and the extracted tokens for the trait
print(agreeableness_common)
# Out:
# {'ask', 'opportunity', 'listen', 'learn', 'understand', 'feedback', 'person'}

# %%
# Calculate level of 'Agreeableness' trait for candidate

Agreeableness_score_BERT = len(agreeableness_common)/len(Agreeableness_tokens)*5
print('Candidate Score for \'Agreeableness\' trait: ', Agreeableness_score_BERT)
# Out:
# Candidate Score for 'Agreeableness' trait:  3.5

# %%
# NEUROTICISM

# Find the common words in the two lists
neuroticism_common = set(neuroticism_response_words) & set(Neuroticism_tokens)

# Print the common words in the candidate response and the extracted tokens for the trait
print(neuroticism_common)
# Out:
# {'challenge', 'difficult'}

# %%
# Calculate level of 'Neuroticism' trait for candidate

Neuroticism_score_BERT = len(neuroticism_common)/len(Neuroticism_tokens)*5
print('Candidate Score for \'Neuroticism\' trait: ', Neuroticism_score_BERT)
# Out:
# Candidate Score for 'Neuroticism' trait:  1.6666666666666665

# %% [markdown]
# # Saving Candidate Scores

# %%
# Create a sample dataframe
scores = {'openness': [Openness_score],
        'conscientiousness': [Concientiousness_score],
        'extraversion': [Extraversion_score],
        'agreeableness': [Agreeableness_score],
        'neuroticism': [Neuroticism_score]}

cand_scores = pd.DataFrame(scores)
cand_scores
# Out:
#    openness  conscientiousness  extraversion  agreeableness  neuroticism
# 0  2.857143                2.5      1.666667            3.5     1.666667

# %%
cand_scores.to_csv('candidate_scores.csv', index=False)
