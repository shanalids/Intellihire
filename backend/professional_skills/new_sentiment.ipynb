# %%
import pandas as pd
from textblob import TextBlob
from nltk.sentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt

# Load the CSV file into a DataFrame
data = pd.read_csv('Responses.csv')

# Get the list of column names except the first column
columns_to_analyze = data.columns[1:]

# Initialize the SentimentIntensityAnalyzer
# Step 2: Perform sentiment analysis
sid = SentimentIntensityAnalyzer()
sentiment_scores = sid.polarity_scores(extracted_text)

# Step 3: Visualize the sentiment
# Prepare data for visualization
labels = ['Positive', 'Negative', 'Neutral']
sizes = [sentiment_scores['pos'], sentiment_scores['neg'], sentiment_scores['neu']]
colors = ['blue', 'red', 'green']

# Create pie chart
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.axis('equal')

# Set title
plt.title('Sentiment Analysis')

# Display the chart
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 15
#      12 # Initialize the SentimentIntensityAnalyzer
#      13 # Step 2: Perform sentiment analysis
#      14 sid = SentimentIntensityAnalyzer()
# ---> 15 sentiment_scores = sid.polarity_scores(extracted_text)
#      17 # Step 3: Visualize the sentiment
#      18 # Prepare data for visualization
#      19 labels = ['Positive', 'Negative', 'Neutral']
#
# NameError: name 'extracted_text' is not defined

# %%
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt

# Read CSV file into a DataFrame
csv_file_path = 'Responses.csv'
data = pd.read_csv(csv_file_path)

# Exclude the first column (assuming it's the index column)
columns_to_analyze = data.columns[1:]

# Step 2: Perform sentiment analysis
sid = SentimentIntensityAnalyzer()

# Calculate sentiment scores for each column
sentiment_scores = []
for column in columns_to_analyze:
    column_scores = [sid.polarity_scores(str(response)) for response in data[column]]
    sentiment_scores.extend(column_scores)

# Calculate overall sentiment distribution
labels = ['Positive', 'Negative', 'Neutral']
sentiment_distribution = [0, 0, 0]

for score in sentiment_scores:
    max_sentiment = max(score, key=score.get)
    
    if max_sentiment == 'pos':
        sentiment_distribution[0] += 1
    elif max_sentiment == 'neg':
        sentiment_distribution[1] += 1
    else:
        sentiment_distribution[2] += 1

# Create a single pie chart for overall sentiment distribution
colors = ['blue', 'red', 'green']
plt.figure()
plt.pie(sentiment_distribution, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Overall Sentiment Analysis')
plt.axis('equal')
plt.show()

# %%
columns_to_analyze
# Out:
# Index(['How would you describe your collaboration with (CandidName)',
#        'Can you highlight any significant accomplishments or achievements that (CandidName) attained while working for you?',
#        'For this (position name) position, we need someone who can perform best. How would you rate (CandidName) on each?',
#        'What are (CandidName)’s greatest strengths?',
#        'In your observations, what areas, if any, could (CandidName) improve upon? Can you identify any potential areas for growth?',
#        'Based on your interactions, how would you evaluate (CandidName)'s communication skills and their ability to actively listen?',
#        'In your experience, does (CandidName) work better alone or with a team?',
#        'Please share an instance where (CandidName) encountered a setback or faced a challenging situation during their academic journey, and how did they handle it?',
#        'Did (CandidName) receive any promotions while at your company?',
#        'Based on your overall experience with (CandidName) as an employee, would you recommend them for the program or position they are currently pursuing? ',
#        'Your recommendation on the candidate(descriptive)'],
#       dtype='object')

# %%
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt

# Read CSV file into a DataFrame
csv_file_path = 'responses.csv'
data = pd.read_csv(csv_file_path, skiprows=[0])  # Skip the first row

# Exclude the first column (assuming it's the index column)
columns_to_analyze = data.columns[1:]

# Step 2: Perform sentiment analysis
sid = SentimentIntensityAnalyzer()

# Calculate sentiment scores for each column
sentiment_scores = []
for column in columns_to_analyze:
    column_scores = [sid.polarity_scores(str(response)) for response in data[column]]
    sentiment_scores.extend(column_scores)

# Calculate overall sentiment distribution
labels = ['Positive', 'Negative', 'Neutral']
sentiment_distribution = [0, 0, 0]

for score in sentiment_scores:
    max_sentiment = max(score, key=score.get)
    
    if max_sentiment == 'pos':
        sentiment_distribution[0] += 1
    elif max_sentiment == 'neg':
        sentiment_distribution[1] += 1
    else:
        sentiment_distribution[2] += 1

# Create a single pie chart for overall sentiment distribution
colors = ['blue', 'red', 'green']
plt.figure()
plt.pie(sentiment_distribution, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Overall Sentiment Analysis')
plt.axis('equal')
plt.show()

# %%
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt

# Read CSV file into a DataFrame
csv_file_path = 'Responses.csv'
data = pd.read_csv(csv_file_path, skiprows=[0])  # Skip the first row

# Exclude the first column (assuming it's the index column)
columns_to_analyze = data.columns[1:]

# Step 2: Perform sentiment analysis
sid = SentimentIntensityAnalyzer()

# Calculate sentiment scores for each column
sentiment_scores = {}
for column in columns_to_analyze:
    column_scores = [sid.polarity_scores(str(response)) for response in data[column]]
    sentiment_scores[column] = column_scores

# Calculate overall sentiment distribution
labels = ['Positive', 'Negative', 'Neutral']
sentiment_distribution = [0, 0, 0]

for scores_list in sentiment_scores.values():
    for score in scores_list:
        max_sentiment = max(score, key=score.get)
        
        if max_sentiment == 'pos':
            sentiment_distribution[0] += 1
        elif max_sentiment == 'neg':
            sentiment_distribution[1] += 1
        else:
            sentiment_distribution[2] += 1

# Create a single pie chart for overall sentiment distribution
colors = ['blue', 'red', 'green']
plt.figure()
plt.pie(sentiment_distribution, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Overall Sentiment Analysis')
plt.axis('equal')
plt.show()

# %%
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt

# Read CSV file into a DataFrame, skipping the first row (index 0)
csv_file_path = 'Responses.csv'
data = pd.read_csv(csv_file_path, skiprows=[0])

# Exclude the first column (timestamp) and the first row (index 0)
columns_to_analyze = data.columns[1:]
data = data.iloc[:, 1:]

# Step 2: Perform sentiment analysis
sid = SentimentIntensityAnalyzer()

# Calculate sentiment scores for each column
sentiment_scores = {}
for column in columns_to_analyze:
    column_scores = [sid.polarity_scores(str(response)) for response in data[column]]
    sentiment_scores[column] = column_scores

# Calculate overall sentiment distribution
labels = ['Positive', 'Negative', 'Neutral']
sentiment_distribution = [0, 0, 0]

for scores_list in sentiment_scores.values():
    for score in scores_list:
        max_sentiment = max(score, key=score.get)
        
        if max_sentiment == 'pos':
            sentiment_distribution[0] += 1
        elif max_sentiment == 'neg':
            sentiment_distribution[1] += 1
        else:
            sentiment_distribution[2] += 1

# Create a single pie chart for overall sentiment distribution
colors = ['blue', 'red', 'green']
plt.figure()
plt.pie(sentiment_distribution, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Overall Sentiment Analysis')
plt.axis('equal')
plt.show()

# %%
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt

# Read CSV file into a DataFrame
csv_file_path = 'Responses.csv'
data = pd.read_csv(csv_file_path)

# Exclude the first column (timestamp)
columns_to_analyze = data.columns[1:]
data = data[columns_to_analyze]

# Step 2: Perform sentiment analysis
sid = SentimentIntensityAnalyzer()

# Calculate sentiment scores for each column
sentiment_scores = {}
for column in columns_to_analyze:
    column_scores = [sid.polarity_scores(str(response)) for response in data[column]]
    sentiment_scores[column] = column_scores

# Calculate overall sentiment distribution
labels = ['Positive', 'Negative', 'Neutral']
sentiment_distribution = [0, 0, 0]

for scores_list in sentiment_scores.values():
    for score in scores_list:
        max_sentiment = max(score, key=score.get)
        
        if max_sentiment == 'pos':
            sentiment_distribution[0] += 1
        elif max_sentiment == 'neg':
            sentiment_distribution[1] += 1
        else:
            sentiment_distribution[2] += 1

# Create a single pie chart for overall sentiment distribution
colors = ['blue', 'red', 'green']
plt.figure()
plt.pie(sentiment_distribution, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Overall Sentiment Analysis')
plt.axis('equal')
plt.show()

# %%
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt

# Function to perform sentiment analysis and visualization for a specific row
def analyze_sentiment_and_visualize(row):
    # Step 2: Perform sentiment analysis
    sid = SentimentIntensityAnalyzer()

    # Calculate sentiment scores for each column
    sentiment_scores = {}
    for column, response in row.items():
        response = str(response)
        score = sid.polarity_scores(response)
        sentiment_scores[column] = score

    # Calculate overall sentiment distribution
    labels = ['Positive', 'Negative', 'Neutral']
    sentiment_distribution = [0, 0, 0]

    for score in sentiment_scores.values():
        max_sentiment = max(score, key=score.get)
        
        if max_sentiment == 'pos':
            sentiment_distribution[0] += 1
        elif max_sentiment == 'neg':
            sentiment_distribution[1] += 1
        else:
            sentiment_distribution[2] += 1

    # Create a single pie chart for sentiment distribution
    colors = ['blue', 'red', 'green']
    plt.figure()
    plt.pie(sentiment_distribution, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
    plt.title('Sentiment Analysis')
    plt.axis('equal')
    plt.show()

# Read CSV file into a DataFrame
csv_file_path = 'responses.csv'
data = pd.read_csv(csv_file_path)

# Exclude the first column (timestamp)
columns_to_analyze = data.columns[1:]
data = data[columns_to_analyze]

# Get the last row in the DataFrame
last_row = data.iloc[-1]

# Apply sentiment analysis and visualization to the last row
analyze_sentiment_and_visualize(last_row)
