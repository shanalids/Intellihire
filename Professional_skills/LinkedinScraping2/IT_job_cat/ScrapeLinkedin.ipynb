# %%
import requests
api_endpoint = 'https://nubela.co/proxycurl/api/v2/linkedin'
linkedin_profile_url = 'https://www.linkedin.com/in/chanuxbro/'
api_key = 'jtiOFtUah7GkK79fcRQqww'
headers = {'Authorization': 'Bearer ' + api_key}

response = requests.get(api_endpoint,
                        params={'url': linkedin_profile_url,'skills': 'include'},
                        headers=headers)

# %%
profile_data = response.json()
profile_data
# Out:
# {'public_identifier': 'chanuxbro',
#  'profile_pic_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/person/chanuxbro/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20230813%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20230813T071628Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=eb3dda51522f33b94ba48a9587a868a42c6225e5d4f2f0fa5634a160beae7577',
#  'background_cover_image_url': None,
#  'first_name': 'Chanux',
#  'last_name': 'Bro',
#  'full_name': 'Chanux Bro',
#  'follower_count': None,
#  'occupation': 'Founder and CEO at Chanux Bro (Private) Limited',
#  'headline': 'Software Engineer, Social Media Consultant, Most Popular Socialmedia personality in LK 🇱🇰 awarded',
#  'summary': 'Be Your Own Boss 😉',
#  'country': 'LK',
#  'country_full_name': 'Sri Lanka',
#  'city': None,
#  'state': None,
#  'experiences': [{'starts_at': {'day': 1, 'month': 1, 'year': 2014},
#    'ends_at': None,
#    'company': 'Sinlix',
#    'company_linkedin_profile_url': None,
#    'title': 'Software Engineer',
#    'description': None,
#    'location': None,
#    'logo_url': None},
#   {'starts_at': {'day': 1, 'month': 4, 'year': 2010},
#    'ends_at': None,
#    'company': 'Sinlix Inc',
#    'company_linkedin_profile_url': None,
#    'title': 'Social Media Consultant',
#    'description': None,
#    'location': 'Sri Lanka',
#    'logo_url': None},
#   {'starts_at': {'day': 1, 'month': 1, 'year': 2009},
#    'ends_at': None,
#    'company': 'Chanux Bro (Private) Limited',
#    'company_linkedin_profile_url': None,
#    'title': 'Founder and CEO',
#    'description': None,
#    'location': 'Colombo, Western, Sri Lanka',
#    'logo_url': None},
#   {'starts_at': {'day': 1, 'month': 3, 'year': 2008},
#    'ends_at': None,
#    'company': 'YouTube',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/youtube/',
#    'title': 'Youtuber',
#    'description': 'Most Popular Youtuber 2017 Sri Lanka Social media award',
#    'location': 'Sri Lanka',
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/youtube/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20230813%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20230813T071628Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=0d9532e853744783fe664864d25555b7d4e1dc7675b14ba464584043df233411'}],
#  'education': [],
#  'languages': [],
#  'accomplishment_organisations': [],
#  'accomplishment_publications': [],
#  'accomplishment_honors_awards': [{'title': 'Most Popular Education Vloger in Sri Lanka',
#    'issuer': 'Mashable Social Media Day',
#    'issued_on': None,
#    'description': 'Most Popular Education Vloger in Sri Lanka - Chanux Bro'},
#   {'title': 'Most Popular Social Media Personality In Sri Lanka',
#    'issuer': 'Mashable Social Media Day',
#    'issued_on': None,
#    'description': 'Most Popular Social Media Personality In Sri Lanka'},
#   {'title': 'Most Popular Tech YouTuber In Sri Lanka Google IO award ',
#    'issuer': 'Google / Dialog',
#    'issued_on': None,
#    'description': 'Most Popular Tech YouTuber In Sri Lanka Google IO award '},
#   {'title': 'Most Popular YouTuber In Sri Lanka - Edu Award ',
#    'issuer': 'Mashable Social Media Day',
#    'issued_on': None,
#    'description': 'Most Popular YouTuber In Sri Lanka - Edu Award for Chanux bro YouTube Channel'},
#   {'title': 'YouTube Silver Play Button Award',
#    'issuer': 'Google and YouTube',
#    'issued_on': None,
#    'description': 'YouTube Silver Play Button Award for Chanux Bro YouTube Channel.'}],
#  'accomplishment_patents': [],
#  'accomplishment_courses': [],
#  'accomplishment_projects': [],
#  'accomplishment_test_scores': [],
#  'volunteer_work': [],
#  'certifications': [],
#  'connections': None,
#  'people_also_viewed': [{'link': 'https://www.linkedin.com/in/stephanie-sansoni-a9930116b',
#    'name': 'Stephanie Sansoni',
#    'summary': 'Musical Artist & Social Media Personality',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/nisalhe',
#    'name': 'Nisal Hewagamage',
#    'summary': 'Founder of Xydder 3D, Youtuber, MSc Student',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/chehani-jayawardena',
#    'name': 'Chehani Jayawardena',
#    'summary': 'Associate QA Lead at CodeGen International, Educational YouTube Content Creator, Social Media Influencer',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/naamini-jayaratne-529517a5',
#    'name': 'Naamini Jayaratne',
#    'summary': 'Content Creator, Branding and Social Media Manager & Wellness Coach',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/pasindu-jayasinghe-603883ba',
#    'name': 'Pasindu Jayasinghe',
#    'summary': 'Founder at Seya Solutions',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/malindaonline',
#    'name': 'Malinda Alahakoon',
#    'summary': 'YouTuber',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/kalith-yuran-9bb863211',
#    'name': 'Kalith Yuran',
#    'summary': 'Content Creator | Director | Software Engineer | Athlete',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/madusanka',
#    'name': 'Madusanka Premaratne',
#    'summary': 'Digital Entrepreneur • Looking for Investments & Business Partnerships for SaaS Products • Founder of Knovik • Director of Sri Lanka’s Largest Digital Entrepreneurs Society (OECSL)',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/kavini-welarathna-2ba18b173',
#    'name': 'Kavini Welarathna',
#    'summary': 'Software Engineer at Pearson',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/dhanika',
#    'name': 'Dhanika Perera',
#    'summary': 'Changemaking Entrepreneur, Founder of Helakuru, PayHere, HelaPay & Esana, CEO of Bhasha',
#    'location': None}],
#  'recommendations': [],
#  'activities': [],
#  'similarly_named_profiles': [],
#  'articles': [],
#  'groups': [],
#  'skills': ['Linux',
#   'HTML',
#   'Image Processing',
#   'Artificial Intelligence',
#   'Big Data Analytics',
#   'Project Management',
#   'E-commerce SEO',
#   'Entrepreneurship',
#   'Social Entrepreneurship',
#   'Mobile Application Development',
#   'Business Strategy',
#   'Consulting',
#   'Cyber-security',
#   'Information Security Consultancy',
#   'Online Marketing Analysis',
#   'PHP',
#   'IT Consulting',
#   'Social Media Consulting',
#   'E-commerce Consulting',
#   'Start-up Consulting'],
#  'inferred_salary': None,
#  'gender': None,
#  'birth_date': None,
#  'industry': None,
#  'extra': None,
#  'interests': [],
#  'personal_emails': [],
#  'personal_numbers': []}

# %%
profile_data['experiences']
# Out:
# [{'starts_at': {'day': 1, 'month': 1, 'year': 2014},
#   'ends_at': None,
#   'company': 'Sinlix',
#   'company_linkedin_profile_url': None,
#   'title': 'Software Engineer',
#   'description': None,
#   'location': None,
#   'logo_url': None},
#  {'starts_at': {'day': 1, 'month': 4, 'year': 2010},
#   'ends_at': None,
#   'company': 'Sinlix Inc',
#   'company_linkedin_profile_url': None,
#   'title': 'Social Media Consultant',
#   'description': None,
#   'location': 'Sri Lanka',
#   'logo_url': None},
#  {'starts_at': {'day': 1, 'month': 1, 'year': 2009},
#   'ends_at': None,
#   'company': 'Chanux Bro (Private) Limited',
#   'company_linkedin_profile_url': None,
#   'title': 'Founder and CEO',
#   'description': None,
#   'location': 'Colombo, Western, Sri Lanka',
#   'logo_url': None},
#  {'starts_at': {'day': 1, 'month': 3, 'year': 2008},
#   'ends_at': None,
#   'company': 'YouTube',
#   'company_linkedin_profile_url': 'https://www.linkedin.com/company/youtube/',
#   'title': 'Youtuber',
#   'description': 'Most Popular Youtuber 2017 Sri Lanka Social media award',
#   'location': 'Sri Lanka',
#   'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/youtube/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20230813%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20230813T071628Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=0d9532e853744783fe664864d25555b7d4e1dc7675b14ba464584043df233411'}]

# %%
csv_file = "Linkedin_results.csv"

# %%
results = profile_data['public_identifier'], profile_data['full_name'],profile_data['follower_count'], profile_data['occupation'],profile_data['headline'], profile_data['summary'], profile_data['country_full_name'], profile_data['city'], profile_data['experiences'][0],profile_data['industry'], profile_data['education'], profile_data['languages'], profile_data['accomplishment_honors_awards'],profile_data['accomplishment_patents'], profile_data['accomplishment_courses'], profile_data['accomplishment_projects'], profile_data['accomplishment_test_scores'],profile_data['certifications'], profile_data['connections'], profile_data['recommendations'], profile_data['skills'], profile_data['interests']

results
# Out:
# ('chanuxbro',
#  'Chanux Bro',
#  None,
#  'Founder and CEO at Chanux Bro (Private) Limited',
#  'Software Engineer, Social Media Consultant, Most Popular Socialmedia personality in LK 🇱🇰 awarded',
#  'Be Your Own Boss 😉',
#  'Sri Lanka',
#  None,
#  {'starts_at': {'day': 1, 'month': 1, 'year': 2014},
#   'ends_at': None,
#   'company': 'Sinlix',
#   'company_linkedin_profile_url': None,
#   'title': 'Software Engineer',
#   'description': None,
#   'location': None,
#   'logo_url': None},
#  None,
#  [],
#  [],
#  [{'title': 'Most Popular Education Vloger in Sri Lanka',
#    'issuer': 'Mashable Social Media Day',
#    'issued_on': None,
#    'description': 'Most Popular Education Vloger in Sri Lanka - Chanux Bro'},
#   {'title': 'Most Popular Social Media Personality In Sri Lanka',
#    'issuer': 'Mashable Social Media Day',
#    'issued_on': None,
#    'description': 'Most Popular Social Media Personality In Sri Lanka'},
#   {'title': 'Most Popular Tech YouTuber In Sri Lanka Google IO award ',
#    'issuer': 'Google / Dialog',
#    'issued_on': None,
#    'description': 'Most Popular Tech YouTuber In Sri Lanka Google IO award '},
#   {'title': 'Most Popular YouTuber In Sri Lanka - Edu Award ',
#    'issuer': 'Mashable Social Media Day',
#    'issued_on': None,
#    'description': 'Most Popular YouTuber In Sri Lanka - Edu Award for Chanux bro YouTube Channel'},
#   {'title': 'YouTube Silver Play Button Award',
#    'issuer': 'Google and YouTube',
#    'issued_on': None,
#    'description': 'YouTube Silver Play Button Award for Chanux Bro YouTube Channel.'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  None,
#  [],
#  ['Linux',
#   'HTML',
#   'Image Processing',
#   'Artificial Intelligence',
#   'Big Data Analytics',
#   'Project Management',
#   'E-commerce SEO',
#   'Entrepreneurship',
#   'Social Entrepreneurship',
#   'Mobile Application Development',
#   'Business Strategy',
#   'Consulting',
#   'Cyber-security',
#   'Information Security Consultancy',
#   'Online Marketing Analysis',
#   'PHP',
#   'IT Consulting',
#   'Social Media Consulting',
#   'E-commerce Consulting',
#   'Start-up Consulting'],
#  [])

# %%
profile_data['skills']
# Out:
# ['Linux',
#  'HTML',
#  'Image Processing',
#  'Artificial Intelligence',
#  'Big Data Analytics',
#  'Project Management',
#  'E-commerce SEO',
#  'Entrepreneurship',
#  'Social Entrepreneurship',
#  'Mobile Application Development',
#  'Business Strategy',
#  'Consulting',
#  'Cyber-security',
#  'Information Security Consultancy',
#  'Online Marketing Analysis',
#  'PHP',
#  'IT Consulting',
#  'Social Media Consulting',
#  'E-commerce Consulting',
#  'Start-up Consulting']

# %%
Skills = profile_data['skills']
Skills
# Out:
# ['Linux',
#  'HTML',
#  'Image Processing',
#  'Artificial Intelligence',
#  'Big Data Analytics',
#  'Project Management',
#  'E-commerce SEO',
#  'Entrepreneurship',
#  'Social Entrepreneurship',
#  'Mobile Application Development',
#  'Business Strategy',
#  'Consulting',
#  'Cyber-security',
#  'Information Security Consultancy',
#  'Online Marketing Analysis',
#  'PHP',
#  'IT Consulting',
#  'Social Media Consulting',
#  'E-commerce Consulting',
#  'Start-up Consulting']

# %%
# Open the file in write mode
with open('output.txt', 'w') as file:
    # Iterate over the list
    for item in Skills:
        # Write each item to the file
        file.write(item + '\n')
