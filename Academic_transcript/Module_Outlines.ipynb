# %% [markdown]
# # Importing the necessary Libraries

# %%
import pandas as pd
import numpy as np
import nltk
import re
from nltk import ngrams
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# # Loading the Module Outlines CSV file

# %%
# Load the CSV file
df = pd.read_csv('Module Outlines.csv')

# %%
df.head()
# Out:
#    Year  Semester    Code                      Module Title  \
# 0   1.0       1.0  IT1030         MATHEMATICS FOR COMPUTING
# 1   1.0       1.0  IT1010       Introduction to Programming
# 2   1.0       1.0  IT1040              Communication Skills
# 3   1.0       1.0  IT1020  Introduction to Computer Systems
# 4   1.0       2.0  IT1080     English for Academic Purposes
#
#                                   Module Description
# 0  Logic Control, Number Systems, Differentiation...
# 1  Introducion to fundamental programming concept...
# 2  Speech test, spot tests and a midterm examinat...
# 3  Essentials of computer systems and computer ne...
# 4  Necessary English language skills and all the ...

# %% [markdown]
# # Define the desired n-gram range

# %%
# Define the desired n-gram range
n = 3  # Change this value for different n-gram lengths

# %% [markdown]
# # Downloading the NLTK libraries

# %%
import nltk
nltk.download('punkt')

import nltk
nltk.download('stopwords')

nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %% [markdown]
# # Extract a specific column by column name

# %%
# Extract a specific column by column name
module_desc_column = df['Module Description']

# Print the extracted column data
print(module_desc_column)
# Out:
# 0      Logic Control, Number Systems, Differentiation...
# 1      Introducion to fundamental programming concept...
# 2      Speech test, spot tests and a midterm examinat...
# 3      Essentials of computer systems and computer ne...
# 4      Necessary English language skills and all the ...
#                              ...
# 151    This module exposes future IT professionals to...
# 152    The objective of the module is to provide an o...
# 153    This module aims to develop skills of designin...
# 154    This course will cover the necessary basics of...
# 155    This module helps students to develop an under...
# Name: Module Description, Length: 156, dtype: object

# %% [markdown]
# # Preprocess the module description column

# %%
# Create a list to store the words in each row
words_per_row = []

# Iterate over the rows and split the module description into words
for desc in module_desc_column:
    if isinstance(desc, str):
        words = desc.lower().split()  # Split the description into lowercase words

        # Remove stop words
        stop_words = set(stopwords.words("english"))
        words = [word for word in words if word not in stop_words]
        
          # Remove unwanted characters using regular expressions
        words = [re.sub(r"[^a-zA-Z0-9]", "", word) for word in words]
        
        # Remove empty strings
        words = [word for word in words if word]
        
        words_per_row.append(words)  # Add the words to the list

# Print the lists of words per row
for words in words_per_row:
    print(words)
# Out:
# ['logic', 'control', 'number', 'systems', 'differentiation', 'integration', 'functions', 'counting', 'graph', 'theory', 'matrices', 'finitestate', 'machines']
# ['introducion', 'fundamental', 'programming', 'concepts', 'specifically', 'procedural', 'programming', 'paradigm', 'topics', 'include', 'data', 'types', 'control', 'structures', 'functions', 'pointers', 'arrays', 'files', 'recursion', 'mechanics', 'testing', 'debugging', 'students', 'also', 'get', 'hands', 'experience', 'develop', 'applications', 'using', 'c', 'language', 'linux', 'operation', 'system']
# ['speech', 'test', 'spot', 'tests', 'midterm', 'examination', 'final', 'examination', 'comprehensive', 'exam', 'based', 'topics', 'covered', 'semester']
# ['essentials', 'computer', 'systems', 'computer', 'networks', 'order', 'prepare', 'students', 'advanced', 'courses', 'covers', 'fundamentals', 'computer', 'organization', 'combinational', 'sequential', 'logic', 'circuits', 'data', 'communication', 'computer', 'networks', 'end', 'course', 'students', 'able', 'explain', 'computer', 'systems', 'organized', 'layered', 'communication', 'models', 'basic', 'operation', 'computer', 'networks']
# ['necessary', 'english', 'language', 'skills', 'academic', 'practices', 'require', 'pursue', 'university', 'studies']
# ['understand', 'apply', 'basic', 'concepts', 'object', 'oriented', 'programming', 'design', 'solutions', 'identifying', 'classes', 'relationships', 'object', 'oriented', 'analysis', 'design', 'implement', 'solution', 'given', 'problem', 'using', 'c', 'language']
# ['objective', 'module', 'introduce', 'software', 'engineering', 'concepts', 'topics', 'discussed', 'module', 'include', 'requirement', 'specification', 'design', 'implementation', 'verification', 'validation', 'evolution', 'software', 'artifacts', 'further', 'students', 'able', 'appreciate', 'software', 'engineering', 'concepts', 'help', 'produce', 'maintain', 'software', 'products', 'softwareintensive', 'systems']
# ['mandatory', 'module', '1st', 'year', 'students', 'bsc', 'sp', 'hons', 'information', 'technology', 'streams', 'objective', 'unit', 'provide', 'overall', 'understanding', 'information', 'systems', 'data', 'modeling', 'students', 'mainly', 'understand', 'aspect', 'real', 'world', 'information', 'systems', 'including', 'business', 'process', 'modeling', 'relationship', 'data', 'modeling', 'introduced', 'relational', 'database', 'systems']
# ['explain', 'concepts', 'technologies', 'associated', 'internet', 'related', 'applications', 'identify', 'effective', 'use', 'social', 'media', 'organizations', 'individual', 'users', 'explain', 'fundamentals', 'ecommerce', 'application', 'domain', 'along', 'security', 'privacy', 'concerns', 'supportive', 'web', 'technologies', 'apply', 'modern', 'markup', 'languages', 'presentation', 'technologies', 'design', 'web', 'interfaces', 'implement', 'web', 'applications', 'using', 'client', 'server', 'side', 'scripting', 'languages', 'apply', 'standards', 'ui', 'design', 'principles', 'best', 'practices', 'enhance', 'usability', 'web', 'application', 'development', 'explain', 'importance', 'web', 'standards', 'digital', 'content', 'rights', 'usability', 'accessibility', 'initiatives', 'web', 'related', 'applications']
# ['unit', 'enables', 'student', 'understand', 'engineering', 'mathematics', 'special', 'emphasis', 'studying', 'applying', 'mathematical', 'techniques', 'engineering', 'systems', 'objective', 'unit', 'provide', 'students', 'skills', 'necessary', 'solve', 'various', 'mathematical', 'problems', 'encountered', 'engineering', 'electricalelectroniccomputer', 'engineering', 'particular']
# ['aim', 'module', 'cover', 'essentials', 'data', 'communications', 'computer', 'network', 'concepts', 'prepare', 'students', 'advanced', 'networking', 'courses', 'covers', 'essentials', 'computer', 'networks', 'internet', 'technologies', 'end', 'course', 'students', 'able', 'build', 'simple', 'lans', 'perform', 'basic', 'configurations', 'routers', 'switches', 'implement', 'ip', 'addressing', 'schemes']
# ['apply', 'object', 'oriented', 'concepts', 'java', 'language', 'validate', 'knowledge', 'concurrency', 'programming', 'synthesize', 'suitable', 'set', 'design', 'patterns', 'application', 'development', 'justify', 'usage', 'software', 'engineering', 'concepts', 'developing', 'application', 'apply', 'concurrency', 'programming', 'application', 'development']
# ['design', 'develop', 'maintain', 'database', 'cater', 'user', 'requirements', 'module', 'covers', 'conceptual', 'database', 'design', 'logical', 'database', 'design', 'schema', 'refinement', 'sql', 'database', 'programming', 'furthermore', 'students', 'obtain', 'handsonexperience', 'developing', 'database', 'performing', 'administrative', 'tasks', 'database', 'using', 'ms', 'sql', 'server']
# ['routing', 'switching', 'theory', 'configurations', 'tcp', 'ip', 'operations']
# ['major', 'components', 'operating', 'systems', 'practice', 'utilities', 'unix', 'system', 'administration', 'students', 'also', 'apply', 'knowledge', 'learn', 'lectures', 'tutorial', 'labs', 'complete', 'units', 'programming', 'assignment']
# ['object', 'oriented', 'analysis', 'design', 'using', 'unified', 'modeling', 'languageuml', 'tools', 'object', 'oriented', 'software', 'engineering', 'applying', 'design', 'patterns', 'software', 'testing', 'supportive', 'processes']
# ['essential', 'digital', 'electronic', 'concept', 'computer', 'networking', 'engineering', 'graduate', 'module', 'give', 'understanding', 'knowledge', 'signals', 'processing', 'keep', 'operation', 'computer', 'systems', 'network', 'module', 'covers', 'number', 'systems', 'sequential', 'logic', 'combinational', 'logic', 'basic', 'concept', 'covering', 'theories', 'applications']
# ['provide', 'understanding', 'theory', 'behind', 'descriptive', 'statistics', 'inferential', 'statistics', 'data', 'analysis', 'interpretation', 'outputs', 'obtained', 'using', 'statistical', 'software', 'basic', 'theory', 'covers', 'distribution', 'theory', 'statistical', 'inference', 'outputs', 'easily', 'understood', 'practical', 'sessions', 'consists', 'performing', 'different', 'statistical', 'techniques', 'different', 'data', 'using', 'r', 'software', 'package']
# ['understand', 'basic', 'analogue', 'electronic', 'engineering', 'concepts', 'objective', 'unit', 'provide', 'students', 'knowledge', 'necessa', 'understand', 'various', 'analog', 'electronic', 'devices', 'operate', 'provide', 'skills', 'design', 'develop', 'analog', 'electronic', 'circuitry', 'using', 'discrete', 'devices', 'integrated', 'circuits', 'syllabus', 'contains', 'introduction', 'semiconductors', 'diodes', 'transistors', 'operational', 'amplifiers', 'frequency', 'response', 'filters']
# ['oracle', 'database', 'components', 'architecture', 'creating', 'controlling', 'database', 'installing', 'oracle', 'database', 'software', 'database', 'creation', 'managing', 'oracle', 'instanceconfiguring', 'oracle', 'network', 'environment', 'user', 'administration', 'security', 'managing', 'undo', 'data', 'backup', 'recovery', 'concept', 'performing', 'database', 'backup']
# ['routing', 'concepts', 'static', 'routing', 'dynamic', 'routing', 'switched', 'networks', 'switch', 'configuration', 'vlans', 'access', 'control', 'lists', 'dhcp', 'nat', 'ipv4', 'device', 'discovery', 'management', 'maintenance']
# ['design', 'develop', 'database', 'solutions', 'real', 'world', 'applications', 'use', 'relational', 'query', 'languages', 'database', 'programming', 'applications', 'evaluate', 'query', 'plans', 'recommend', 'solutions', 'speed', 'database', 'servers', 'design', 'implement', 'database', 'maintenance', 'plans', 'propose', 'appropriate', 'solutions', 'address', 'security', 'performance', 'concerns', 'databases']
# ['introduction', 'cyber', 'security', 'security', 'controls', 'risk', 'management', 'malicious', 'software', 'user', 'authentication', 'access', 'control', 'introduction', 'cryptography', 'cryptographic', 'hashes', 'symmetric', 'cryptograph', 'asymmetric', 'cryptography', 'public', 'key', 'infrastructure', 'trusted', 'systems', 'multilevel', 'security', 'os', 'security', 'general', 'legal', 'ethical', 'aspects', 'information', 'security']
# ['operating', 'systems', 'structure', 'process', 'management', 'cpu', 'scheduling', 'basic', 'concepts', 'process', 'synchronization', 'background', 'memory', 'management', 'deadlocks', 'real', 'time', 'systems', 'system', 'characteristics', 'system', 'protection', 'security', 'secondary', 'storage', 'structure', 'io', 'systems', 'io', 'hardware', 'file', 'systems']
# ['structured', 'analysis', 'design', 'information', 'systems', 'students', 'learn', 'analyze', 'business', 'problems', 'design', 'information', 'systems', 'structured', 'approach', 'students', 'also', 'gain', 'handson', 'experience', 'computeraided', 'software', 'engineering', 'case', 'tools', 'used', 'structured', 'analysis', 'design', 'module', 'students', 'also', 'consider', 'organizational', 'matters', 'implementation', 'maintenance', 'information', 'systems', 'is']
# ['module', 'provides', 'students', 'knowledge', 'problem', 'solving', 'difficult', 'often', 'ineffective', 'well', 'practical', 'tools', 'analyzing', 'effectively', 'solving', 'complex', 'problems', 'future', 'business', 'analysts', 'students', 'learn', 'become', 'effective', 'problem', 'solvers', 'defining', 'problem', 'accommodating', 'varied', 'perspectives', 'organizational', 'stakeholders', 'identifying', 'appropriate', 'solutions', 'effectively', 'collaborating', 'others']
# ['provides', 'introduction', 'network', 'design', 'management', 'field', 'network', 'covers', 'fundamental', 'concepts', 'theory', 'evolution', 'applications', 'recent', 'technological', 'advancements']
# ['module', 'covers', 'fundamental', 'concepts', 'mobile', 'application', 'development', 'applied', 'using', 'mobile', 'technologies', 'module', 'introduces', 'students', 'different', 'features', 'mobile', 'applications', 'platforms', 'further', 'module', 'provides', 'indepth', 'knowledge', 'android', 'technologies', 'enables', 'student', 'develop', 'mobile', 'application', 'cater', 'real', 'world', 'requirements']
# ['module', 'introduces', 'students', 'fundamental', 'data', 'structures', 'stacks', 'queues', 'linked', 'lists', 'trees', 'addition', 'offers', 'indepth', 'coverage', 'different', 'algorithms', 'techniques', 'designing', 'algorithms', 'enables', 'students', 'understand', 'analyze', 'problem', 'algorithmic', 'way']
# ['final', 'presentation', 'viva', 'final', 'report', 'writing', 'system', 'testing', 'activity', 'git', 'report', 'progress', 'evaluation', 'informal', 'progress', 'evaluation', 'er', 'diagram', 'activity', 'interface', 'designing', 'activities', 'proposal', 'evaluation', 'lecture', 'scrum', 'activity', 'introduction', 'itp', 'project', 'proposal', 'writing']
# ['introductory', 'course', 'discrete', 'mathematics', 'goal', 'course', 'introduce', 'students', 'ideas', 'techniques', 'discrete', 'mathematics', 'widely', 'used', 'science', 'engineering', 'course', 'teaches', 'students', 'techniques', 'think', 'logically', 'mathematically', 'apply', 'techniques', 'solving', 'problems', 'achieve', 'goal', 'students', 'learn', 'logic', 'proof', 'sets', 'functions', 'well', 'algorithms', 'mathematical', 'reasoning', 'key', 'topics', 'involving', 'relations', 'graphs', 'trees', 'formal', 'languages', 'computability', 'covered', 'course']
# ['course', 'survey', 'computer', 'algorithms', 'examines', 'fundamental', 'techniques', 'algorithm', 'design', 'analysis', 'develops', 'problemsolving', 'skills', 'required', 'programs', 'study', 'involving', 'computer', 'science', 'topics', 'include', 'advanced', 'data', 'structures', 'redblack', '234', 'trees', 'unionfind', 'recursion', 'mathematical', 'induction', 'algorithm', 'analysis', 'computational', 'complexity', 'recurrence', 'relations', 'bigo', 'notation', 'npcompleteness', 'sorting', 'searching', 'design', 'paradigms', 'divide', 'conquer', 'greedy', 'heuristic', 'dynamic', 'programming', 'amortized', 'analysis', 'graph', 'algorithms', 'depthfirst', 'breadthfirst', 'search', 'connectivity', 'minimum', 'spanning', 'trees', 'network', 'flow', 'advanced', 'topics', 'selected', 'among', 'following', 'randomized', 'algorithms', 'information', 'retrieval', 'string', 'pattern', 'matching', 'computational', 'geometry']
# ['course', 'covers', 'fundamentals', 'technologies', 'data', 'communications', 'related', 'network', 'infrastructure', 'business', 'environment', 'topics', 'include', 'business', 'imperatives', 'distributed', 'systems', 'systems', 'architectural', 'designs', 'clientserver', 'distributed', 'processing', 'etc', 'layered', 'architecture', 'models', 'tcpip', 'osi', 'etc', 'key', 'network', 'technologies', 'security', 'design', 'issues', 'related', 'architecture', 'network', 'configuration', 'management', 'techniques']
# ['module', 'aims', 'students', 'gain', 'practical', 'experience', 'developing', 'managing', 'achieving', 'objectives', 'ict', 'industry', 'based', 'project', 'involves', 'identifying', 'project', 'goals', 'gathering', 'requirements', 'client', 'preparation', 'project', 'plans', 'implementing', 'marketing', 'aspects', 'project', 'showing', 'various', 'stages', 'completion']
# ['activity', 'diagram', 'object', 'diagram', 'state', 'diagram', 'class', 'diagram']
# ['introduction', 'lan', 'concepts', 'ipv6', 'lan', 'design', 'scaling', 'vlans', 'spanning', 'tree', 'protocol', 'stp', 'etherchannel', 'hsrp', 'dynamic', 'routing', 'single', 'area', 'ospf', 'eigr']
# ['understanding', 'system', 'network', 'administration', 'apply', 'theory', 'practice', 'using', 'command', 'line', 'interfaces', 'understand', 'complex', 'ideas', 'relate', 'specific', 'problems', 'questions', 'understanding', 'tasks', 'system', 'administration', 'involves', 'tasks', 'might', 'approached', 'understanding', 'areas', 'system', 'network', 'administration', 'impact', 'ability', 'evaluate', 'different', 'approaches', 'system', 'administration', 'apply', 'knowledge', 'system', 'administration', 'appropriately', 'order', 'solve', 'problems', 'ability', 'manage', 'solve', 'problems', 'using', 'understanding', 'solutions', 'problems', 'might', 'implemented']
# ['module', 'introduce', 'realtime', 'operating', 'systems', 'basics', 'objectives', 'unit', 'educate', 'students', 'fundamentals', 'operating', 'systems', 'scheduling', 'mechanisms', 'processor', 'reserves', 'capabilities', 'commercial', 'different', 'operating', 'systems']
# ['module', 'designed', 'introductory', 'course', 'embedded', 'system', 'design', 'students', 'following', 'unit', 'learn', 'requirement', 'analysis', 'embedded', 'systems', 'design', 'implement', 'closedloop', 'automatic', 'control', 'using', 'microcontroller']
# ['introduction', 'management', 'introduction', 'business', 'analysis', 'introduction', 'project', 'management', 'planning', 'forecasting', 'team', 'building', 'project', 'initiation', 'selection', 'project', 'estimation', 'planning', 'project', 'monitoring', 'controlling', 'pmi', 'guidelines', 'project', 'group', 'project']
# ['testing', 'fundamentals', 'methods', 'specification', 'based', 'test', 'case', 'design', 'techniques', 'code', 'coverage', 'analysis', 'functional', 'nonfunctional', 'testing']
# ['module', 'intends', 'familiarise', 'students', 'concepts', 'applications', 'distributed', 'computing', 'students', 'get', 'understanding', 'importance', 'distributed', 'computing', 'oppose', 'standalone', 'systems', 'difference', 'distributed', 'computing', 'systems', 'approaches', 'technologies', 'also', 'gain', 'understanding', 'situations', 'problems', 'distributed', 'computing', 'may', 'applied', 'possible', 'challenges', 'involved', 'developing', 'distributed', 'systems']
# ['module', 'intends', 'gather', 'knowledge', 'many', 'areas', 'frameworks', 'presentation', 'persistence', 'web', 'service', 'enterprise', 'applications', 'integration', 'data', 'access', 'layers', 'test', 'technologies', 'frameworks', 'comprises', 'students', 'exposed', 'conventional', 'java', 'scriptingbased', 'development', 'layered', 'architecture']
# ['define', 'user', 'experience', 'design', 'identify', 'fits', 'software', 'development', 'life', 'cycle', 'apply', 'design', 'thinking', 'software', 'interfaces', 'investigate', 'users', 'elicit', 'user', 'characteristics', 'design', 'solutions', 'using', 'requirement', 'engineering', 'techniques', 'real', 'world', 'problems', 'demonstrate', 'user', 'experience', 'testing', 'secure', 'design', 'skills', 'extend', 'solution', 'space', 'user', 'experience', 'design', 'trends']
# ['unit', 'continuation', 'it1030', 'it2040', 'extends', 'nosql', 'hadoop', 'framework', 'xml', 'integration', 'object', 'rdbms', 'rdbms', 'parallel', 'distributed', 'db', 'architectures', 'topics', 'related', 'query', 'optimization', 'database', 'tuning', 'transactions', 'concurrency', 'control', 'techniques', 'discussed', 'detail']
# ['objective', 'module', 'discuss', 'important', 'topics', 'software', 'engineering', 'requirements', 'engineering', 'software', 'analysis', 'detailed', 'design', 'software', 'testing', 'students', 'reflect', 'knowledge', 'gained', 'applying', 'concepts', 'industrybased', 'case', 'study']
# ['azure', 'dashboard', 'agile', 'project', 'management', 'tool', 'sonarqube', 'code', 'quality', 'inspection', 'tool', 'git', 'distributed', 'version', 'control', 'system', 'selenium', 'test', 'automation', 'framework']
# ['aims', 'industrial', 'training', 'module', 'provide', 'students', 'industrial', 'exposure', 'allow', 'students', 'interact', 'technical', 'specialists', 'undergo', 'industrial', 'training', 'training', 'institute', 'approved', 'sliit', 'period', '6', 'months']
# ['contemporary', 'concepts', 'technologies', 'frameworkslibraries', 'tools', 'industry', 'best', 'practices', 'used', 'engineer', 'enterprise', 'systems', 'students', 'exposed', 'standard', 'webbased', 'applications', 'development', 'well', 'rich', 'webbased', 'applications', 'development', 'using', 'heavy', 'clientside', 'components']
# ['underlying', 'theory', 'practical', 'problems', 'encountered', 'using', 'models', 'reallife', 'situation', 'models', 'studied', 'advanced', 'statistical', 'models', 'regression', 'time', 'series', 'etc', 'students', 'also', 'learn', 'use', 'statistical', 'package', 'r']
# ['planning', 'work', 'many', 'aspects', 'bi', 'solutions', 'include', 'database', 'administrators', 'project', 'managers', 'testers', 'support', 'techs', 'report', 'developers', 'many', 'others', 'small', 'medium', 'large', 'companies', 'well', 'departments', 'within', 'companies', 'take', 'advantages', 'bi', 'software', 'solutions', 'effectively', 'completing', 'unit', 'working', 'recommended', 'exercises', 'students', 'tools', 'build', 'bi', 'solutions', 'well', 'interact', 'bi', 'team', 'members', 'greater', 'understanding', 'roles', 'within', 'bi', 'solution', 'process']
# ['objectrelational', 'databases', 'xml', 'integration', 'components', 'database', 'systems', 'further', 'topics', 'related', 'disk', 'files', 'indexes', 'query', 'optimization', 'database', 'tuning', 'transactions', 'concurrency', 'control', 'techniques', 'crash', 'recovery', 'discussed', 'detail']
# ['meaning', 'information', 'spreads', 'wide', 'day', 'day', 'news', 'details', 'market', 'products', 'academic', 'publications', 'complex', 'concepts', 'internet', 'world', 'wide', 'web', 'people', 'preferred', 'getting', 'information', 'people', 'media', 'like', 'newspapers', 'tv', 'evolvement', 'computerbased', 'information', 'systems', 'world', 'wide', 'web', 'everybody', 'access', 'internet', 'retrieving', 'information', 'using', 'aforesaid', 'technologies', 'various', 'purposes', 'checking', 'train', 'schedule', 'learn', 'new', 'technologies', 'published', 'academic', 'research', 'journals', 'however', 'web', 'allowing', 'unleash', 'publication', 'scale', 'tens', 'millions', 'content', 'creators', 'explosion', 'published', 'information', 'would', 'moot', 'information', 'could', 'found', 'annotated', 'analyzed', 'user', 'quickly', 'find', 'retrieve', 'information', 'relevant', 'comprehensive', 'needs']
# ['module', 'creates', 'learning', 'environment', 'study', 'theory', 'practices', 'field', 'data', 'mining', 'topics', 'include', 'different', 'types', 'data', 'mining', 'applications', 'data', 'preprocessing', 'methods', 'algorithms', 'concepts', 'relate', 'frequent', 'pattern', 'mining', 'associations', 'fundamentals', 'classification', 'clustering', 'techniques', 'design', 'develop', 'deploy', 'data', 'mining', 'applications']
# ['compulsory', 'module', '3rd', 'year', 'students', 'follows', 'bsc', 'hons', 'specializing', 'data', 'science', 'program', 'covers', 'background', 'knowledge', 'required', 'massive', 'data', 'processing', 'using', 'cloudbased', 'infrastructure', 'development', 'tools']
# ['objective', 'module', 'provide', 'sound', 'foundation', 'fundamental', 'concepts', 'machine', 'learning', 'optimization', 'module', 'students', 'learn', 'fundamentals', 'neural', 'networks', 'multilayer', 'neural', 'networks', 'fundamentals', 'optimization', 'linear', 'programming', 'genetic', 'algorithms']
# ['aims', 'industrial', 'training', 'module', 'provide', 'students', 'industrial', 'exposure', 'allow', 'students', 'interact', 'technical', 'specialists', 'undergo', 'industrial', 'training', 'training', 'institute', 'approved', 'sliit', 'period', '6', 'months']
# ['explain', 'mobile', 'security', 'impacts', 'small', 'medium', 'large', 'organizations', 'build', 'effective', 'security', 'analyse', 'security', 'concerns', 'different', 'mobile', 'operating', 'system', 'environments', 'androidioswindows', 'explain', 'security', 'concerns', 'related', 'multiple', 'mobile', 'infrastructure', 'models', 'including', '3g', '4g', 'lte', 'explain', 'mobile', 'security', 'concepts', 'theoretical', 'principles']
# ['course', 'explore', 'several', 'structured', 'risk', 'management', 'approaches', 'guide', 'information', 'security', 'decisionmaking', 'course', 'follows', 'four', 'domains', 'isaca', 'certified', 'risk', 'information', 'systems', 'control', 'crisc', 'risk', 'identification', 'risk', 'assessment', 'risk', 'response', 'mitigation', 'risk', 'control', 'monitoring', 'reporting', 'course', 'topics', 'include', 'developing', 'maintaining', 'risk', 'assessments', 'ra', 'developing', 'maintaining', 'risk', 'management', 'plans', 'rm', 'regulatory', 'legal', 'compliance', 'issues', 'affecting', 'risk', 'plans', 'developing', 'control', 'framework', 'mitigating', 'risks', 'risk', 'transfer', 'business', 'continuity', 'disaster', 'recovery', 'planning', 'information', 'security', 'perspective', 'course', 'students', 'explore', 'overarching', 'concept', 'grc', 'several', 'structured', 'risk', 'management', 'approaches', 'guide', 'information', 'security', 'decision', 'making']
# ['describe', 'information', 'assurance', 'respect', 'data', 'operating', 'systems', 'security', 'explain', 'requirement', 'data', 'dependent', 'access', 'controls', 'compare', 'contrast', 'preventive', 'detective', 'data', 'operating', 'system', 'security', 'mechanisms', 'combine', 'multiple', 'tools', 'techniques', 'design', 'secure', 'database', 'environment', 'evaluate', 'security', 'operating', 'system']
# ['course', 'provides', 'opportunities', 'integrate', 'apply', 'information', 'security', 'knowledge', 'following', 'casestudy', 'approach', 'introduced', 'current', 'realworld', 'cases', 'developed', 'presented', 'practitioner', 'community', 'design', 'execute', 'information', 'assurance', 'strategies', 'solve', 'cases', 'analysis', 'problem', 'solving', 'using', 'cases', 'contracted', 'real', 'world', 'problems', 'information', 'assurance', 'including', 'selection', 'application', 'controls', 'construction', 'security', 'policies', 'understanding', 'application', 'regulatory', 'requirements', 'understanding', 'application', 'business', 'constraints', 'communication', 'risk', 'noninformation', 'assurance', 'professionals', 'identification', 'remediation', 'new', 'threats']
# ['course', 'introduction', 'basic', 'theory', 'practice', 'cryptographic', 'techniques', 'used', 'computer', 'security', 'cover', 'topics', 'encryption', 'secretkey', 'publickey', 'message', 'integrity', 'digital', 'signatures', 'user', 'authentication', 'key', 'management', 'cryptographic', 'hashing', 'network', 'security', 'protocols', 'ssl', 'ipsec', 'publickey', 'infrastructure', 'digital', 'rights', 'management', 'secret', 'sharing', 'bit', 'zeroknowledge', 'protocols', 'highly', 'theoretical', 'subject', 'requires', 'sound', 'foundation', 'mathematics', 'dedicated', 'lecture', 'tutorial', 'session', 'allocated', 'familiarize', 'students', 'advanced', 'mathematics', 'required', 'module', 'mathematics', 'cryptography']
# ['objectives', 'module', 'teach', 'concept', 'project', 'project', 'management', 'students', 'given', 'knowledge', 'identify', 'information', 'system', 'project', 'ten', 'project', 'management', 'knowledge', 'areas', 'defined', 'project', 'management', 'institute', 'project', 'management', 'body', 'knowledge', 'pmbok', 'further', 'recent', 'development', 'project', 'management', 'software', 'technologies', 'discusse']
# ['unit', 'provides', 'introduction', 'nature', 'organizations', 'relation', 'management', 'practices', 'use', 'managerial', 'concepts', 'marketing', 'perform', 'organizational', 'functions', 'unit', 'examines', 'internal', 'nature', 'organizations', 'theoretical', 'practical', 'viewpoint', 'unit', 'intended', 'develop', 'understanding', 'behavior', 'people', 'within', 'organizations', 'significance', 'organizational', 'design', 'characteristics', 'also', 'aims', 'provide', 'basic', 'for', 'underpin', 'study', 'in', 'specialist', 'areas', 'business']
# ['module', 'provides', 'students', 'wellbalanced', 'repository', 'skills', 'business', 'knowledge', 'required', 'become', 'mis', 'professionals', 'future', 'students', 'learn', 'businesses', 'use', 'information', 'improve', 'operations', 'manage', 'various', 'information', 'systems', 'best', 'serve', 'needs', 'managers', 'staff', 'customers', 'strategic', 'use', 'impact', 'organizational', 'change', 'innovation']
# ['incorporating', 'data', 'integration', 'business', 'intelligence', 'enables', 'business', 'organisations', 'discover', 'new', 'patterns', 'new', 'trends', 'data', 'order', 'obtain', 'analytical', 'insight', 'business', 'challenges', 'aim', 'module', 'develop', 'appreciation', 'understanding', 'techniques', 'approaches', 'used', 'develop', 'deploy', 'data', 'integration', 'purposes', 'business', 'intelligence', 'module', 'examine', 'data', 'quality', 'data', 'transformation', 'methods', 'practices', 'addition', 'data', 'integration', 'modelling', 'techniques', 'order', 'build', 'quality', 'data', 'warehouse', 'empowered', 'data', 'mining', 'facilitate', 'support', 'strategic', 'planning', 'business', 'intelligence', 'applications']
# ['module', 'covers', 'significant', 'areas', 'ebusiness', 'starting', 'from', 'business', 'strategies', 'applicable', 'ebusiness', 'ebusiness', 'concepts', 'technical', 'architectures', 'business', 'revenue', 'models', 'ebusiness', 'areas', 'considered', 'usability', 'user', 'experience', 'ecommerce', 'sites', 'designing', 'ecommerce', 'sites', 'testing', 'usability', 'ecommerce', 'sites']
# ['module', 'covers', 'enterprise', 'information', 'security', 'concepts', 'practices', 'detail', 'goal', 'open', 'doors', 'students', 'acquire', 'sufficient', 'knowledge', 'protect', 'information', 'assets', 'organization']
# ['aim', 'module', 'provide', 'introduction', 'concepts', 'practices', 'economics', 'accounting', 'human', 'resource', 'management', 'module', 'provides', 'general', 'understanding', 'concepts', 'practices', 'economics', 'starting', 'basic', 'ideas', 'fundamental', 'economic', 'concepts', 'market', 'forces', 'supply', 'demand', 'introduction', 'cost', 'production', 'course', 'also', 'intends', 'introduce', 'process', 'financial', 'accounting', 'moreover', 'module', 'provides', 'introduction', 'concepts', 'practices', 'human', 'resource', 'management']
# ['course', 'provides', 'technical', 'overview', 'enterprise', 'resource', 'planning', 'systems', 'impact', 'organizations', 'sap', 'introduced', 'illustrate', 'concepts', 'fundamentals', 'framework', 'general', 'information', 'technology', 'context', 'technological', 'infrastructure', 'integration', 'business', 'enterprisewide', 'applications', 'fundamentals', 'enterprise', 'resource', 'planning', 'erp', 'systems', 'concepts', 'importance', 'integrated', 'information', 'systems', 'organization', 'focus', 'course', 'illustrating', 'procurement', 'production', 'sales', 'business', 'processes', 'using', 'erp', 'software', 'use', 'sap', 'example', 'erp', 'system']
# ['module', 'examines', 'nature', 'business', 'enterprise', 'competitive', 'markets', 'information', 'systems', 'strategies', 'developed', 'fundamental', 'connections', 'linking', 'core', 'business', 'strategy', 'technology', 'innovation', 'also', 'explored', 'module', 'help', 'students', 'think', 'strategically', 'innovation', 'provide', 'analytical', 'tools', 'help', 'make', 'effective', 'decisions', 'use', 'organizations', 'put', 'basic', 'framework', 'relationships', 'among', 'business', 'strategy', 'information', 'systems', 'organizational', 'strategies', 'module', 'describes', 'managers', 'participate', 'decisionmaking', 'process', 'outline', 'key', 'topics', 'consider', 'develop', 'point', 'view']
# ['introduction', 'network', 'design', 'mapping', 'baselining', 'network', 'server', 'monitoring', 'fault', 'tolerance', 'disaster', 'recovery', 'simple', 'network', 'management', 'protocol', 'snmp', 'lightweight', 'directory', 'access', 'protocol', 'ldap', 'ldap', 'data', 'interchange', 'format', 'ldif', 'ldap', 'topology', 'design', 'ldap', 'replication', 'ldap', 'security', 'cloud', 'computing']
# ['objectives', 'module', 'teach', 'wan', 'technologies', 'network', 'services', 'required', 'converged', 'applications', 'complex', 'network', 'module', 'focus', 'selection', 'criteria', 'network', 'devices', 'wan', 'technologies', 'meet', 'network', 'requirements', 'organization']
# ['module', 'focuses', 'storing', 'protecting', 'optimizing', 'managing', 'large', 'amount', 'digital', 'information', 'created', 'every', 'moment', 'individuals', 'organizations', 'students', 'learn', 'storage', 'system', 'storage', 'networking', 'technologies', 'backup', 'archive', 'replication', 'cloud', 'storage', 'systems', 'security', 'managing', 'storage', 'infrastructure']
# ['unit', 'designed', 'familiarize', 'students', 'basic', 'concepts', 'management', 'economics', 'marketing', 'accounting', 'course', 'examines', 'practice', 'management', 'principles', 'economics', 'marketing', 'management', 'accounting', 'within', 'changing', 'business', 'environment', 'since', 'students', 'technical', 'background', 'subject', 'introduces', 'practical', 'management', 'concepts', 'order', 'used', 'functioning', 'areas']
# ['introduction', 'security', 'fundamentals', 'modern', 'network', 'security', 'threats', 'cryptography', 'fundamentals', 'cryptographic', 'hashes', 'symmetric', 'cryptograph', 'asymmetric', 'cryptography', 'public', 'key', 'infrastructure', 'authentication', 'authorization', 'accounting', 'firewall', 'technologies', 'intrusion', 'detection', 'system', 'intrusion', 'prevention', 'systems', 'virtual', 'private', 'network', 'ipsec', 'managing', 'secure', 'network']
# ['user', 'experience', 'encompasses', 'aspects', 'endusers', 'interaction', 'company', 'services', 'products', 'user', 'experience', 'designing', 'combination', 'tools', 'methods', 'frameworks', 'solve', 'design', 'problems', 'methodical', 'way', 'focusing', 'users', 'product', 'service', 'user', 'experience', 'designers', 'seek', 'find', 'balance', 'logic', 'emotion', 'establishment', 'logical', 'structure', 'experience', 'creating', 'emotional', 'connection', 'products', 'users', 'companies', 'beginning', 'understand', 'power', 'differentiating', 'products', 'focusing', 'users', 'creating', 'better', 'user', 'experiences', 'students', 'learn', 'understand', 'users', 'thinking', 'product', 'service', 'helpful', 'design', 'much', 'usable', 'product', 'service']
# ['objective', 'module', 'provide', 'students', 'overall', 'knowledge', '3d', 'modeling', 'sculpting', 'techniques', 'advanced', 'character', 'animation', 'topics', 'discussed', 'module', 'includes', 'modeling', 'texturing', 'lighting', 'rendering', 'character', 'animation', 'design', 'fundamentals', 'involved', 'visual', 'production', 'simulations', 'objectives', 'module', 'spans', 'providing', 'knowledge', 'cgi', 'product', 'must', 'created', 'beginning', 'point', 'creative', 'thinking', 'going', 'way', 'successful', 'publishing']
# ['objective', 'module', 'provide', 'students', 'overall', 'knowledge', 'digital', 'video', 'production', 'comprehensive', 'manner', 'topics', 'discussed', 'module', 'includes', 'evolution', 'visual', 'production', 'equipment', 'technology', 'audio', 'arrangements', 'color', 'grading', 'vfx', 'digital', 'cinema', 'marketing', 'concepts', 'advertising', 'objectives', 'module', 'spans', 'providing', 'knowledge', 'motion', 'picture', 'production', 'must', 'created', 'beginning', 'point', 'creative', 'thinking', 'going', 'way', 'point', 'final', 'screening', 'integrated', 'latest', 'technologies']
# ['introductory', 'module', 'image', 'processing', 'give', 'students', 'working', 'knowledge', 'commonly', 'used', 'methods', 'procedures', 'image', 'enhancement', 'restoration', 'segmentation']
# ['games', 'technology', 'module', 'aims', 'provide', 'sound', 'knowledge', 'computer', 'gaming', 'enable', 'ability', 'apply', 'industry', 'discusses', 'topics', 'including', 'ethical', 'cultural', 'aspects', 'computer', 'games', 'latest', 'technologies', 'used', 'game', 'making', 'process', 'effect', 'society', 'computer', 'games', 'game', 'story', 'writing']
# ['lo1', 'provide', 'creative', 'innovative', 'solution', 'openended', 'complex', 'problem', 'lo2', 'apply', 'key', 'pillars', 'domain', 'computing', 'lo3', 'apply', 'project', 'management', 'methodologies', 'provide', 'solution', 'openended', 'problem', 'using', 'appropriate', 'techniques', 'tools', 'best', 'practices', 'standards', 'ethical', 'security', 'social', 'legal', 'professional', 'context', 'lo4', 'communicate', 'effectively', 'wide', 'range', 'audiences', 'including', 'technical', 'nontechnical', 'stakeholders', 'lo5', 'assess', 'commercial', 'viability', 'project']
# ['objective', 'module', 'provide', 'understanding', 'working', 'knowledge', 'current', 'topics', 'trends', 'technologies', 'software', 'engineering', 'industry', 'following', 'module', 'students', 'able', 'apply', 'concepts', 'frameworks', 'technologies', 'learnt', 'throughout', 'module', 'effectively', 'solve', 'real', 'world', 'problems']
# ['today', 'digital', 'image', 'processing', 'become', 'one', 'important', 'essential', 'areas', 'many', 'industrial', 'software', 'applications', 'digital', 'image', 'processing', 'provides', 'solid', 'working', 'knowledge', 'commonly', 'use', 'methods', 'procedures', 'digital', 'image', 'manipulation', 'including', 'enhancement', 'filtering', 'restoration', 'course', 'provide', 'basic', 'techniques', 'algorithms', 'applications', 'digital', 'image', 'processing', 'including', 'intensity', 'transformation', 'spatial', 'filters', 'edge', 'detection', 'morphological', 'operators', 'feature', 'extraction', 'color', 'image', 'processing', 'also', 'empowers', 'learners', 'develop', 'image', 'processing', 'programs', 'leverage', 'opencv', 'functionalities', 'implement', 'sophisticated', 'image', 'applications']
# ['module', 'intends', 'familiarize', 'students', 'concepts', 'applications', 'machine', 'learning', 'discuss', 'machine', 'learning', 'important', 'current', 'applications', 'information', 'technology', 'different', 'machine', 'learning', 'algorithms', 'techniques', 'may', 'applied', 'solve', 'realworld', 'problems', 'cannot', 'solved', 'deterministic', 'algorithms', 'also', 'discuss', 'limitations', 'possible', 'future', 'research', 'directions', 'machine', 'learning']
# ['module', 'aims', 'discuss', 'technologies', 'emerging', 'trends', 'used', 'automating', 'basic', 'structural', 'tasks', 'enterprise', 'applications', 'freeing', 'developers', 'timeconsuming', 'low', 'aggregated', 'value', 'tasks', 'allowing', 'concentrate', 'actual', 'goal', 'software', 'development', 'implementation', 'user', 'requirements', 'module', 'covers', 'key', 'concepts', 'software', 'industry', 'including', 'j2ee', 'ead', 'methodologies', 'nosql', 'web', 'services', 'micro', 'services', 'iot', 'devops', 'odata', 'cloud', 'computing', 'big', 'data', 'mobile', 'application', 'development', 'etc']
# ['mobile', 'systems', 'component', 'almost', 'every', 'digital', 'experience', 'retail', 'health', 'games', 'social', 'music', 'money', 'etc', 'course', 'covers', 'basics', 'ios', 'development', 'engaging', 'students', 'applicationinspired', 'project', 'based', 'learning', 'around', 'key', 'challenges', 'resource', 'management', 'user', 'experience', 'design', 'students', 'strive', 'create', 'meaningful', 'relationships', 'people', 'products', 'services', 'use', 'computers', 'mobile', 'devices', 'appliances', 'beyond']
# ['compulsory', 'unit', 'offered', 'second', 'year', 'bsc', 'honors', 'degree', 'computer', 'science', 'unit', 'intends', 'give', 'broad', 'knowledge', 'theoretical', 'applied', 'aspects', 'deep', 'neural', 'networks', 'used', 'realworld', 'nonlinear', 'predictions']
# ['objective', 'module', 'introduce', 'paralle', 'compting', 'concepts', 'practices', 'cover', 'multithreading', 'parallel', 'algorithms', 'gpu', 'computing', 'shared', 'memory', 'distributed', 'memory', 'parallelism', 'map', 'reduce', 'based', 'distributed', 'processing', 'systems']
# ['compulsory', 'unit', '4th', 'year', 'students', 'follows', 'bsc', 'hons', 'specializing', 'data', 'science', 'programme', 'objective', 'unit', 'provide', 'learning', 'environment', 'take', 'depth', 'understanding', 'theory', 'practices', 'field', 'database', 'administration', 'storages', 'systems', 'oracle', 'dbms', 'tools', 'used', 'teaching', 'purpose', 'further', 'course', 'covered', 'available', 'enterprise', 'storage', 'solutions', 'features']
# ['module', 'provides', 'indepth', 'coverage', 'iot', 'architectures', 'implementations', 'underlying', 'technologies', 'data', 'analytics', 'used', 'iot', 'service', 'point', 'view', 'particularly', 'covers', 'industry', 'approaching', 'iot', 'challenges', 'unstructured', 'data', 'real', 'time', 'basis', 'analyzed', 'insight', 'give', 'major', 'portion', 'course', 'project', 'students', 'work', 'teams', 'simulate', 'iot', 'system', 'generates', 'data', 'streams', 'apply', 'data', 'analytic', 'techniques', 'iot', 'generated', 'data']
# ['compulsory', 'unit', '3rd', 'year', 'students', 'follows', 'bsc', 'hons', 'specializing', 'data', 'science', 'program', 'objective', 'unit', 'provide', 'learning', 'environment', 'develop', 'indepth', 'understanding', 'theory', 'practices', 'fields', 'visual', 'analytics', 'user', 'experience', 'design', 'course', 'helps', 'students', 'learn', 'use', 'build', 'cuttingedge', 'visual', 'analytics', 'tools', 'systems', 'understand', 'real', 'world', 'data', 'also', 'provides', 'comprehensive', 'knowledge', 'analytical', 'reasoning', 'techniques', 'visual', 'representations', 'interaction', 'techniques', 'students', 'learn', 'computation', 'graphics', 'information', 'dashboard', 'design', 'techniques', 'support', 'production', 'presentation', 'dissemination', 'results', 'analysis', 'communicate', 'information', 'appropriate', 'context', 'variety', 'audiences']
# ['security', 'economic', 'analysis', 'booming', 'research', 'field', 'multidisciplinary', 'field', 'cybersecurityeconomics']
# ['secure', 'software', 'concepts', 'secure', 'software', 'requirements', 'secure', 'software', 'design', 'secure', 'software', 'implementationcoding']
# ['fundamentals', 'digital', 'forensics', 'computer', 'crimes', 'investigation', 'process', 'digital', 'evidence', 'data', 'acquisition', 'duplication', 'operating', 'system', 'forensics', 'windowslinux', 'investigating', 'email', 'crimes', 'network', 'forensics', 'modern', 'topics', 'cyber', 'forensics', 'mobile', 'forensics', 'cloud', 'forensics', 'introduction', 'incident', 'management', 'incident', 'response', 'soc']
# ['course', 'explore', 'key', 'areas', 'governance', 'part', 'overarching', 'enterprise', 'governance', 'structure', 'governance', 'risk', 'management', 'compliance', 'grc', 'umbrella', 'term', 'covering', 'three', 'major', 'facets', 'organizations', 'approach', 'towards', 'it', 'course', 'also', 'examines', 'legal', 'policy', 'challenges', 'stemming', 'rapidly', 'evolving', 'cyber', 'security', 'threats', 'cyber', 'insecurities', 'affect', 'many', 'types', 'actorsfor', 'example', 'individuals', 'suffer', 'cybercrimes', 'media', 'outlets', 'whose', 'websites', 'hacked', 'taken', 'offline', 'businesses', 'whose', 'intellectual', 'property', 'plundered', 'states', 'undertake', 'andor', 'attempt', 'defend', 'espionage', 'uses', 'force', 'cyberspace', 'course', 'explore', 'national', 'international', 'legal', 'frameworks', 'govern', 'malicious', 'defensive', 'actions', 'cyberspace', 'including', 'laws', 'related', 'cybercrime', 'cyberespionage', 'cyberwar', 'course', 'consider', 'legal', 'questions', 'within', 'context', 'broader', 'debates', 'issues', 'governance', 'cyberspace', 'internet', 'roles', 'governmental', 'nongovernmental', 'actors', 'evolving', 'understandings', 'privacy', 'role', 'law', 'governing', 'constantly', 'changing', 'domain', 'many', 'actors', 'operate', 'secret']
# ['module', 'intends', 'familiarize', 'students', 'concepts', 'applications', 'machine', 'learning', 'discuss', 'machine', 'learning', 'important', 'current', 'applications', 'information', 'technology', 'different', 'machine', 'learning', 'algorithms', 'techniques', 'may', 'applied', 'solve', 'realworld', 'problems', 'cannot', 'solved', 'deterministic', 'algorithms', 'also', 'discuss', 'limitations', 'possible', 'future', 'research', 'directions', 'machine', 'learning']
# ['unit', 'aims', 'give', 'students', 'introduction', 'accepted', 'practices', 'field', 'business', 'analysis', 'captured', 'business', 'analysis', 'body', 'knowledge', 'babok', 'focus', 'role', 'business', 'analyst', 'knowledge', 'skills', 'essential', 'successfully', 'conduct', 'business', 'requirements', 'analysis', 'order', 'develop', 'effective', 'solutions', 'business', 'problems']
# ['hris', 'roles', 'is', 'types', 'information', 'systems', 'relationship', 'hr', 'practices', 'hris', 'hris', 'become', 'study', 'area', 'maturity', 'hris', 'hr', 'analytics']
# ['course', 'provides', 'broad', 'view', 'quality', 'assurance', 'process', 'management', 'improvement', 'testing', 'participants', 'broad', 'awareness', 'many', 'activities', 'contribute', 'guarantee', 'quality', 'software', 'product', 'course', 'cover', 'methods', 'tools', 'achieving', 'software', 'quality', 'assurance', 'various', 'levels', 'development', 'lifecycle', 'also', 'role', 'standards', 'policies', 'procedures', 'discussed', 'course', 'provides', 'practical', 'knowledge', 'variety', 'quality', 'assurance', 'techniques', 'test', 'design', 'execution', 'techniques', 'understanding', 'tradeoffs', 'techniques']
# ['module', 'focuses', 'knowledge', 'created', 'captured', 'represented', 'stored', 'reused', 'fully', 'leverage', 'intellectual', 'assets', 'firm', 'tools', 'techniques', 'knowledge', 'acquisition', 'assessment', 'evaluation', 'management', 'organization', 'dissemination', 'applied', 'business', 'situations', 'topics', 'include', 'knowledge', 'generation', 'knowledge', 'coordination', 'codification', 'knowledge', 'transfer', 'reuse', 'technologies', 'knowledge', 'management', 'knowledge', 'management', 'strategies', 'goal', 'enable', 'learn', 'practice', 'context', 'managing', 'design', 'development', 'operation', 'information', 'technologies', 'facilitate', 'km']
# ['humancomputer', 'interaction', 'hci', 'study', 'interaction', 'people', 'users', 'computing', 'devices', 'often', 'regarded', 'intersection', 'computer', 'science', 'behavioral', 'sciences', 'design', 'several', 'fields', 'study', 'interaction', 'users', 'computing', 'devices', 'occurs', 'user', 'interface', 'includes', 'software', 'hardware', 'module', 'aims', 'develop', 'necessary', 'skills', 'design', 'evaluation', 'implementation', 'interactive', 'computing', 'systems', 'human', 'use', 'topics', 'covered', 'module', 'includes', 'need', 'finding', 'user', 'research', 'techniques', 'interaction', 'design', 'software', 'sketching', 'prototyping', 'techniques', 'usability', 'process', 'interface', 'evaluation', 'techniques']
# ['module', 'aims', 'discuss', 'technologies', 'emerging', 'trends', 'used', 'automating', 'basic', 'structural', 'tasks', 'enterprise', 'applications', 'freeing', 'developers', 'timeconsuming', 'low', 'aggregated', 'value', 'tasks', 'allowing', 'concentrate', 'actual', 'goal', 'software', 'development', 'implementation', 'user', 'requirements', 'module', 'covers', 'key', 'concepts', 'software', 'industry', 'including', 'j2ee', 'ead', 'methodologies', 'nosql', 'web', 'services', 'micro', 'services', 'iot', 'devops', 'odata', 'cloud', 'computing', 'big', 'data', 'mobile', 'application', 'development', 'etc']
# ['module', 'focuses', 'software', 'defined', 'networking', 'sdn', 'emerging', 'paradigm', 'data', 'center', 'networking', 'sdn', 'separates', 'networks', 'control', 'logic', 'underlying', 'physical', 'routers', 'switches', 'forward', 'traffic', 'allows', 'network', 'operators', 'write', 'highlevel', 'control', 'programs', 'specify', 'behavior', 'entire', 'network', 'course', 'covers', 'concepts', 'stateofart', 'sdn', 'depth', 'including', 'history', 'current', 'usages', 'future', 'directions', 'further', 'module', 'contains', 'set', 'lab', 'sessions', 'configuring', 'troubleshooting', 'sdn', 'based', 'network', 'sdn', 'simulation', 'environment', 'mininet', 'end', 'course', 'students', 'develop', 'good', 'theoretical', 'practical', 'understanding', 'sdn', 'challenges', 'applications']
# ['module', 'focuses', 'iot', 'ecosystem', 'services', 'development', 'phases', 'iot', 'ecosystem', 'particular', 'module', 'discusses', 'origination', 'iot', 'industry', 'approaching', 'it', 'challenges', 'associated', 'it', 'analyzes', 'unstructured', 'data', 'real', 'time', 'basis', 'etc']
# ['module', 'cover', 'topics', 'virtualization', 'cloud', 'computing', 'introduction', 'course', 'discusses', 'motivating', 'factors', 'benefits', 'challenges', 'virtualization', 'usage', 'virtualization', 'concepts', 'cloud', 'computing', 'module', 'focuses', 'two', 'virtualization', 'methods', 'hypervisorbased', 'containerbased', 'virtualization', 'furthermore', 'module', 'discussed', 'method', 'applying', 'virtualization', 'principles', 'different', 'domains', 'network', 'virtualization', 'network', 'function', 'virtualization', 'latter', 'part', 'module', 'cover', 'security', 'aspects', 'virtualization', 'techniques', 'finally', 'module', 'concludes', 'usage', 'virtualization', 'techniques', 'cloud', 'computing']
# ['explain', 'characteristics', 'multimedia', 'projects', 'explain', 'applications', 'multimedia', 'explain', 'multimedia', 'delivery', 'methods', 'explain', 'uses', 'various', 'multimedia', 'software', 'applications']
# ['objective', 'module', 'provide', 'understanding', 'working', 'knowledge', 'current', 'topics', 'trends', 'technologies', 'information', 'technology', 'industry', 'following', 'module', 'students', 'able', 'apply', 'concepts', 'frameworks', 'technologies', 'learnt', 'throughout', 'module', 'effectively', 'solve', 'realworld', 'problems']
# ['optional', 'module', '4', 'th', 'year', 'students', 'bsc', 'sp', 'hons', 'information', 'technology', 'software', 'engineering', 'streams', 'objective', 'module', 'provide', 'depth', 'understanding', 'theory', 'practices', 'database', 'administration', 'oracle', 'dbms', 'tools', 'used', 'teaching', 'purpose']
# ['objective', 'module', 'provide', 'depth', 'understanding', 'theory', 'practices', 'field', 'cloud', 'computing', 'aws', 'tools', 'used', 'teaching', 'purpose']
# ['provides', 'introduction', 'network', 'design', 'management', 'field', 'network', 'covers', 'fundamental', 'concepts', 'theory', 'evolution', 'applications', 'recent', 'technological', 'advancements']
# ['module', 'develops', 'knowledge', 'skills', 'attitudes', 'required', 'maintain', 'acceptable', 'professional', 'conduct', 'organization', 'society', 'course', 'covers', 'spectrum', 'topics', 'compliment', 'current', 'values', 'attitudes', 'strengths', 'student', 'prepare', 'professional', 'world', 'student', 'groomed', 'take', 'responsibilities', 'selfdevelopment', 'abide', 'social', 'norms', 'ethics', 'respect', 'ip', 'embrace', 'diversity', 'respect', 'different', 'opinions', 'module', 'make', 'students', 'aware', 'essential', 'elements', 'professionalism', 'practice', 'future', 'engagements', 'degree', 'programme', 'industrial', 'training']
# ['aim', 'module', 'provide', 'students', 'exposure', 'required', 'practice', 'industry', 'graduate', 'lectures', 'conducted', 'students', 'following', '2nd', 'year', 'second', 'semester', 'non', 'gpa', 'compulsory', 'module', 'offered', 'students', 'following', 'four', 'year', 'degree']
# ['provide', 'understanding', 'working', 'knowledge', 'current', 'topics', 'trends', 'technologies', 'information', 'technology', 'industry', 'following', 'module', 'students', 'able', 'apply', 'concepts', 'frameworks', 'technologies', 'learnt', 'throughout', 'module', 'effectively', 'solve', 'realworld', 'problems']
# ['introduction', 'network', 'design', 'management', 'network', 'mapping', 'baselining', 'network', 'servers', 'network', 'server', 'os', 'monitoring', 'fault', 'tolerance', 'disaster', 'recovery', 'network', 'security', 'lightweight', 'directoryaccess', 'protocol', 'ldap', 'simple', 'network', 'management', 'protocol', 'snmp', 'introduction', 'world', 'wide', 'web', 'www', 'introduction', 'virtualization', 'cloud', 'computing']
# ['unit', 'covers', 'objectrelational', 'databases', 'nosql', 'xml', 'integration', 'advanced', 'features', 'relational', 'database', 'systems', 'further', 'topics', 'related', 'indexing', 'query', 'optimization', 'transactions', 'concurrency', 'control', 'techniques', 'discussed', 'detail']
# ['module', 'exposes', 'future', 'professionals', 'various', 'domains', 'knowledge', 'field', 'business', 'management', 'may', 'broaden', 'professionals', 'view', 'overall', 'economy', 'whole', 'business', 'organization', 'particular']
# ['objective', 'module', 'provide', 'overview', 'theory', 'practices', 'related', 'field', 'data', 'science', 'data', 'analytics', 'particular', 'module', 'familiarize', 'students', 'theory', 'concepts', 'related', 'data', 'warehousing', 'business', 'intelligence', 'traditional', 'methods', 'analyzing', 'data', 'well', 'using', 'modern', 'methods', 'data', 'analytics', 'students', 'also', 'obtain', 'hands', 'experience', 'data', 'warehousing', 'using', 'sql', 'server', 'data', 'analytics', 'using', 'python']
# ['module', 'aims', 'develop', 'skills', 'designing', 'evaluating', 'implementing', 'interactive', 'computing', 'systems', 'human', 'use', 'topics', 'covered', 'module', 'includes', 'need', 'finding', 'user', 'research', 'techniques', 'interaction', 'design', 'user', 'experience', 'design', 'software', 'standards', 'best', 'practices', 'principles', 'design', 'sketching', 'prototyping', 'techniques', 'interface', 'evaluation', 'techniques']
# ['course', 'cover', 'necessary', 'basics', 'information', 'security', 'assurance', 'course', 'takes', 'theoretical', 'approach', 'teaching', 'introductory', 'topics', 'information', 'assurance', 'security', 'course', 'expand', 'upon', 'students', 'knowledge', 'addressing', 'essential', 'elements', 'domains', 'comprise', 'common', 'body', 'knowledge', 'cbk', 'developed', 'international', 'information', 'system', 'security', 'certification', 'consortium', 'isc', 'information', 'systems', 'security', 'professionals', 'course', 'offers', 'depth', 'approach', 'security', 'process', 'providing', 'framework', 'prepare', 'cissp', 'certification']
# ['module', 'helps', 'students', 'develop', 'understanding', 'nature', 'global', 'supply', 'chain', 'networks', 'major', 'issues', 'likely', 'encountered', 'sphere', 'module', 'provides', 'overview', 'supply', 'chain', 'management', 'logistics', 'discusses', 'issues', 'related', 'emerging', 'economies', 'global', 'markets', 'discusses', 'information', 'technology', 'help', 'achieve', 'goals', 'supply', 'chain', 'management', 'cost', 'reduction', 'service', 'enhancement', 'todays', 'global', 'business', 'environment']

# %%
# Create a WordNet lemmatizer object
lemmatizer = WordNetLemmatizer()

# Create a list to store the lemmatized words in each row
lemmatized_words_per_row = []

# Iterate over the rows and lemmatize the words
for words in words_per_row:
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    lemmatized_words_per_row.append(lemmatized_words)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.util import ngrams

# %% [markdown]
# # Getting the Top words and the keyowrds using n-grams

# %%
# Join the lemmatized words per row into sentences
sentences = [' '.join(words) for words in lemmatized_words_per_row]

# Create a TF-IDF vectorizer object
vectorizer = TfidfVectorizer()

# Fit and transform the sentences using TF-IDF vectorizer
tfidf_matrix = vectorizer.fit_transform(sentences)

# Get the feature names (words)
feature_names = vectorizer.get_feature_names_out() 

# Print the most important words for each row
for i, row in enumerate(tfidf_matrix):
    row_data = row.toarray()[0]
    sorted_indices = row_data.argsort()[::-1]
    top_words = [feature_names[idx] for idx in sorted_indices[:10]]  # Change 10 to desired number of top words
    print(f"Row {i+1} - Top Words: {top_words}")

# Extract n-grams from the sentences
ngram_vectorizer = TfidfVectorizer(ngram_range=(2, 3))  # Change the n-gram range as desired
ngram_matrix = ngram_vectorizer.fit_transform(sentences)

# Get the n-gram feature names
ngram_feature_names = ngram_vectorizer.get_feature_names_out()

# Print the most important n-grams for each row
for i, row in enumerate(ngram_matrix):
    row_data = row.toarray()[0]
    sorted_indices = row_data.argsort()[::-1]
    top_ngrams = [ngram_feature_names[idx] for idx in sorted_indices[:10]]  # Change 10 to desired number of top n-grams
    print(f"Row {i+1} - Top N-grams: {top_ngrams}")
# Out:
# Row 1 - Top Words: ['matrix', 'counting', 'differentiation', 'finitestate', 'number', 'graph', 'machine', 'function', 'logic', 'integration']
# Row 2 - Top Words: ['programming', 'mechanic', 'pointer', 'linux', 'procedural', 'debugging', 'introducion', 'array', 'specifically', 'get']
# Row 3 - Top Words: ['examination', 'test', 'midterm', 'speech', 'spot', 'exam', 'semester', 'final', 'comprehensive', 'covered']
# Row 4 - Top Words: ['computer', 'communication', 'network', 'course', 'organized', 'sequential', 'circuit', 'combinational', 'layered', 'end']
# Row 5 - Top Words: ['university', 'require', 'english', 'pursue', 'academic', 'necessary', 'language', 'study', 'skill', 'practice']
# Row 6 - Top Words: ['oriented', 'object', 'solution', 'given', 'class', 'design', 'identifying', 'relationship', 'implement', 'language']
# Row 7 - Top Words: ['software', 'engineering', 'verification', 'artifact', 'produce', 'validation', 'appreciate', 'softwareintensive', 'specification', 'maintain']
# Row 8 - Top Words: ['modeling', 'information', 'system', 'data', 'mainly', '1st', 'mandatory', 'sp', 'relational', 'stream']
# Row 9 - Top Words: ['web', 'application', 'explain', 'usability', 'standard', 'language', 'technology', 'related', 'apply', 'side']
# Row 10 - Top Words: ['engineering', 'mathematical', 'unit', 'special', 'emphasis', 'electricalelectroniccomputer', 'studying', 'encountered', 'mathematics', 'necessary']
# Row 11 - Top Words: ['essential', 'computer', 'network', 'course', 'cover', 'scheme', 'addressing', 'router', 'lan', 'perform']
# Row 12 - Top Words: ['concurrency', 'application', 'programming', 'apply', 'development', 'synthesize', 'validate', 'justify', 'suitable', 'java']
# Row 13 - Top Words: ['database', 'sql', 'design', 'schema', 'handsonexperience', 'refinement', 'conceptual', 'administrative', 'logical', 'cater']
# Row 14 - Top Words: ['tcp', 'switching', 'routing', 'ip', 'configuration', 'operation', 'theory', 'evaluation', 'every', 'everybody']
# Row 15 - Top Words: ['assignment', 'unix', 'utility', 'complete', 'lab', 'tutorial', 'lecture', 'major', 'system', 'administration']
# Row 16 - Top Words: ['oriented', 'object', 'software', 'unified', 'languageuml', 'supportive', 'design', 'modeling', 'applying', 'pattern']
# Row 17 - Top Words: ['logic', 'computer', 'signal', 'keep', 'combinational', 'electronic', 'graduate', 'number', 'sequential', 'covering']
# Row 18 - Top Words: ['statistical', 'statistic', 'output', 'theory', 'different', 'using', 'software', 'data', 'behind', 'understood']
# Row 19 - Top Words: ['electronic', 'analog', 'device', 'understand', 'provide', 'analogue', 'necessa', 'amplifier', 'operational', 'circuitry']
# Row 20 - Top Words: ['oracle', 'database', 'backup', 'managing', 'instanceconfiguring', 'undo', 'creation', 'installing', 'controlling', 'creating']
# Row 21 - Top Words: ['routing', 'static', 'ipv4', 'nat', 'switched', 'discovery', 'dhcp', 'list', 'vlans', 'switch']
# Row 22 - Top Words: ['database', 'solution', 'plan', 'query', 'application', 'performance', 'propose', 'address', 'speed', 'recommend']
# Row 23 - Top Words: ['security', 'cryptography', 'control', 'introduction', 'trusted', 'multilevel', 'symmetric', 'public', 'asymmetric', 'malicious']
# Row 24 - Top Words: ['system', 'io', 'structure', 'process', 'management', 'cpu', 'synchronization', 'deadlock', 'secondary', 'protection']
# Row 25 - Top Words: ['structured', 'information', 'design', 'analysis', 'system', 'also', 'student', 'computeraided', 'handson', 'matter']
# Row 26 - Top Words: ['problem', 'solving', 'effectively', 'solver', 'defining', 'accommodating', 'collaborating', 'ineffective', 'varied', 'difficult']
# Row 27 - Top Words: ['network', 'advancement', 'recent', 'technological', 'evolution', 'field', 'provides', 'theory', 'introduction', 'fundamental']
# Row 28 - Top Words: ['mobile', 'application', 'module', 'android', 'platform', 'technology', 'cater', 'introduces', 'feature', 'indepth']
# Row 29 - Top Words: ['algorithm', 'queue', 'stack', 'linked', 'algorithmic', 'offer', 'list', 'analyze', 'addition', 'introduces']
# Row 30 - Top Words: ['activity', 'evaluation', 'progress', 'proposal', 'writing', 'report', 'final', 'viva', 'informal', 'itp']
# Row 31 - Top Words: ['course', 'discrete', 'mathematics', 'goal', 'technique', 'student', 'logically', 'proof', 'mathematically', 'computability']
# Row 32 - Top Words: ['algorithm', 'computational', 'analysis', 'tree', 'advanced', 'computer', 'string', 'recurrence', 'redblack', 'complexity']
# Row 33 - Top Words: ['network', 'distributed', 'etc', 'architecture', 'related', 'business', 'imperative', 'clientserver', 'osi', 'architectural']
# Row 34 - Top Words: ['project', 'ict', 'preparation', 'showing', 'completion', 'gathering', 'stage', 'achieving', 'involves', 'implementing']
# Row 35 - Top Words: ['diagram', 'state', 'class', 'activity', 'object', 'zeroknowledge', 'evolving', 'evaluation', 'every', 'everybody']
# Row 36 - Top Words: ['lan', 'etherchannel', 'single', 'scaling', 'eigr', 'ospf', 'hsrp', 'ipv6', 'stp', 'spanning']
# Row 37 - Top Words: ['administration', 'problem', 'understanding', 'system', 'might', 'ability', 'task', 'solve', 'apply', 'using']
# Row 38 - Top Words: ['operating', 'system', 'processor', 'educate', 'realtime', 'capability', 'reserve', 'commercial', 'mechanism', 'scheduling']
# Row 39 - Top Words: ['embedded', 'microcontroller', 'automatic', 'closedloop', 'designed', 'design', 'introductory', 'system', 'implement', 'following']
# Row 40 - Top Words: ['project', 'introduction', 'planning', 'management', 'forecasting', 'building', 'pmi', 'guideline', 'estimation', 'group']
# Row 41 - Top Words: ['testing', 'nonfunctional', 'functional', 'specification', 'code', 'coverage', 'case', 'test', 'based', 'method']
# Row 42 - Top Words: ['distributed', 'computing', 'system', 'understanding', 'familiarise', 'difference', 'oppose', 'standalone', 'get', 'involved']
# Row 43 - Top Words: ['framework', 'layer', 'gather', 'persistence', 'comprises', 'conventional', 'scriptingbased', 'java', 'exposed', 'layered']
# Row 44 - Top Words: ['user', 'design', 'experience', 'solution', 'software', 'fit', 'demonstrate', 'life', 'elicit', 'cycle']
# Row 45 - Top Words: ['rdbms', 'it2040', 'db', 'extends', 'continuation', 'it1030', 'hadoop', 'tuning', 'parallel', 'xml']
# Row 46 - Top Words: ['software', 'engineering', 'reflect', 'detailed', 'gained', 'industrybased', 'important', 'applying', 'case', 'study']
# Row 47 - Top Words: ['tool', 'azure', 'version', 'inspection', 'sonarqube', 'selenium', 'automation', 'agile', 'git', 'dashboard']
# Row 48 - Top Words: ['training', 'industrial', 'approved', 'undergo', 'allow', 'period', 'month', 'sliit', 'specialist', 'exposure']
# Row 49 - Top Words: ['webbased', 'development', 'application', 'clientside', 'engineer', 'contemporary', 'frameworkslibraries', 'rich', 'heavy', 'exposed']
# Row 50 - Top Words: ['model', 'statistical', 'series', 'reallife', 'studied', 'regression', 'package', 'encountered', 'situation', 'underlying']
# Row 51 - Top Words: ['bi', 'solution', 'company', 'within', 'well', 'many', 'greater', 'tester', 'administrator', 'completing']
# Row 52 - Top Words: ['database', 'index', 'crash', 'disk', 'tuning', 'objectrelational', 'file', 'xml', 'transaction', 'concurrency']
# Row 53 - Top Words: ['information', 'wide', 'web', 'day', 'publication', 'published', 'academic', 'internet', 'people', 'world']
# Row 54 - Top Words: ['mining', 'data', 'application', 'association', 'preprocessing', 'classification', 'frequent', 'clustering', 'creates', 'deploy']
# Row 55 - Top Words: ['data', 'cloudbased', 'massive', '3rd', 'specializing', 'background', 'follows', 'compulsory', 'hons', 'program']
# Row 56 - Top Words: ['neural', 'fundamental', 'optimization', 'network', 'multilayer', 'genetic', 'linear', 'foundation', 'sound', 'machine']
# Row 57 - Top Words: ['training', 'industrial', 'approved', 'undergo', 'allow', 'period', 'month', 'sliit', 'specialist', 'exposure']
# Row 58 - Top Words: ['mobile', 'security', 'explain', 'concern', 'androidioswindows', 'analyse', '3g', '4g', 'lte', 'small']
# Row 59 - Top Words: ['risk', 'developing', 'course', 'information', 'guide', 'maintaining', 'control', 'several', 'structured', 'explore']
# Row 60 - Top Words: ['operating', 'security', 'data', 'system', 'describe', 'dependent', 'preventive', 'contrast', 'compare', 'combine']
# Row 61 - Top Words: ['assurance', 'case', 'application', 'information', 'problem', 'understanding', 'security', 'practitioner', 'opportunity', 'noninformation']
# Row 62 - Top Words: ['mathematics', 'publickey', 'cryptographic', 'protocol', 'digital', 'security', 'management', 'requires', 'encryption', 'secretkey']
# Row 63 - Top Words: ['project', 'management', 'knowledge', 'pmbok', 'discusse', 'ten', 'given', 'defined', 'identify', 'body']
# Row 64 - Top Words: ['organization', 'unit', 'nature', 'organizational', 'viewpoint', 'in', 'underpin', 'internal', 'managerial', 'intended']
# Row 65 - Top Words: ['use', 'business', 'information', 'change', 'improve', 'repository', 'customer', 'wellbalanced', 'staff', 'mi']
# Row 66 - Top Words: ['data', 'intelligence', 'business', 'integration', 'quality', 'new', 'order', 'develop', 'examine', 'discover']
# Row 67 - Top Words: ['ebusiness', 'site', 'ecommerce', 'usability', 'area', 'business', 'from', 'considered', 'significant', 'revenue']
# Row 68 - Top Words: ['information', 'door', 'protect', 'open', 'acquire', 'sufficient', 'asset', 'detail', 'goal', 'enterprise']
# Row 69 - Top Words: ['economics', 'introduction', 'accounting', 'resource', 'human', 'concept', 'practice', 'provides', 'module', 'management']
# Row 70 - Top Words: ['erp', 'sap', 'resource', 'system', 'planning', 'enterprise', 'organization', 'fundamental', 'business', 'course']
# Row 71 - Top Words: ['strategy', 'innovation', 'help', 'business', 'module', 'information', 'outline', 'strategically', 'linking', 'put']
# Row 72 - Top Words: ['ldap', 'protocol', 'network', 'interchange', 'topology', 'ldif', 'format', 'directory', 'lightweight', 'tolerance']
# Row 73 - Top Words: ['network', 'wan', 'converged', 'meet', 'criterion', 'technology', 'selection', 'teach', 'device', 'complex']
# Row 74 - Top Words: ['storage', 'managing', 'amount', 'protecting', 'moment', 'storing', 'optimizing', 'archive', 'backup', 'every']
# Row 75 - Top Words: ['management', 'economics', 'accounting', 'marketing', 'since', 'functioning', 'changing', 'designed', 'subject', 'introduces']
# Row 76 - Top Words: ['intrusion', 'cryptography', 'network', 'fundamental', 'security', 'prevention', 'private', 'firewall', 'authorization', 'virtual']
# Row 77 - Top Words: ['user', 'product', 'experience', 'service', 'focusing', 'company', 'creating', 'understand', 'better', 'combination']
# Row 78 - Top Words: ['character', 'animation', 'modeling', 'objective', 'module', 'publishing', 'texturing', '3d', 'rendering', 'sculpting']
# Row 79 - Top Words: ['production', 'point', 'digital', 'objective', 'module', 'cinema', 'arrangement', 'manner', 'vfx', 'screening']
# Row 80 - Top Words: ['image', 'segmentation', 'restoration', 'commonly', 'procedure', 'enhancement', 'introductory', 'give', 'processing', 'working']
# Row 81 - Top Words: ['game', 'computer', 'effect', 'cultural', 'story', 'gaming', 'technology', 'ability', 'latest', 'enable']
# Row 82 - Top Words: ['openended', 'solution', 'project', 'apply', 'problem', 'provide', 'lo1', 'pillar', 'nontechnical', 'ass']
# Row 83 - Top Words: ['module', 'technology', 'throughout', 'learnt', 'effectively', 'working', 'able', 'following', 'trend', 'current']
# Row 84 - Top Words: ['image', 'processing', 'digital', 'application', 'including', 'opencv', 'extraction', 'solid', 'sophisticated', 'functionality']
# Row 85 - Top Words: ['machine', 'learning', 'algorithm', 'discus', 'application', 'deterministic', 'limitation', 'solved', 'cannot', 'possible']
# Row 86 - Top Words: ['task', 'service', 'development', 'application', 'software', 'timeconsuming', 'aggregated', 'odata', 'j2ee', 'structural']
# Row 87 - Top Words: ['mobile', 'experience', 'engaging', 'music', 'money', 'almost', 'retail', 'strive', 'create', 'appliance']
# Row 88 - Top Words: ['unit', 'prediction', 'nonlinear', 'honor', 'deep', 'broad', 'offered', 'neural', 'second', 'degree']
# Row 89 - Top Words: ['memory', 'distributed', 'reduce', 'parallelism', 'map', 'paralle', 'shared', 'gpu', 'compting', 'multithreading']
# Row 90 - Top Words: ['storage', 'unit', 'available', '4th', 'programme', 'dbms', 'specializing', 'oracle', 'follows', 'teaching']
# Row 91 - Top Words: ['iot', 'data', 'portion', 'generated', 'simulate', 'particularly', 'generates', 'analytic', 'unstructured', 'work']
# Row 92 - Top Words: ['visual', 'analytics', 'technique', 'learn', 'unit', 'student', 'information', 'data', 'cuttingedge', 'computation']
# Row 93 - Top Words: ['field', 'booming', 'cybersecurityeconomics', 'multidisciplinary', 'economic', 'research', 'analysis', 'security', 'evolvement', 'every']
# Row 94 - Top Words: ['secure', 'software', 'implementationcoding', 'requirement', 'design', 'concept', 'enhancement', 'enhance', 'evaluation', 'every']
# Row 95 - Top Words: ['forensics', 'crime', 'incident', 'digital', 'investigating', 'evidence', 'email', 'soc', 'investigation', 'duplication']
# Row 96 - Top Words: ['governance', 'cyberspace', 'legal', 'course', 'law', 'evolving', 'cybercrime', 'actor', 'whose', 'explore']
# Row 97 - Top Words: ['machine', 'learning', 'algorithm', 'discus', 'application', 'deterministic', 'limitation', 'solved', 'cannot', 'possible']
# Row 98 - Top Words: ['business', 'analysis', 'babok', 'accepted', 'successfully', 'knowledge', 'conduct', 'analyst', 'captured', 'body']
# Row 99 - Top Words: ['hris', 'hr', 'maturity', 'is', 'analytics', 'become', 'type', 'relationship', 'role', 'study']
# Row 100 - Top Words: ['quality', 'assurance', 'broad', 'course', 'technique', 'provides', 'software', 'improvement', 'awareness', 'contribute']
# Row 101 - Top Words: ['knowledge', 'management', 'reused', 'fully', 'stored', 'firm', 'coordination', 'represented', 'generation', 'codification']
# Row 102 - Top Words: ['interaction', 'user', 'computing', 'includes', 'evaluation', 'device', 'interface', 'study', 'technique', 'science']
# Row 103 - Top Words: ['task', 'service', 'development', 'application', 'software', 'timeconsuming', 'aggregated', 'odata', 'j2ee', 'structural']
# Row 104 - Top Words: ['sdn', 'network', 'networking', 'control', 'course', 'allows', 'physical', 'troubleshooting', 'history', 'highlevel']
# Row 105 - Top Words: ['iot', 'ecosystem', 'it', 'phase', 'origination', 'analyzes', 'approaching', 'basis', 'unstructured', 'associated']
# Row 106 - Top Words: ['virtualization', 'cloud', 'computing', 'usage', 'module', 'method', 'network', 'cover', 'finally', 'latter']
# Row 107 - Top Words: ['multimedia', 'explain', 'application', 'delivery', 'us', 'characteristic', 'various', 'method', 'project', 'software']
# Row 108 - Top Words: ['technology', 'module', 'throughout', 'learnt', 'effectively', 'able', 'realworld', 'working', 'trend', 'following']
# Row 109 - Top Words: ['th', 'optional', 'dbms', 'sp', 'oracle', 'stream', 'teaching', 'depth', 'hons', 'purpose']
# Row 110 - Top Words: ['aws', 'teaching', 'depth', 'purpose', 'cloud', 'field', 'computing', 'theory', 'used', 'tool']
# Row 111 - Top Words: ['network', 'advancement', 'recent', 'technological', 'evolution', 'field', 'provides', 'theory', 'introduction', 'fundamental']
# Row 112 - Top Words: ['attitude', 'respect', 'professional', 'student', 'spectrum', 'acceptable', 'strength', 'diversity', 'professionalism', 'compliment']
# Row 113 - Top Words: ['following', 'year', 'student', '2nd', 'non', 'gpa', 'conducted', 'second', 'offered', 'four']
# Row 114 - Top Words: ['technology', 'throughout', 'learnt', 'realworld', 'working', 'effectively', 'able', 'trend', 'following', 'current']
# Row 115 - Top Words: ['network', 'introduction', 'protocol', 'server', 'management', 'www', 'directoryaccess', 'fault', 'snmp', 'lightweight']
# Row 116 - Top Words: ['database', 'indexing', 'objectrelational', 'xml', 'transaction', 'relational', 'optimization', 'feature', 'concurrency', 'query']
# Row 117 - Top Words: ['professional', 'business', 'expose', 'broaden', 'whole', 'economy', 'may', 'view', 'overall', 'particular']
# Row 118 - Top Words: ['data', 'analytics', 'warehousing', 'using', 'related', 'method', 'theory', 'python', 'traditional', 'analyzing']
# Row 119 - Top Words: ['technique', 'design', 'user', 'evaluating', 'implementing', 'sketching', 'prototyping', 'finding', 'interactive', 'human']
# Row 120 - Top Words: ['security', 'course', 'information', 'certification', 'assurance', 'approach', 'cbk', 'common', 'expand', 'isc']
# Row 121 - Top Words: ['chain', 'global', 'supply', 'issue', 'help', 'discus', 'management', 'reduction', 'likely', 'logistics']
# Row 1 - Top N-grams: ['graph theory', 'theory matrix', 'function counting graph', 'graph theory matrix', 'function counting', 'counting graph', 'counting graph theory', 'system differentiation', 'system differentiation integration', 'integration function']
# Row 2 - Top N-grams: ['programming paradigm topic', 'recursion mechanic', 'programming concept specifically', 'programming concept', 'array file recursion', 'array file', 'function pointer', 'function pointer array', 'linux operation', 'pointer array']
# Row 3 - Top N-grams: ['speech test spot', 'midterm examination final', 'final examination', 'final examination comprehensive', 'test midterm', 'test midterm examination', 'test spot', 'test spot test', 'based topic covered', 'based topic']
# Row 4 - Top N-grams: ['computer network', 'computer system', 'basic operation', 'able explain computer', 'fundamental computer organization', 'explain computer system', 'explain computer', 'computer network end', 'computer network order', 'logic circuit data']
# Row 5 - Top N-grams: ['academic practice', 'practice require pursue', 'language skill', 'practice require', 'university study', 'necessary english', 'necessary english language', 'skill academic practice', 'skill academic', 'language skill academic']
# Row 6 - Top N-grams: ['object oriented', 'understand apply basic', 'programming design', 'solution given problem', 'solution given', 'class relationship object', 'class relationship', 'analysis design implement', 'concept object oriented', 'concept object']
# Row 7 - Top N-grams: ['software engineering concept', 'engineering concept', 'software engineering', 'module include', 'maintain software', 'validation evolution software', 'validation evolution', 'help produce maintain', 'maintain software product', 'artifact further student']
# Row 8 - Top N-grams: ['data modeling', 'information system', '1st year', 'overall understanding', 'modeling relationship', 'modeling relationship data', 'understand aspect', 'understand aspect real', 'system data modeling', 'system data']
# Row 9 - Top N-grams: ['related application', 'web application', 'domain along security', 'design principle best', 'design principle', 'markup language', 'markup language presentation', 'standard digital', 'application development explain', 'standard ui']
# Row 10 - Top N-grams: ['problem encountered engineering', 'applying mathematical', 'mathematics special', 'mathematics special emphasis', 'student skill necessary', 'understand engineering', 'understand engineering mathematics', 'student skill', 'studying applying', 'studying applying mathematical']
# Row 11 - Top N-grams: ['cover essential', 'computer network', 'perform basic', 'ip addressing scheme', 'networking course', 'networking course cover', 'aim module cover', 'simple lan', 'simple lan perform', 'perform basic configuration']
# Row 12 - Top N-grams: ['concurrency programming', 'application development', 'usage software', 'development justify usage', 'developing application apply', 'suitable set design', 'set design', 'set design pattern', 'concept developing', 'usage software engineering']
# Row 13 - Top N-grams: ['database design', 'handsonexperience developing database', 'schema refinement sql', 'schema refinement', 'sql database programming', 'sql database', 'logical database design', 'design schema refinement', 'database using sql', 'database using']
# Row 14 - Top N-grams: ['configuration tcp', 'tcp ip operation', 'theory configuration', 'theory configuration tcp', 'ip operation', 'switching theory', 'routing switching theory', 'routing switching', 'tcp ip', 'configuration tcp ip']
# Row 15 - Top N-grams: ['administration student also', 'knowledge learn lecture', 'component operating', 'tutorial lab complete', 'tutorial lab', 'system administration student', 'lecture tutorial lab', 'knowledge learn', 'complete unit programming', 'unit programming']
# Row 16 - Top N-grams: ['object oriented', 'pattern software testing', 'applying design', 'oriented software engineering', 'oriented software', 'modeling languageuml', 'modeling languageuml tool', 'applying design pattern', 'object oriented software', 'pattern software']
# Row 17 - Top N-grams: ['system sequential', 'engineering graduate', 'logic basic concept', 'logic basic', 'number system sequential', 'keep operation computer', 'computer networking engineering', 'computer networking', 'module give understanding', 'module give']
# Row 18 - Top N-grams: ['data using software', 'descriptive statistic', 'performing different statistical', 'performing different', 'statistical technique different', 'statistical technique', 'statistical software basic', 'statistical software', 'statistical inference output', 'statistical inference']
# Row 19 - Top N-grams: ['analog electronic', 'student knowledge necessa', 'circuitry using', 'engineering concept objective', 'knowledge necessa', 'knowledge necessa understand', 'using discrete device', 'circuit syllabus', 'circuit syllabus contains', 'circuitry using discrete']
# Row 20 - Top N-grams: ['oracle database', 'managing oracle instanceconfiguring', 'managing undo data', 'managing undo', 'recovery concept', 'recovery concept performing', 'backup recovery', 'concept performing', 'concept performing database', 'managing oracle']
# Row 21 - Top N-grams: ['discovery management maintenance', 'routing concept', 'switch configuration', 'nat ipv4 device', 'nat ipv4', 'switch configuration vlans', 'dhcp nat ipv4', 'switched network', 'switched network switch', 'access control list']
# Row 22 - Top N-grams: ['server design implement', 'evaluate query plan', 'plan propose appropriate', 'plan recommend', 'plan recommend solution', 'use relational', 'use relational query', 'real world application', 'speed database server', 'speed database']
# Row 23 - Top N-grams: ['security security', 'introduction cyber security', 'aspect information', 'security control', 'security security general', 'security security control', 'security control risk', 'risk management malicious', 'software user authentication', 'software user']
# Row 24 - Top N-grams: ['secondary storage', 'file system', 'system characteristic system', 'characteristic system', 'characteristic system protection', 'process management cpu', 'management cpu', 'management cpu scheduling', 'operating system structure', 'memory management deadlock']
# Row 25 - Top N-grams: ['structured analysis', 'structured analysis design', 'design information', 'design information system', 'information system', 'analysis design', 'student also', 'computeraided software', 'problem design', 'student also gain']
# Row 26 - Top N-grams: ['practical tool analyzing', 'identifying appropriate solution', 'often ineffective', 'often ineffective well', 'analyst student learn', 'analyst student', 'perspective organizational stakeholder', 'perspective organizational', 'organizational stakeholder identifying', 'organizational stakeholder']
# Row 27 - Top N-grams: ['evolution application', 'theory evolution', 'concept theory evolution', 'management field', 'management field network', 'concept theory', 'field network cover', 'field network', 'design management field', 'provides introduction network']
# Row 28 - Top N-grams: ['mobile application', 'applied using', 'applied using mobile', 'real world requirement', 'platform further', 'platform further module', 'module cover fundamental', 'concept mobile', 'concept mobile application', 'mobile technology']
# Row 29 - Top N-grams: ['understand analyze', 'stack queue linked', 'different algorithm', 'list tree addition', 'list tree', 'designing algorithm enables', 'designing algorithm', 'algorithmic way', 'addition offer indepth', 'stack queue']
# Row 30 - Top N-grams: ['progress evaluation', 'testing activity git', 'evaluation informal', 'activity introduction itp', 'activity introduction', 'activity interface designing', 'activity interface', 'activity git report', 'activity git', 'evaluation lecture scrum']
# Row 31 - Top N-grams: ['discrete mathematics', 'introduce student', 'formal language', 'science engineering course', 'science engineering', 'discrete mathematics goal', 'involving relation graph', 'algorithm mathematical', 'algorithm mathematical reasoning', 'involving relation']
# Row 32 - Top N-grams: ['technique algorithm design', 'program study', 'recursion mathematical', 'recurrence relation bigo', 'recurrence relation', 'npcompleteness sorting searching', 'npcompleteness sorting', 'notation npcompleteness sorting', 'notation npcompleteness', 'program study involving']
# Row 33 - Top N-grams: ['architectural design clientserver', 'system architectural design', 'issue related architecture', 'include business', 'include business imperative', 'design clientserver', 'related architecture', 'related architecture network', 'key network', 'key network technology']
# Row 34 - Top N-grams: ['implementing marketing aspect', 'various stage completion', 'implementing marketing', 'objective ict', 'managing achieving', 'managing achieving objective', 'client preparation project', 'client preparation', 'developing managing', 'developing managing achieving']
# Row 35 - Top N-grams: ['object diagram state', 'diagram state diagram', 'activity diagram object', 'activity diagram', 'state diagram', 'class diagram', 'state diagram class', 'diagram class', 'diagram class diagram', 'diagram object diagram']
# Row 36 - Top N-grams: ['single area', 'etherchannel hsrp dynamic', 'ospf eigr', 'routing single', 'dynamic routing single', 'lan design scaling', 'lan design', 'lan concept ipv6', 'lan concept', 'single area ospf']
# Row 37 - Top N-grams: ['system administration', 'network administration', 'solve problem', 'administration apply', 'system network administration', 'system network', 'practice using', 'involves task', 'evaluate different', 'interface understand complex']
# Row 38 - Top N-grams: ['operating system', 'operating system basic', 'fundamental operating', 'objective unit educate', 'introduce realtime', 'introduce realtime operating', 'operating system scheduling', 'capability commercial', 'capability commercial different', 'basic objective unit']
# Row 39 - Top N-grams: ['system design', 'embedded system design', 'embedded system', 'using microcontroller', 'student following unit', 'closedloop automatic', 'following unit', 'control using', 'design student following', 'unit learn requirement']
# Row 40 - Top N-grams: ['controlling pmi guideline', 'management introduction', 'business analysis introduction', 'group project', 'estimation planning', 'estimation planning project', 'selection project estimation', 'selection project', 'team building project', 'team building']
# Row 41 - Top N-grams: ['testing fundamental', 'analysis functional', 'coverage analysis', 'test case', 'test case design', 'coverage analysis functional', 'method specification based', 'method specification', 'case design', 'fundamental method specification']
# Row 42 - Top N-grams: ['distributed computing', 'computing oppose', 'computing may', 'intends familiarise student', 'intends familiarise', 'module intends familiarise', 'application distributed computing', 'may applied possible', 'standalone system difference', 'standalone system']
# Row 43 - Top N-grams: ['application integration', 'gather knowledge', 'framework comprises', 'integration data', 'integration data access', 'gather knowledge many', 'access layer test', 'access layer', 'scriptingbased development', 'development layered']
# Row 44 - Top N-grams: ['user experience', 'user experience design', 'experience design', 'cycle apply design', 'software development life', 'experience testing', 'interface investigate', 'interface investigate user', 'experience testing secure', 'apply design']
# Row 45 - Top N-grams: ['it2040 extends nosql', 'framework xml', 'unit continuation it1030', 'unit continuation', 'architecture topic', 'architecture topic related', 'distributed db architecture', 'distributed db', 'topic related query', 'framework xml integration']
# Row 46 - Top N-grams: ['module discus important', 'software analysis detailed', 'objective module discus', 'engineering software', 'gained applying', 'gained applying concept', 'analysis detailed', 'industrybased case study', 'industrybased case', 'analysis detailed design']
# Row 47 - Top N-grams: ['code quality inspection', 'control system', 'management tool', 'management tool sonarqube', 'tool sonarqube code', 'git distributed', 'git distributed version', 'inspection tool git', 'version control', 'version control system']
# Row 48 - Top N-grams: ['industrial training', 'industrial exposure', 'period month', 'aim industrial', 'aim industrial training', 'provide student industrial', 'specialist undergo', 'specialist undergo industrial', 'industrial training training', 'industrial training module']
# Row 49 - Top N-grams: ['webbased application development', 'webbased application', 'application development', 'standard webbased application', 'heavy clientside', 'well rich', 'well rich webbased', 'practice used engineer', 'practice used', 'technology frameworkslibraries']
# Row 50 - Top N-grams: ['student also learn', 'time series etc', 'etc student', 'etc student also', 'learn use statistical', 'reallife situation', 'reallife situation model', 'theory practical', 'use statistical package', 'use statistical']
# Row 51 - Top N-grams: ['bi solution', 'build bi', 'recommended exercise student', 'recommended exercise', 'department within company', 'department within', 'greater understanding', 'greater understanding role', 'build bi solution', 'planning work']
# Row 52 - Top N-grams: ['component database system', 'related disk', 'integration component', 'integration component database', 'file index', 'file index query', 'recovery discussed', 'recovery discussed detail', 'topic related disk', 'database xml']
# Row 53 - Top N-grams: ['world wide', 'world wide web', 'wide web', 'meaning information', 'newspaper tv', 'like newspaper tv', 'creator explosion', 'creator explosion published', 'meaning information spread', 'evolvement computerbased']
# Row 54 - Top N-grams: ['data mining', 'mining application', 'data mining application', 'relate frequent pattern', 'data preprocessing', 'data preprocessing method', 'practice field data', 'concept relate frequent', 'concept relate', 'field data mining']
# Row 55 - Top N-grams: ['using cloudbased infrastructure', 'data processing using', 'program cover background', 'data processing', 'processing using cloudbased', 'processing using', 'infrastructure development', 'infrastructure development tool', 'module 3rd', 'module 3rd year']
# Row 56 - Top N-grams: ['neural network', 'learning optimization', 'programming genetic', 'optimization module', 'optimization linear programming', 'concept machine', 'linear programming genetic', 'sound foundation fundamental', 'linear programming', 'foundation fundamental concept']
# Row 57 - Top N-grams: ['industrial training', 'industrial exposure', 'period month', 'aim industrial', 'aim industrial training', 'provide student industrial', 'specialist undergo', 'specialist undergo industrial', 'industrial training training', 'industrial training module']
# Row 58 - Top N-grams: ['explain mobile', 'explain mobile security', 'security concern', 'mobile security', 'large organization', 'lte explain', 'androidioswindows explain security', 'security concern related', 'security concern different', 'security concept theoretical']
# Row 59 - Top N-grams: ['risk management', 'information security', 'guide information security', 'risk management approach', 'developing maintaining', 'developing maintaining risk', 'management approach', 'approach guide', 'approach guide information', 'management approach guide']
# Row 60 - Top N-grams: ['operating system', 'data operating system', 'data operating', 'operating system security', 'system security', 'secure database environment', 'explain requirement data', 'security explain', 'security explain requirement', 'security mechanism']
# Row 61 - Top N-grams: ['understanding application', 'information assurance', 'security policy', 'practitioner community design', 'understanding application business', 'professional identification remediation', 'professional identification', 'integrate apply', 'integrate apply information', 'casestudy approach introduced']
# Row 62 - Top N-grams: ['zeroknowledge protocol highly', 'authentication key management', 'message integrity', 'sharing bit', 'infrastructure digital', 'infrastructure digital right', 'sharing bit zeroknowledge', 'authentication key', 'ssl ipsec', 'protocol ssl']
# Row 63 - Top N-grams: ['project management', 'recent development', 'student given knowledge', 'identify information system', 'information system project', 'management institute project', 'management institute', 'defined project management', 'project ten project', 'body knowledge pmbok']
# Row 64 - Top N-grams: ['nature organization', 'practical viewpoint unit', 'significance organizational design', 'provide basic for', 'relation management', 'relation management practice', 'practice use managerial', 'practice use', 'concept marketing', 'concept marketing perform']
# Row 65 - Top N-grams: ['serve need', 'impact organizational change', 'strategic use', 'change innovation', 'strategic use impact', 'manage various', 'manage various information', 'skill business', 'wellbalanced repository', 'wellbalanced repository skill']
# Row 66 - Top N-grams: ['data integration', 'business intelligence', 'quality data', 'order build quality', 'addition data integration', 'build quality data', 'challenge aim module', 'challenge aim', 'examine data', 'examine data quality']
# Row 67 - Top N-grams: ['ecommerce site', 'model ebusiness', 'from business strategy', 'considered usability', 'technical architecture business', 'technical architecture', 'strategy applicable', 'strategy applicable ebusiness', 'from business', 'business revenue']
# Row 68 - Top N-grams: ['student acquire sufficient', 'detail goal open', 'cover enterprise', 'cover enterprise information', 'student acquire', 'enterprise information security', 'enterprise information', 'information asset organization', 'information asset', 'protect information asset']
# Row 69 - Top N-grams: ['concept practice', 'human resource management', 'introduction concept', 'human resource', 'practice economics', 'concept practice economics', 'introduction concept practice', 'resource management', 'module provides', 'general understanding']
# Row 70 - Top N-grams: ['erp system', 'enterprise resource', 'enterprise resource planning', 'resource planning', 'fundamental framework', 'planning erp system', 'technology context technological', 'concept fundamental', 'concept fundamental framework', 'concept importance']
# Row 71 - Top N-grams: ['business strategy', 'information system', 'tool help make', 'module describes', 'module describes manager', 'core business strategy', 'core business', 'consider develop', 'provide analytical tool', 'provide analytical']
# Row 72 - Top N-grams: ['ldap ldap data', 'ldap security cloud', 'ldap topology', 'ldap topology design', 'ldif ldap', 'replication ldap security', 'data interchange format', 'network design mapping', 'disaster recovery simple', 'recovery simple']
# Row 73 - Top N-grams: ['wan technology', 'criterion network device', 'module focus selection', 'technology network service', 'technology network', 'requirement organization', 'module teach wan', 'technology meet network', 'technology meet', 'network module focus']
# Row 74 - Top N-grams: ['storage system', 'amount digital information', 'protecting optimizing managing', 'student learn storage', 'created every moment', 'created every', 'replication cloud', 'replication cloud storage', 'every moment individual', 'every moment']
# Row 75 - Top N-grams: ['economics marketing', 'familiarize student basic', 'used functioning area', 'changing business environment', 'practice management principle', 'concept management', 'concept management economics', 'accounting within changing', 'accounting within', 'management accounting']
# Row 76 - Top N-grams: ['cryptography fundamental cryptographic', 'managing secure', 'modern network', 'fundamental cryptographic hash', 'fundamental cryptographic', 'modern network security', 'introduction security fundamental', 'cryptography fundamental', 'ipsec managing secure', 'security threat cryptography']
# Row 77 - Top N-grams: ['user experience', 'product service', 'focusing user', 'product user', 'method framework', 'helpful design', 'helpful design much', 'experience designer', 'connection product user', 'connection product']
# Row 78 - Top N-grams: ['character animation', 'objective module', 'providing knowledge cgi', 'includes modeling', 'way successful publishing', 'cgi product', 'cgi product must', 'successful publishing', 'knowledge 3d', 'knowledge 3d modeling']
# Row 79 - Top N-grams: ['objective module', 'integrated latest technology', 'technology audio arrangement', 'way point final', 'picture production', 'picture production must', 'includes evolution', 'includes evolution visual', 'overall knowledge digital', 'evolution visual production']
# Row 80 - Top N-grams: ['introductory module image', 'image enhancement', 'commonly used', 'commonly used method', 'image processing give', 'enhancement restoration segmentation', 'enhancement restoration', 'method procedure image', 'processing give student', 'processing give']
# Row 81 - Top N-grams: ['computer game', 'technology module aim', 'ethical cultural aspect', 'ethical cultural', 'industry discus', 'module aim provide', 'industry discus topic', 'computer game game', 'computer game latest', 'gaming enable ability']
# Row 82 - Top N-grams: ['solution openended', 'ass commercial viability', 'apply key pillar', 'nontechnical stakeholder lo5', 'problem using appropriate', 'nontechnical stakeholder', 'apply project', 'apply project management', 'best practice standard', 'including technical']
# Row 83 - Top N-grams: ['engineering industry', 'software engineering industry', 'effectively solve real', 'trend technology software', 'solve real', 'solve real world', 'engineering industry following', 'module provide understanding', 'technology software', 'technology software engineering']
# Row 84 - Top N-grams: ['image processing', 'digital image', 'digital image processing', 'application digital', 'application digital image', 'digital image manipulation', 'morphological operator', 'image manipulation', 'use method procedure', 'use method']
# Row 85 - Top N-grams: ['machine learning', 'deterministic algorithm', 'machine learning discus', 'technology different', 'algorithm technique may', 'discus machine learning', 'realworld problem cannot', 'discus machine', 'discus limitation possible', 'discus limitation']
# Row 86 - Top N-grams: ['nosql web service', 'software development implementation', 'goal software', 'allowing concentrate', 'allowing concentrate actual', 'key concept', 'key concept software', 'actual goal software', 'actual goal', 'technology emerging']
# Row 87 - Top N-grams: ['service use', 'create meaningful', 'meaningful relationship', 'learning around key', 'learning around', 'almost every', 'every digital', 'design student strive', 'every digital experience', 'service use computer']
# Row 88 - Top N-grams: ['science unit', 'science unit intends', 'unit intends give', 'unit intends', 'neural network used', 'aspect deep', 'network used', 'honor degree computer', 'honor degree', 'network used realworld']
# Row 89 - Top N-grams: ['gpu computing shared', 'memory parallelism map', 'reduce based distributed', 'computing shared memory', 'computing shared', 'module introduce paralle', 'gpu computing', 'parallelism map reduce', 'parallelism map', 'parallel algorithm gpu']
# Row 90 - Top N-grams: ['solution feature', 'environment take depth', 'enterprise storage solution', 'enterprise storage', 'programme objective', 'covered available', 'covered available enterprise', 'programme objective unit', 'unit 4th', 'unit 4th year']
# Row 91 - Top N-grams: ['data stream', 'service point', 'major portion course', 'major portion', 'iot architecture', 'student work team', 'indepth coverage iot', 'point view particularly', 'student work', 'service point view']
# Row 92 - Top N-grams: ['visual analytics', 'student learn', 'presentation dissemination', 'learn use build', 'reasoning technique', 'real world data', 'context variety audience', 'comprehensive knowledge analytical', 'comprehensive knowledge', 'unit 3rd']
# Row 93 - Top N-grams: ['field cybersecurityeconomics', 'multidisciplinary field', 'security economic analysis', 'economic analysis booming', 'economic analysis', 'security economic', 'research field', 'research field multidisciplinary', 'booming research field', 'booming research']
# Row 94 - Top N-grams: ['secure software', 'software requirement secure', 'design secure software', 'requirement secure', 'software implementationcoding', 'software concept', 'secure software requirement', 'secure software implementationcoding', 'secure software design', 'secure software concept']
# Row 95 - Top N-grams: ['forensics introduction incident', 'computer crime investigation', 'forensics computer crime', 'forensics introduction', 'introduction incident management', 'forensics mobile', 'forensics mobile forensics', 'forensics modern', 'forensics modern topic', 'forensics windowslinux']
# Row 96 - Top N-grams: ['course explore', 'examines legal policy', 'governance risk management', 'business whose', 'business whose intellectual', 'governing constantly changing', 'governing constantly', 'governance structure governance', 'governance structure', 'governance risk']
# Row 97 - Top N-grams: ['machine learning', 'deterministic algorithm', 'machine learning discus', 'technology different', 'algorithm technique may', 'discus machine learning', 'realworld problem cannot', 'discus machine', 'discus limitation possible', 'discus limitation']
# Row 98 - Top N-grams: ['business analysis', 'order develop effective', 'skill essential', 'aim give student', 'aim give', 'babok focus role', 'babok focus', 'business requirement', 'business requirement analysis', 'captured business']
# Row 99 - Top N-grams: ['role is', 'maturity hris', 'relationship hr', 'hris role', 'hris hris become', 'hris hris', 'hris hr analytics', 'hris hr', 'hris become study', 'hris become']
# Row 100 - Top N-grams: ['quality assurance', 'course provides', 'participant broad awareness', 'tool achieving software', 'tool achieving', 'participant broad', 'practical knowledge variety', 'awareness many', 'awareness many activity', 'standard policy']
# Row 101 - Top N-grams: ['knowledge management', 'reused fully', 'knowledge acquisition assessment', 'created captured', 'created captured represented', 'coordination codification knowledge', 'module focus knowledge', 'coordination codification', 'tool technique knowledge', 'include knowledge generation']
# Row 102 - Top N-grams: ['computing device', 'study interaction', 'user computing device', 'user computing', 'behavioral science', 'often regarded', 'several field', 'occurs user', 'occurs user interface', 'interaction design software']
# Row 103 - Top N-grams: ['nosql web service', 'software development implementation', 'goal software', 'allowing concentrate', 'allowing concentrate actual', 'key concept', 'key concept software', 'actual goal software', 'actual goal', 'technology emerging']
# Row 104 - Top N-grams: ['networking sdn', 'develop good', 'underlying physical', 'simulation environment mininet', 'emerging paradigm', 'emerging paradigm data', 'current usage future', 'current usage', 'understanding sdn challenge', 'understanding sdn']
# Row 105 - Top N-grams: ['iot ecosystem', 'iot ecosystem particular', 'focus iot ecosystem', 'phase iot ecosystem', 'analyzes unstructured data', 'analyzes unstructured', 'industry approaching it', 'ecosystem particular', 'ecosystem particular module', 'origination iot']
# Row 106 - Top N-grams: ['cloud computing', 'usage virtualization', 'virtualization technique', 'module cover', 'virtualization method', 'virtualization technique finally', 'virtualization principle different', 'virtualization principle', 'virtualization network function', 'virtualization network']
# Row 107 - Top N-grams: ['us various', 'project explain application', 'multimedia project explain', 'multimedia project', 'multimedia explain multimedia', 'multimedia explain', 'characteristic multimedia project', 'characteristic multimedia', 'multimedia delivery method', 'multimedia delivery']
# Row 108 - Top N-grams: ['technology industry following', 'information technology industry', 'module provide understanding', 'technology information technology', 'effectively solve realworld', 'technology information', 'trend technology information', 'technology industry', 'apply concept', 'understanding working knowledge']
# Row 109 - Top N-grams: ['practice database', 'database administration oracle', 'information technology software', 'engineering stream objective', 'software engineering stream', 'engineering stream', 'th year', 'th year student', 'module th year', 'module th']
# Row 110 - Top N-grams: ['aws tool', 'aws tool used', 'practice field cloud', 'field cloud', 'field cloud computing', 'computing aws tool', 'computing aws', 'cloud computing aws', 'provide depth understanding', 'provide depth']
# Row 111 - Top N-grams: ['evolution application', 'theory evolution', 'concept theory evolution', 'management field', 'management field network', 'concept theory', 'field network cover', 'field network', 'design management field', 'provides introduction network']
# Row 112 - Top N-grams: ['embrace diversity respect', 'required maintain acceptable', 'develops knowledge', 'professionalism practice', 'professional world student', 'professional world', 'prepare professional', 'prepare professional world', 'norm ethic respect', 'norm ethic']
# Row 113 - Top N-grams: ['student following', 'gpa compulsory module', 'practice industry', 'student exposure', 'student exposure required', 'student following 2nd', 'student following four', 'following four year', 'following four', 'following 2nd year']
# Row 114 - Top N-grams: ['technology information technology', 'technology information', 'technology industry following', 'technology industry', 'trend technology information', 'information technology industry', 'effectively solve realworld', 'knowledge current', 'module student able', 'able apply concept']
# Row 115 - Top N-grams: ['network server', 'network mapping baselining', 'network server network', 'protocol ldap simple', 'security lightweight directoryaccess', 'security lightweight', 'network security lightweight', 'protocol snmp introduction', 'web www introduction', 'lightweight directoryaccess protocol']
# Row 116 - Top N-grams: ['related indexing', 'advanced feature', 'cover objectrelational', 'cover objectrelational database', 'indexing query optimization', 'indexing query', 'integration advanced', 'integration advanced feature', 'unit cover', 'unit cover objectrelational']
# Row 117 - Top N-grams: ['overall economy whole', 'may broaden professional', 'whole business', 'whole business organization', 'various domain knowledge', 'various domain', 'economy whole business', 'broaden professional view', 'may broaden', 'broaden professional']
# Row 118 - Top N-grams: ['data analytics', 'data warehousing', 'analytics student', 'analytics student also', 'practice related field', 'practice related', 'analytics using python', 'analytics using', 'theory concept related', 'provide overview']
# Row 119 - Top N-grams: ['evaluating implementing interactive', 'design user experience', 'designing evaluating', 'experience design software', 'develop skill', 'develop skill designing', 'practice principle', 'standard best', 'design user', 'interaction design user']
# Row 120 - Top N-grams: ['information system security', 'system security', 'information system', 'course take theoretical', 'comprise common', 'framework prepare', 'framework prepare cissp', 'security course', 'theoretical approach teaching', 'theoretical approach']
# Row 121 - Top N-grams: ['supply chain', 'chain management', 'supply chain management', 'today global business', 'goal supply chain', 'sphere module provides', 'sphere module', 'related emerging economy', 'help achieve', 'achieve goal supply']

# %% [markdown]
# # Saving the keywords in a csv file

# %%
import csv

# Print the most important n-grams for each module title
with open('module Keywords.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Module Title', 'Top N-grams'])  # Write header row

    module_titles = df['Module Title']

    for i, row in enumerate(ngram_matrix):
        row_data = row.toarray()[0]
        sorted_indices = row_data.argsort()[::-1]
        top_ngrams = [ngram_feature_names[idx] for idx in sorted_indices[:10]]  # Change 10 to desired number of top n-grams
        writer.writerow([module_titles[i], ', '.join(top_ngrams)])  # Write module title and top n-grams

print("Top n-grams saved to Module Keywords file.")
# Out:
# Top n-grams saved to Module Keywords file.
